# %% [markdown]
# # **Detection of Buildings (using ImageNet weights)**
#
# #### **Team Bag – Andrius Šukys, Benas Skripkiūnas, Greta Virpšaitė**
#
# **The Objective.** The main purpose of the task was to create a UNet-based binary semantic segmentation model that would be able to recognize buildings in the given satellite pictures as accurately as possible.
#
# **The Process.** Two models were run in parallel:
# * one with common ImageNet weights of *`mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225]`* which in turn made it a fine-tuning task,
#
# * the other model was given weights of *`mean = [0, 0, 0], std = [1, 1, 1]`* to train the model from scratch.
#
# Both models were trained on thresholds from 0.1 to 0.9 (with step of 0.1) to determine which threshold works best for the aforementioned given weights. Then the models of both weight sets using their best threshold values were compared in practice using a test dataset.
#
# **The Results.** The results of the aforementioned process were analyzed in the final report.
#
# #### **The source codes and the final report of the project are all available on [GitHub](https://github.com/Andrius-Sukys/DL-DetectionOfBuildings).**
#
# #### **The datasets, predictions and output models due to their big size (GitHub does not allow to save them there) of the project are all available on [Google Drive](https://drive.google.com/drive/folders/1jMvX0dYo60M-s_ZaNAo_Fe_TC1f5Tut7?usp=sharing).**

# %% [markdown]
# # Setup of needed Modules and Libraries

# %%
from albumentations.pytorch import ToTensorV2
from matplotlib.ticker import MultipleLocator
from PIL import Image
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import albumentations as alb
import matplotlib.pyplot as plt
import numpy as np
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms.functional as F

# %% [markdown]
# # Mounting on Google Drive

# %% [markdown]
# In order to avoid having to upload the images and masks each time the project is run, they were placed in Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Getting the images and masks, testing if they were obtained correctly.

# %%
# Images and masks for training
train_image_dir = '/content/drive/My Drive/images/train'
train_mask_dir = '/content/drive/My Drive/masks/train'

# Images and masks for validation
validation_image_dir = '/content/drive/My Drive/images/validation'
validation_mask_dir = '/content/drive/My Drive/masks/validation'

# Function to print image names to ensure mounting works as expected
def print_image_names(image_dir, mask_dir):

  image_names = sorted(os.listdir(image_dir))
  mask_names = sorted(os.listdir(mask_dir))

  print(image_names)
  print(mask_names)

print("Training Set:")
print_image_names(train_image_dir, train_mask_dir)

print("\nValidation Set:")
print_image_names(validation_image_dir, validation_mask_dir)
# Out:
# Training Set:
# ['image_01.png', 'image_02.png', 'image_03.png', 'image_04.png', 'image_05.png', 'image_06.png', 'image_07.png', 'image_08.png', 'image_09.png', 'image_10.png', 'image_100.png', 'image_1000.png', 'image_1001.png', 'image_1002.png', 'image_1003.png', 'image_1004.png', 'image_1005.png', 'image_1006.png', 'image_1007.png', 'image_1008.png', 'image_1009.png', 'image_101.png', 'image_1010.png', 'image_1011.png', 'image_1012.png', 'image_1013.png', 'image_1014.png', 'image_1015.png', 'image_1016.png', 'image_1017.png', 'image_1018.png', 'image_1019.png', 'image_102.png', 'image_1020.png', 'image_1021.png', 'image_1022.png', 'image_1023.png', 'image_1024.png', 'image_1025.png', 'image_1026.png', 'image_1027.png', 'image_1028.png', 'image_1029.png', 'image_103.png', 'image_1030.png', 'image_1031.png', 'image_1032.png', 'image_1033.png', 'image_1034.png', 'image_1035.png', 'image_1036.png', 'image_1037.png', 'image_1038.png', 'image_1039.png', 'image_104.png', 'image_1040.png', 'image_1041.png', 'image_1042.png', 'image_1043.png', 'image_1044.png', 'image_1045.png', 'image_1046.png', 'image_1047.png', 'image_1048.png', 'image_1049.png', 'image_105.png', 'image_1050.png', 'image_1051.png', 'image_1052.png', 'image_1053.png', 'image_1054.png', 'image_1055.png', 'image_1056.png', 'image_1057.png', 'image_1058.png', 'image_1059.png', 'image_106.png', 'image_1060.png', 'image_1061.png', 'image_1062.png', 'image_1063.png', 'image_1064.png', 'image_1065.png', 'image_1066.png', 'image_1067.png', 'image_1068.png', 'image_1069.png', 'image_107.png', 'image_1070.png', 'image_1071.png', 'image_1072.png', 'image_1073.png', 'image_1074.png', 'image_1075.png', 'image_1076.png', 'image_1077.png', 'image_1078.png', 'image_1079.png', 'image_108.png', 'image_1080.png', 'image_1081.png', 'image_1082.png', 'image_1083.png', 'image_1084.png', 'image_1085.png', 'image_1086.png', 'image_1087.png', 'image_1088.png', 'image_1089.png', 'image_109.png', 'image_1090.png', 'image_1091.png', 'image_1092.png', 'image_1093.png', 'image_1094.png', 'image_1095.png', 'image_1096.png', 'image_1097.png', 'image_1098.png', 'image_1099.png', 'image_11.png', 'image_110.png', 'image_1100.png', 'image_1101.png', 'image_1102.png', 'image_1103.png', 'image_1104.png', 'image_1105.png', 'image_1106.png', 'image_1107.png', 'image_1108.png', 'image_1109.png', 'image_111.png', 'image_1110.png', 'image_1111.png', 'image_1112.png', 'image_1113.png', 'image_1114.png', 'image_1115.png', 'image_1116.png', 'image_1117.png', 'image_1118.png', 'image_1119.png', 'image_112.png', 'image_1120.png', 'image_1121.png', 'image_1122.png', 'image_1123.png', 'image_1124.png', 'image_1125.png', 'image_1126.png', 'image_1127.png', 'image_1128.png', 'image_1129.png', 'image_113.png', 'image_1130.png', 'image_1131.png', 'image_1132.png', 'image_1133.png', 'image_1134.png', 'image_1135.png', 'image_1136.png', 'image_1137.png', 'image_1138.png', 'image_1139.png', 'image_114.png', 'image_1140.png', 'image_1141.png', 'image_1142.png', 'image_1143.png', 'image_1144.png', 'image_1145.png', 'image_1146.png', 'image_1147.png', 'image_1148.png', 'image_1149.png', 'image_115.png', 'image_1150.png', 'image_1151.png', 'image_1152.png', 'image_1153.png', 'image_1154.png', 'image_1155.png', 'image_1156.png', 'image_1157.png', 'image_1158.png', 'image_1159.png', 'image_116.png', 'image_1160.png', 'image_1161.png', 'image_1162.png', 'image_1163.png', 'image_1164.png', 'image_1165.png', 'image_1166.png', 'image_1167.png', 'image_1168.png', 'image_1169.png', 'image_117.png', 'image_1170.png', 'image_1171.png', 'image_1172.png', 'image_1173.png', 'image_1174.png', 'image_1175.png', 'image_1176.png', 'image_1177.png', 'image_1178.png', 'image_1179.png', 'image_118.png', 'image_1180.png', 'image_1181.png', 'image_1182.png', 'image_1183.png', 'image_1184.png', 'image_1185.png', 'image_1186.png', 'image_1187.png', 'image_1188.png', 'image_1189.png', 'image_119.png', 'image_1190.png', 'image_1191.png', 'image_1192.png', 'image_11 ...
# ['mask_01.png', 'mask_02.png', 'mask_03.png', 'mask_04.png', 'mask_05.png', 'mask_06.png', 'mask_07.png', 'mask_08.png', 'mask_09.png', 'mask_10.png', 'mask_100.png', 'mask_1000.png', 'mask_1001.png', 'mask_1002.png', 'mask_1003.png', 'mask_1004.png', 'mask_1005.png', 'mask_1006.png', 'mask_1007.png', 'mask_1008.png', 'mask_1009.png', 'mask_101.png', 'mask_1010.png', 'mask_1011.png', 'mask_1012.png', 'mask_1013.png', 'mask_1014.png', 'mask_1015.png', 'mask_1016.png', 'mask_1017.png', 'mask_1018.png', 'mask_1019.png', 'mask_102.png', 'mask_1020.png', 'mask_1021.png', 'mask_1022.png', 'mask_1023.png', 'mask_1024.png', 'mask_1025.png', 'mask_1026.png', 'mask_1027.png', 'mask_1028.png', 'mask_1029.png', 'mask_103.png', 'mask_1030.png', 'mask_1031.png', 'mask_1032.png', 'mask_1033.png', 'mask_1034.png', 'mask_1035.png', 'mask_1036.png', 'mask_1037.png', 'mask_1038.png', 'mask_1039.png', 'mask_104.png', 'mask_1040.png', 'mask_1041.png', 'mask_1042.png', 'mask_1043.png', 'mask_1044.png', 'mask_1045.png', 'mask_1046.png', 'mask_1047.png', 'mask_1048.png', 'mask_1049.png', 'mask_105.png', 'mask_1050.png', 'mask_1051.png', 'mask_1052.png', 'mask_1053.png', 'mask_1054.png', 'mask_1055.png', 'mask_1056.png', 'mask_1057.png', 'mask_1058.png', 'mask_1059.png', 'mask_106.png', 'mask_1060.png', 'mask_1061.png', 'mask_1062.png', 'mask_1063.png', 'mask_1064.png', 'mask_1065.png', 'mask_1066.png', 'mask_1067.png', 'mask_1068.png', 'mask_1069.png', 'mask_107.png', 'mask_1070.png', 'mask_1071.png', 'mask_1072.png', 'mask_1073.png', 'mask_1074.png', 'mask_1075.png', 'mask_1076.png', 'mask_1077.png', 'mask_1078.png', 'mask_1079.png', 'mask_108.png', 'mask_1080.png', 'mask_1081.png', 'mask_1082.png', 'mask_1083.png', 'mask_1084.png', 'mask_1085.png', 'mask_1086.png', 'mask_1087.png', 'mask_1088.png', 'mask_1089.png', 'mask_109.png', 'mask_1090.png', 'mask_1091.png', 'mask_1092.png', 'mask_1093.png', 'mask_1094.png', 'mask_1095.png', 'mask_1096.png', 'mask_1097.png', 'mask_1098.png', 'mask_1099.png', 'mask_11.png', 'mask_110.png', 'mask_1100.png', 'mask_1101.png', 'mask_1102.png', 'mask_1103.png', 'mask_1104.png', 'mask_1105.png', 'mask_1106.png', 'mask_1107.png', 'mask_1108.png', 'mask_1109.png', 'mask_111.png', 'mask_1110.png', 'mask_1111.png', 'mask_1112.png', 'mask_1113.png', 'mask_1114.png', 'mask_1115.png', 'mask_1116.png', 'mask_1117.png', 'mask_1118.png', 'mask_1119.png', 'mask_112.png', 'mask_1120.png', 'mask_1121.png', 'mask_1122.png', 'mask_1123.png', 'mask_1124.png', 'mask_1125.png', 'mask_1126.png', 'mask_1127.png', 'mask_1128.png', 'mask_1129.png', 'mask_113.png', 'mask_1130.png', 'mask_1131.png', 'mask_1132.png', 'mask_1133.png', 'mask_1134.png', 'mask_1135.png', 'mask_1136.png', 'mask_1137.png', 'mask_1138.png', 'mask_1139.png', 'mask_114.png', 'mask_1140.png', 'mask_1141.png', 'mask_1142.png', 'mask_1143.png', 'mask_1144.png', 'mask_1145.png', 'mask_1146.png', 'mask_1147.png', 'mask_1148.png', 'mask_1149.png', 'mask_115.png', 'mask_1150.png', 'mask_1151.png', 'mask_1152.png', 'mask_1153.png', 'mask_1154.png', 'mask_1155.png', 'mask_1156.png', 'mask_1157.png', 'mask_1158.png', 'mask_1159.png', 'mask_116.png', 'mask_1160.png', 'mask_1161.png', 'mask_1162.png', 'mask_1163.png', 'mask_1164.png', 'mask_1165.png', 'mask_1166.png', 'mask_1167.png', 'mask_1168.png', 'mask_1169.png', 'mask_117.png', 'mask_1170.png', 'mask_1171.png', 'mask_1172.png', 'mask_1173.png', 'mask_1174.png', 'mask_1175.png', 'mask_1176.png', 'mask_1177.png', 'mask_1178.png', 'mask_1179.png', 'mask_118.png', 'mask_1180.png', 'mask_1181.png', 'mask_1182.png', 'mask_1183.png', 'mask_1184.png', 'mask_1185.png', 'mask_1186.png', 'mask_1187.png', 'mask_1188.png', 'mask_1189.png', 'mask_119.png', 'mask_1190.png', 'mask_1191.png', 'mask_1192.png', 'mask_1193.png', 'mask_1194.png', 'mask_1195.png', 'mask_1196.png', 'mask_1197.png', 'mask_1198.png', 'mask_1199.png', 'mask_12.png', 'mask_120.png', 'mask_1200.png', 'mask_121.png', 'mask_122.png', 'mask_123.png', 'mask_124.png', 'm ...
#
# Validation Set:
# ['image_1201.png', 'image_1202.png', 'image_1203.png', 'image_1204.png', 'image_1205.png', 'image_1206.png', 'image_1207.png', 'image_1208.png', 'image_1209.png', 'image_1210.png', 'image_1211.png', 'image_1212.png', 'image_1213.png', 'image_1214.png', 'image_1215.png', 'image_1216.png', 'image_1217.png', 'image_1218.png', 'image_1219.png', 'image_1220.png', 'image_1221.png', 'image_1222.png', 'image_1223.png', 'image_1224.png', 'image_1225.png', 'image_1226.png', 'image_1227.png', 'image_1228.png', 'image_1229.png', 'image_1230.png', 'image_1231.png', 'image_1232.png', 'image_1233.png', 'image_1234.png', 'image_1235.png', 'image_1236.png', 'image_1237.png', 'image_1238.png', 'image_1239.png', 'image_1240.png', 'image_1241.png', 'image_1242.png', 'image_1243.png', 'image_1244.png', 'image_1245.png', 'image_1246.png', 'image_1247.png', 'image_1248.png', 'image_1249.png', 'image_1250.png', 'image_1251.png', 'image_1252.png', 'image_1253.png', 'image_1254.png', 'image_1255.png', 'image_1256.png', 'image_1257.png', 'image_1258.png', 'image_1259.png', 'image_1260.png', 'image_1261.png', 'image_1262.png', 'image_1263.png', 'image_1264.png', 'image_1265.png', 'image_1266.png', 'image_1267.png', 'image_1268.png', 'image_1269.png', 'image_1270.png', 'image_1271.png', 'image_1272.png', 'image_1273.png', 'image_1274.png', 'image_1275.png', 'image_1276.png', 'image_1277.png', 'image_1278.png', 'image_1279.png', 'image_1280.png', 'image_1281.png', 'image_1282.png', 'image_1283.png', 'image_1284.png', 'image_1285.png', 'image_1286.png', 'image_1287.png', 'image_1288.png', 'image_1289.png', 'image_1290.png', 'image_1291.png', 'image_1292.png', 'image_1293.png', 'image_1294.png', 'image_1295.png', 'image_1296.png', 'image_1297.png', 'image_1298.png', 'image_1299.png', 'image_1300.png', 'image_1301.png', 'image_1302.png', 'image_1303.png', 'image_1304.png', 'image_1305.png', 'image_1306.png', 'image_1307.png', 'image_1308.png', 'image_1309.png', 'image_1310.png', 'image_1311.png', 'image_1312.png', 'image_1313.png', 'image_1314.png', 'image_1315.png', 'image_1316.png', 'image_1317.png', 'image_1318.png', 'image_1319.png', 'image_1320.png', 'image_1321.png', 'image_1322.png', 'image_1323.png', 'image_1324.png', 'image_1325.png', 'image_1326.png', 'image_1327.png', 'image_1328.png', 'image_1329.png', 'image_1330.png', 'image_1331.png', 'image_1332.png', 'image_1333.png', 'image_1334.png', 'image_1335.png', 'image_1336.png', 'image_1337.png', 'image_1338.png', 'image_1339.png', 'image_1340.png', 'image_1341.png', 'image_1342.png', 'image_1343.png', 'image_1344.png', 'image_1345.png', 'image_1346.png', 'image_1347.png', 'image_1348.png', 'image_1349.png', 'image_1350.png', 'image_1351.png', 'image_1352.png', 'image_1353.png', 'image_1354.png', 'image_1355.png', 'image_1356.png', 'image_1357.png', 'image_1358.png', 'image_1359.png', 'image_1360.png', 'image_1361.png', 'image_1362.png', 'image_1363.png', 'image_1364.png', 'image_1365.png', 'image_1366.png', 'image_1367.png', 'image_1368.png', 'image_1369.png', 'image_1370.png', 'image_1371.png', 'image_1372.png', 'image_1373.png', 'image_1374.png', 'image_1375.png', 'image_1376.png', 'image_1377.png']
# ['mask_1201.png', 'mask_1202.png', 'mask_1203.png', 'mask_1204.png', 'mask_1205.png', 'mask_1206.png', 'mask_1207.png', 'mask_1208.png', 'mask_1209.png', 'mask_1210.png', 'mask_1211.png', 'mask_1212.png', 'mask_1213.png', 'mask_1214.png', 'mask_1215.png', 'mask_1216.png', 'mask_1217.png', 'mask_1218.png', 'mask_1219.png', 'mask_1220.png', 'mask_1221.png', 'mask_1222.png', 'mask_1223.png', 'mask_1224.png', 'mask_1225.png', 'mask_1226.png', 'mask_1227.png', 'mask_1228.png', 'mask_1229.png', 'mask_1230.png', 'mask_1231.png', 'mask_1232.png', 'mask_1233.png', 'mask_1234.png', 'mask_1235.png', 'mask_1236.png', 'mask_1237.png', 'mask_1238.png', 'mask_1239.png', 'mask_1240.png', 'mask_1241.png', 'mask_1242.png', 'mask_1243.png', 'mask_1244.png', 'mask_1245.png', 'mask_1246.png', 'mask_1247.png', 'mask_1248.png', 'mask_1249.png', 'mask_1250.png', 'mask_1251.png', 'mask_1252.png', 'mask_1253.png', 'mask_1254.png', 'mask_1255.png', 'mask_1256.png', 'mask_1257.png', 'mask_1258.png', 'mask_1259.png', 'mask_1260.png', 'mask_1261.png', 'mask_1262.png', 'mask_1263.png', 'mask_1264.png', 'mask_1265.png', 'mask_1266.png', 'mask_1267.png', 'mask_1268.png', 'mask_1269.png', 'mask_1270.png', 'mask_1271.png', 'mask_1272.png', 'mask_1273.png', 'mask_1274.png', 'mask_1275.png', 'mask_1276.png', 'mask_1277.png', 'mask_1278.png', 'mask_1279.png', 'mask_1280.png', 'mask_1281.png', 'mask_1282.png', 'mask_1283.png', 'mask_1284.png', 'mask_1285.png', 'mask_1286.png', 'mask_1287.png', 'mask_1288.png', 'mask_1289.png', 'mask_1290.png', 'mask_1291.png', 'mask_1292.png', 'mask_1293.png', 'mask_1294.png', 'mask_1295.png', 'mask_1296.png', 'mask_1297.png', 'mask_1298.png', 'mask_1299.png', 'mask_1300.png', 'mask_1301.png', 'mask_1302.png', 'mask_1303.png', 'mask_1304.png', 'mask_1305.png', 'mask_1306.png', 'mask_1307.png', 'mask_1308.png', 'mask_1309.png', 'mask_1310.png', 'mask_1311.png', 'mask_1312.png', 'mask_1313.png', 'mask_1314.png', 'mask_1315.png', 'mask_1316.png', 'mask_1317.png', 'mask_1318.png', 'mask_1319.png', 'mask_1320.png', 'mask_1321.png', 'mask_1322.png', 'mask_1323.png', 'mask_1324.png', 'mask_1325.png', 'mask_1326.png', 'mask_1327.png', 'mask_1328.png', 'mask_1329.png', 'mask_1330.png', 'mask_1331.png', 'mask_1332.png', 'mask_1333.png', 'mask_1334.png', 'mask_1335.png', 'mask_1336.png', 'mask_1337.png', 'mask_1338.png', 'mask_1339.png', 'mask_1340.png', 'mask_1341.png', 'mask_1342.png', 'mask_1343.png', 'mask_1344.png', 'mask_1345.png', 'mask_1346.png', 'mask_1347.png', 'mask_1348.png', 'mask_1349.png', 'mask_1350.png', 'mask_1351.png', 'mask_1352.png', 'mask_1353.png', 'mask_1354.png', 'mask_1355.png', 'mask_1356.png', 'mask_1357.png', 'mask_1358.png', 'mask_1359.png', 'mask_1360.png', 'mask_1361.png', 'mask_1362.png', 'mask_1363.png', 'mask_1364.png', 'mask_1365.png', 'mask_1366.png', 'mask_1367.png', 'mask_1368.png', 'mask_1369.png', 'mask_1370.png', 'mask_1371.png', 'mask_1372.png', 'mask_1373.png', 'mask_1374.png', 'mask_1375.png', 'mask_1376.png', 'mask_1377.png']

# %% [markdown]
# Creating folders to store models and predicted masks that are downloaded later.

# %%
if not os.path.exists('../models/'):
  os.makedirs('../models/')

if not os.path.exists('../predictions/'):
  os.makedirs('../predictions/')

# %% [markdown]
# # Creation of Custom Dataset
#
# * __init__ takes the directories of images and masks as well as transformations that are applied onto them, then sorts the images and masks by names so they are aligned with each other as expected.
#
# * __len__ returns the total number of images in the dataset.
#
# * __getitem__ takes a pair of image and mask specified by index from given directories. Both the image and mask are opened as images, transformed into arrays and then converted to type of *float32* to ensure they work with the UNet model architecture. Finally, the same transformation is applied on both the image and the mask and this pair gets returned.

# %%
class CustomDataset(Dataset):
  def __init__(self,image_dir, mask_dir, transform):
    self.image_dir = image_dir
    self.mask_dir = mask_dir
    self.transform = transform

    self.image_paths = sorted(os.listdir(image_dir))
    self.mask_paths = sorted(os.listdir(mask_dir))

  def __len__(self):
    return len(self.image_paths)

  def __getitem__(self, index):
    image_path = os.path.join(self.image_dir, self.image_paths[index])
    mask_path = os.path.join(self.mask_dir, self.mask_paths[index])

    image = np.array(Image.open(image_path).convert('RGB')).astype(np.float32)
    mask = np.array(Image.open(mask_path).convert('L')).astype(bool).astype(np.float32)

    transformed = self.transform(image = image, mask = mask)

    return transformed['image'], transformed['mask']

# %% [markdown]
# # Transformations for both Training and Validation
#
# Transformations for both training and validation datasets are described.
#
# They differ as images in the validation dataset must only be resized to expected size, normalized and converted to tensor type.
#
# Other augmentations are not applied to keep the image as close to the actual input as possible .

# %%
# Set of transformations for training set
train_transform = alb.Compose([alb.Resize(height = 224, width = 224),
                               alb.Rotate(limit = 10, p = 0.5),
                               alb.HorizontalFlip(p = 0.5),
                               alb.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225], max_pixel_value=255.0),
                               ToTensorV2()])

# Set of transformations for validation set
validation_transform = alb.Compose([alb.Resize(height = 224, width = 224),
                                    alb.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225], max_pixel_value=255.0),
                                    ToTensorV2()])

# %% [markdown]
# # Model based on UNet Architecture

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Generally used to deepen the neural network for better performance
class DoubleConvolution(nn.Module):
  def __init__(self, in_channels, out_channels):
    super().__init__()

    # Double convolution as a sequence of operations applied to data
    self.double_conv = nn.Sequential(nn.Conv2d(in_channels, out_channels, kernel_size = 3, padding = 1), # 2D convolution
                                     nn.BatchNorm2d(out_channels), # Batch normalization
                                     nn.ReLU(inplace = True), # The original input is modified instead of creating a new tensor
                                     nn.Conv2d(out_channels, out_channels, kernel_size = 3, padding = 1), # 2D convolution
                                     nn.BatchNorm2d(out_channels), # Batch normalization
                                     nn.ReLU(inplace = True)) # The original input is modified instead of creating a new tensor

  def forward(self, x):
    return self.double_conv(x)

# Used to reduce the dimensions of input feature maps and increase receptive field
class DownSample(nn.Module):
  def __init__(self, in_channels, out_channels):
    super().__init__()

    # Performs max pooling and double convolution on reduced feature maps while increasing channels
    self.maxpool_conv = nn.Sequential(nn.MaxPool2d(2), DoubleConvolution(in_channels, out_channels))

  def forward(self, x):
    return self.maxpool_conv(x)

# Used to increase the dimensions of the downsampled feature maps
class UpSample(nn.Module):
  def __init__(self, in_channels, out_channels):
    super().__init__()

    # Used to increase the spatial dimensions of feature maps while decreasing the number of channels
    # The feature map grows twice each time because of kernel_size and stride but the channels get reduced
    self.up = nn.ConvTranspose2d(in_channels, in_channels // 2, kernel_size = 2, stride = 2)
    self.conv = DoubleConvolution(in_channels, out_channels)

  def forward(self, x1, x2):
    x1 = self.up(x1)

    # x2 is cropped to match the dimensions of x1
    # shape[1] is the number of channels, shape[2] is for height, shape[3] is for width
    x2 = F.center_crop(x2, [x1.shape[2], x1.shape[3]])

    # Combines both feature maps to preserve both deep and shallow level details, concatenated horizontally
    x1 = torch.cat([x2, x1], dim = 1)

    return self.conv(x1)

class UNet(nn.Module):
  def __init__(self, in_channels, out_channels):
    super(UNet, self).__init__()
    self.inc = (DoubleConvolution(in_channels, 64))
    self.down1 = (DownSample(64, 128))
    self.down2 = (DownSample(128, 256))
    self.down3 = (DownSample(256, 512))
    self.down4 = (DownSample(512, 1024))
    self.up1 = (UpSample(1024, 512))
    self.up2 = (UpSample(512, 256))
    self.up3 = (UpSample(256, 128))
    self.up4 = (UpSample(128, 64))
    # Used to decrease the number of channels so the kernel_size is 1
    self.outc = nn.Conv2d(64, out_channels, kernel_size = 1)

  def forward(self, x):
    x1 = self.inc(x)
    x2 = self.down1(x1)
    x3 = self.down2(x2)
    x4 = self.down3(x3)
    x5 = self.down4(x4)
    x = self.up1(x5, x4)
    x = self.up2(x, x3)
    x = self.up3(x, x2)
    x = self.up4(x, x1)
    logits = self.outc(x)
    return logits

# %% [markdown]
# # Initialization of Device
#
# Recommended to use GPU *(cuda:0)* for optimal performance.

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Used device type is', device)
# Out:
# Used device type is cuda:0

# %% [markdown]
# # Calculation of Statistics
#
# **Intersection over Union (IoU)**
#
# > $\text{IoU} = \frac{|A \cap B|}{|A \cup B|}$
#
# * Measures the overlap between two sets divided by their union.
# * Ranges from 0 to 1, where 0 indicates no overlap and 1 indicates perfect overlap.
# * Direct measure of overlapping.
# * Also known as Jaccard Index.
#
#
# **Dice**
#
# > $\text{Dice} = \frac{2|A \cap B|}{|A| + |B|}$
#
# * Measures the overlap between two sets.
# * Ranges from 0 to 1, where 0 indicates no overlap and 1 indicates perfect overlap.
# * Dice emphasizes the overlap between two sets more strongly because there is a 2 in the numerator, making it more sensitive to overlaps.
# * Practically the same as F1 score in the context of binary classification.

# %%
# Smooth is a small value that has litle impact, used to prevent division by zero

def iou(predictions, targets):
  smooth = 0.00001
  intersection = torch.sum(predictions * targets)
  union = torch.sum(predictions) + torch.sum(targets) - intersection
  iou = (intersection + smooth) / (union + smooth)
  return iou

def dice_coefficient(predictions, targets):
  smooth = 0.00001
  intersection = torch.sum(predictions * targets)
  union = torch.sum(predictions) + torch.sum(targets)
  dice = (2.0 * intersection + smooth) / (union + smooth)
  return dice

# %% [markdown]
# Used to calculate IoU and Dice using evaluation mode of the model.

# %%
def calculate_statistics(loader, model, threshold):
  dice_total = 0
  iou_total = 0
  all_predictions = []
  all_targets = []

  # Setting the model to evaluation mode
  model.eval()

  with torch.no_grad():
    for x, y in loader:
      # x is for the image, y is for the mask
      x = x.to(device)
      y = y.to(device).unsqueeze(1)

      # Sigmoid is used as it is a binary classification task
      predictions = torch.sigmoid(model(x))
      # Threshold is applied
      predictions = (predictions > threshold).float()

      # Calculating Dice and IoU
      dice_total += dice_coefficient(predictions, y).item()
      iou_total += iou(predictions, y).item()

      all_predictions.extend(predictions.cpu().numpy().flatten())
      all_targets.extend(y.cpu().numpy().flatten())

  dice = dice_total / len(loader)
  mean_iou = iou_total / len(loader)

  print(f"Dice: {dice:.4f}")
  print(f"IoU: {mean_iou:.4f}")

  # Setting the model back to training mode
  model.train()

  return dice, mean_iou

# %% [markdown]
# # Saving Predictions as Images
#
# In order to keep the document as concise as possible, images are saved to folder *predictions* instead of displaying them in the file.
#
# Each threshold has a dedicated folder so the list of folders inside predictions should go as follows:
#
# *   predictions/threshold_0.1
# *   predictions/threshold_0.2
# *   predictions/threshold_0.3
# *   predictions/threshold_0.4
# *   predictions/threshold_0.5
# *   predictions/threshold_0.6
# *   predictions/threshold_0.7
# *   predictions/threshold_0.8
# *   predictions/threshold_0.9
#
# In each folder, two groups of files are present:
#
# *   $x$.png, where $x$ is a number of the given (expected) mask set.
# *   $predicted\_x$.png, where $x$ is a number of the predicted mask set.
# *   So, for example, *1.png* is the set of expected masks for the first 16 images in the validation set, while *predicted_1.png* is the prediction of the model for these 16 images.
#
# Each image file should contain 16 images as it is the size of the loader.

# %%
def save_predictions_as_imgs(loader, model, folder, threshold):
  # Setting the model to evaluation mode
  model.eval()

  # x is for the image, y is for the mask
  for index, (x, y) in enumerate(loader):

    # Passing the image to device
    x = x.to(device)

    with torch.no_grad():

      # Sigmoid is used as it is a binary classification task
      predictions = torch.sigmoid(model(x))

      # Threshold is applied
      predictions = (predictions > threshold).float()

    # Saving both predicted and original masks so they can be compared later
    torchvision.utils.save_image(predictions, f"{folder}/predicted_{index}.png")
    torchvision.utils.save_image(y.unsqueeze(1), f"{folder}{index}.png")

  # Setting the model back to training mode
  model.train()

# %% [markdown]
# # Training Functions

# %% [markdown]
# Used to calculate validation loss.

# %%
def calculate_validation_loss(loader, model, loss_function):
  model.eval()
  val_losses = []

  with torch.no_grad():
    for x, y in loader:
      x = x.to(device)
      y = y.to(device).unsqueeze(1)

      predictions = model(x)
      loss = loss_function(predictions, y)
      val_losses.append(loss.item())

  avg_val_loss = sum(val_losses) / len(val_losses)

  return avg_val_loss

# %% [markdown]
# Used to train a single epoch.

# %%
def training_function(loader, model, optimizer, loss_function, scaler):
  model.train()
  train_losses = []

  for _, (data, targets) in enumerate(loader):
    data = data.to(device)
    targets = targets.float().unsqueeze(1).to(device)

    # Enables automatic casting to improve performance
    with torch.cuda.amp.autocast():
      predictions = model(data)
      # Calculates loss
      loss = loss_function(predictions, targets)

    # Clears gradients
    optimizer.zero_grad()
    # Scales the loss and computes the gradient of the loss
    scaler.scale(loss).backward()
    # Updates model parameters based on the calculated gradients
    scaler.step(optimizer)
    # Updates the scaler for the next iteration
    scaler.update()

    train_losses.append(loss.item())

  avg_train_loss = sum(train_losses) / len(train_losses)

  return avg_train_loss

# %% [markdown]
# The main training loop for all epochs.

# %%
def train_model(number_of_epochs, lr, model, threshold):
  loss_function = nn.BCEWithLogitsLoss() # Loss function specifically for binary segmentation
  optimizer = optim.Adam(model.parameters(), lr = lr)

  # Creating datasets and dataloaders
  train_dataset = CustomDataset(image_dir = train_image_dir, mask_dir = train_mask_dir, transform = train_transform)
  train_dataloader = DataLoader(train_dataset, batch_size = 16, shuffle = True)

  validation_dataset = CustomDataset(image_dir = validation_image_dir, mask_dir = validation_mask_dir, transform = validation_transform)
  validation_dataloader = DataLoader(validation_dataset, batch_size = 16, shuffle = False)

  scaler = torch.cuda.amp.GradScaler()

  train_losses = []
  validation_losses = []
  dice_scores = []
  mean_iou_scores = []
  epoch_times = []

  # Starting the timer to calculate total training time for a threshold
  total_start_time = time.time()

  for epoch in range(number_of_epochs):
    print(f"- EPOCH {epoch + 1} -")

    # Starting the timer to calculate training time for an epoch
    start_time = time.time()

    # Training the model
    train_loss = training_function(train_dataloader, model, optimizer, loss_function, scaler)
    train_losses.append(train_loss)

    # Calculating validation loss
    validation_loss = calculate_validation_loss(validation_dataloader, model, loss_function)
    validation_losses.append(validation_loss)

    # Calculating Dice and IoU
    dice, mean_iou = calculate_statistics(validation_dataloader, model, threshold)
    dice_scores.append(dice)
    mean_iou_scores.append(mean_iou)

    # Stopping the timer to calculate duration of training time for an epoch
    end_time = time.time()
    epoch_duration = end_time - start_time
    epoch_times.append(epoch_duration)

    # Converting seconds to more appropriate units of time
    hours, rem = divmod(epoch_duration, 3600)
    minutes, seconds = divmod(rem, 60)
    duration_str = f"{int(hours):02}:{int(minutes):02}:{int(seconds):02}"

    # Printing results for the epoch
    print("Training Loss:", train_loss)
    print("Validation Loss:", validation_loss)
    print("Epoch Training Duration:", duration_str)
    print()

    # Creating a folder to save predictions if it does not yet exist
    threshold_dir = f"../predictions/threshold_{threshold}/"
    if not os.path.exists(threshold_dir):
      os.makedirs(threshold_dir)

    # Saving these predictions in the folder
    save_predictions_as_imgs(validation_dataloader, model, threshold_dir, threshold)

    # If it is the last epoch
    if epoch == (number_of_epochs - 1):

      # Stopping the timer to calculate duration of total training time for a threshold
      total_end_time = time.time()
      total_duration = total_end_time - total_start_time

      # Converting seconds to more appropriate units of time
      total_hours, total_rem = divmod(total_duration, 3600)
      total_minutes, total_seconds = divmod(total_rem, 60)
      total_duration_str = f"{int(total_hours):02}:{int(total_minutes):02}:{int(total_seconds):02}"

      print(f"Total Training Duration for Threshold {threshold}:", total_duration_str)
      print()

      # Returning all of the relevant data to plot it later
      return train_losses, validation_losses, dice_scores, mean_iou_scores

# %% [markdown]
# # Training Cycle for each Threshold

# %% [markdown]
# Training parameters.

# %%
# Learning rate
lr = 0.001
number_of_epochs = 50

# Background threshold, goes from 0.1 to 0.9 with step of 0.1
thresholds = np.linspace(0.1, 0.9, num = 9)
thresholds = np.round(thresholds, 1)

# %% [markdown]
# Training loop.

# %%
# Dictionaries to store data for each threshold
all_dice_scores = {}
all_mean_iou_scores = {}
all_train_losses = {}
all_validation_losses = {}

# Training for each threshold
for index, threshold in enumerate(thresholds, start = 1):
  print(f'-- TRAINING WITH THRESHOLD OF {threshold:.1f} -- ')
  print()

  # Creating the model
  model = UNet(in_channels = 3, out_channels = 1).to(device)

  # Training the model
  train_losses, validation_losses, dice, mean_iou = train_model(number_of_epochs, lr, model, threshold)

  # Saving the model to a file
  torch.save(model.state_dict(), f'../models/UNet_Threshold_{threshold}.pth')

  # Adding the statistics for each threshold
  all_dice_scores[threshold] = dice
  all_mean_iou_scores[threshold] = mean_iou
  all_train_losses[threshold] = train_losses
  all_validation_losses[threshold] = validation_losses
# Out:
# -- TRAINING WITH THRESHOLD OF 0.1 --
#
# - EPOCH 1 -
# Dice: 0.5976
# IoU: 0.4301
# Training Loss: 0.35108038504918415
# Validation Loss: 0.21142229220519462
# Epoch Training Duration: 00:12:38
#
# - EPOCH 2 -
# Dice: 0.5091
# IoU: 0.3473
# Training Loss: 0.278939399321874
# Validation Loss: 0.22112812971075377
# Epoch Training Duration: 00:00:48
#
# - EPOCH 3 -
# Dice: 0.6135
# IoU: 0.4473
# Training Loss: 0.2687609406312307
# Validation Loss: 0.19881297570342818
# Epoch Training Duration: 00:00:48
#
# - EPOCH 4 -
# Dice: 0.4011
# IoU: 0.2587
# Training Loss: 0.2629616924126943
# Validation Loss: 0.2689101764311393
# Epoch Training Duration: 00:00:48
#
# - EPOCH 5 -
# Dice: 0.5984
# IoU: 0.4311
# Training Loss: 0.25941106577714285
# Validation Loss: 0.19037044405316314
# Epoch Training Duration: 00:00:49
#
# - EPOCH 6 -
# Dice: 0.5121
# IoU: 0.3482
# Training Loss: 0.2528874917825063
# Validation Loss: 0.20157554668063918
# Epoch Training Duration: 00:00:50
#
# - EPOCH 7 -
# Dice: 0.5633
# IoU: 0.3968
# Training Loss: 0.26042913595835365
# Validation Loss: 0.2015487610672911
# Epoch Training Duration: 00:00:49
#
# - EPOCH 8 -
# Dice: 0.5658
# IoU: 0.4004
# Training Loss: 0.2488747888803482
# Validation Loss: 0.20314952731132507
# Epoch Training Duration: 00:00:48
#
# - EPOCH 9 -
# Dice: 0.6205
# IoU: 0.4557
# Training Loss: 0.24478019018967948
# Validation Loss: 0.19498265348374844
# Epoch Training Duration: 00:00:48
#
# - EPOCH 10 -
# Dice: 0.6528
# IoU: 0.4916
# Training Loss: 0.24100817422072093
# Validation Loss: 0.19120008933047453
# Epoch Training Duration: 00:00:48
#
# - EPOCH 11 -
# Dice: 0.6094
# IoU: 0.4438
# Training Loss: 0.23734335780143737
# Validation Loss: 0.18975816294550896
# Epoch Training Duration: 00:00:49
#
# - EPOCH 12 -
# Dice: 0.6578
# IoU: 0.4963
# Training Loss: 0.23417148808638255
# Validation Loss: 0.19398753376056752
# Epoch Training Duration: 00:00:49
#
# - EPOCH 13 -
# Dice: 0.5912
# IoU: 0.4244
# Training Loss: 0.2308461574713389
# Validation Loss: 0.19292365682000914
# Epoch Training Duration: 00:00:49
#
# - EPOCH 14 -
# Dice: 0.5478
# IoU: 0.3817
# Training Loss: 0.2294537446896235
# Validation Loss: 0.19879927905276418
# Epoch Training Duration: 00:00:49
#
# - EPOCH 15 -
# Dice: 0.5635
# IoU: 0.3960
# Training Loss: 0.22650893191496532
# Validation Loss: 0.20196594344452024
# Epoch Training Duration: 00:00:49
#
# - EPOCH 16 -
# Dice: 0.6763
# IoU: 0.5184
# Training Loss: 0.22277265071868896
# Validation Loss: 0.18950235238298774
# Epoch Training Duration: 00:00:49
#
# - EPOCH 17 -
# Dice: 0.6453
# IoU: 0.4826
# Training Loss: 0.21944088538487752
# Validation Loss: 0.18485718530913195
# Epoch Training Duration: 00:00:48
#
# - EPOCH 18 -
# Dice: 0.5528
# IoU: 0.3864
# Training Loss: 0.2177512260278066
# Validation Loss: 0.19265178234005967
# Epoch Training Duration: 00:00:48
#
# - EPOCH 19 -
# Dice: 0.6520
# IoU: 0.4901
# Training Loss: 0.2170289788643519
# Validation Loss: 0.18080031607920924
# Epoch Training Duration: 00:00:48
#
# - EPOCH 20 -
# Dice: 0.5688
# IoU: 0.4015
# Training Loss: 0.21623193860054016
# Validation Loss: 0.1955460992952188
# Epoch Training Duration: 00:00:48
#
# - EPOCH 21 -
# Dice: 0.6860
# IoU: 0.5304
# Training Loss: 0.2194407268365224
# Validation Loss: 0.1771144454057018
# Epoch Training Duration: 00:00:48
#
# - EPOCH 22 -
# Dice: 0.6176
# IoU: 0.4521
# Training Loss: 0.21499901096026103
# Validation Loss: 0.18571413572256765
# Epoch Training Duration: 00:00:49
#
# - EPOCH 23 -
# Dice: 0.6630
# IoU: 0.5028
# Training Loss: 0.20944497883319854
# Validation Loss: 0.18346983256439367
# Epoch Training Duration: 00:00:49
#
# - EPOCH 24 -
# Dice: 0.6465
# IoU: 0.4836
# Training Loss: 0.2100522357225418
# Validation Loss: 0.1810523954530557
# Epoch Training Duration: 00:00:49
#
# - EPOCH 25 -
# Dice: 0.6744
# IoU: 0.5180
# Training Loss: 0.20611687044302623
# Validation Loss: 0.18159892161687216
# Epoch Training Duration: 00:00:49
#
# - EPOCH 26 -
# Dice: 0.6865
# IoU: 0.5312
# Training Loss: 0.20591525236765543
# Validation Loss: 0.19023822302309176
# Epoch Training Duration: 00:00:49
#
# - EPOCH 27 -
# Dice: 0.6649
# IoU: 0.5050
# Training Loss: 0.206532701253891
# Validation Loss: 0.17822080617770553
# Epoch Training Duration: 00:00:48
#
# - EPOCH 28 -
# Dice: 0.6839
# IoU: 0.5287
# Training Loss: 0.2023594105243683
# Validation Loss: 0.19252636019761363
# Epoch Training Duration: 00:00:48
#
# - EPOCH 29 -
# Dice: 0.6849
# IoU: 0.5304
# Training Loss: 0.2014676797389984
# Validation Loss: 0.1860097434061269
# Epoch Training Duration: 00:00:49
#
# - EPOCH 30 -
# Dice: 0.6912
# IoU: 0.5365
# Training Loss: 0.19861671229203542
# Validation Loss: 0.1855493693922957
# Epoch Training Duration: 00:00:48
#
# - EPOCH 31 -
# Dice: 0.6585
# IoU: 0.4975
# Training Loss: 0.1960127015908559
# Validation Loss: 0.17960499847928682
# Epoch Training Duration: 00:00:49
#
# - EPOCH 32 -
# Dice: 0.6675
# IoU: 0.5092
# Training Loss: 0.19584814170996348
# Validation Loss: 0.18616033205762506
# Epoch Training Duration: 00:00:49
#
# - EPOCH 33 -
# Dice: 0.6704
# IoU: 0.5117
# Training Loss: 0.2003179395198822
# Validation Loss: 0.1802262452741464
# Epoch Training Duration: 00:00:49
#
# - EPOCH 34 -
# Dice: 0.6737
# IoU: 0.5166
# Training Loss: 0.20489540020624797
# Validation Loss: 0.18511946204428872
# Epoch Training Duration: 00:00:49
#
# - EPOCH 35 -
# Dice: 0.6919
# IoU: 0.5377
# Training Loss: 0.19759516616662343
# Validation Loss: 0.18421804656585059
# Epoch Training Duration: 00:00:49
#
# - EPOCH 36 -
# Dice: 0.6770
# IoU: 0.5217
# Training Loss: 0.1944372812906901
# Validation Loss: 0.1883350012358278
# Epoch Training Duration: 00:00:49
#
# - EPOCH 37 -
# Dice: 0.6466
# IoU: 0.4837
# Training Loss: 0.19540328681468963
# Validation Loss: 0.18665985289650658
# Epoch Training Duration: 00:00:49
#
# - EPOCH 38 -
# Dice: 0.6914
# IoU: 0.5374
# Training Loss: 0.19263358891010285
# Validation Loss: 0.18607715796679258
# Epoch Training Duration: 00:00:48
#
# - EPOCH 39 -
# Dice: 0.6903
# IoU: 0.5356
# Training Loss: 0.191761820713679
# Validation Loss: 0.1824445885916551
# Epoch Training Duration: 00:00:48
#
# - EPOCH 40 -
# Dice: 0.6686
# IoU: 0.5106
# Training Loss: 0.18637922247250874
# Validation Loss: 0.1846547482224802
# Epoch Training Duration: 00:00:48
#
# - EPOCH 41 -
# Dice: 0.6560
# IoU: 0.4944
# Training Loss: 0.19185561696688333
# Validation Loss: 0.18272029251481095
# Epoch Training Duration: 00:00:48
#
# - EPOCH 42 -
# Dice: 0.6676
# IoU: 0.5089
# Training Loss: 0.18629990577697753
# Validation Loss: 0.1814537214425703
# Epoch Training Duration: 00:00:48
#
# - EPOCH 43 -
# Dice: 0.6900
# IoU: 0.5345
# Training Loss: 0.18662342290083567
# Validation Loss: 0.18660374001289406
# Epoch Training Duration: 00:00:49
#
# - EPOCH 44 -
# Dice: 0.6847
# IoU: 0.5282
# Training Loss: 0.18452775617440542
# Validation Loss: 0.18642060148219267
# Epoch Training Duration: 00:00:49
#
# - EPOCH 45 -
# Dice: 0.7056
# IoU: 0.5538
# Training Loss: 0.18098069449265797
# Validation Loss: 0.18323995995645723
# Epoch Training Duration: 00:00:49
#
# - EPOCH 46 -
# Dice: 0.6489
# IoU: 0.4863
# Training Loss: 0.18187160432338714
# Validation Loss: 0.18227041388551393
# Epoch Training Duration: 00:00:48
#
# - EPOCH 47 -
# Dice: 0.6274
# IoU: 0.4625
# Training Loss: 0.18199313104152678
# Validation Loss: 0.1911879200488329
# Epoch Training Duration: 00:00:48
#
# - EPOCH 48 -
# Dice: 0.6424
# IoU: 0.4791
# Training Loss: 0.1844537353515625
# Validation Loss: 0.18533708900213242
# Epoch Training Duration: 00:00:48
#
# - EPOCH 49 -
# Dice: 0.6343
# IoU: 0.4709
# Training Loss: 0.19552906354268393
# Validation Loss: 0.18902135143677393
# Epoch Training Duration: 00:00:48
#
# - EPOCH 50 -
# Dice: 0.6635
# IoU: 0.5035
# Training Loss: 0.18272160212198893
# Validation Loss: 0.18365298304706812
# Epoch Training Duration: 00:00:48
#
# Total Training Duration for Threshold 0.1: 00:57:31
#
# -- TRAINING WITH THRESHOLD OF 0.2 --
#
# - EPOCH 1 -
# Dice: 0.6427
# IoU: 0.4804
# Training Loss: 0.3697037124633789
# Validation Loss: 0.23362341026465097
# Epoch Training Duration: 00:00:57
#
# - EPOCH 2 -
# Dice: 0.5781
# IoU: 0.4195
# Training Loss: 0.28394970218340554
# Validation Loss: 0.21279378794133663
# Epoch Training Duration: 00:00:48
#
# - EPOCH 3 -
# Dice: 0.6146
# IoU: 0.4494
# Training Loss: 0.2711850611368815
# Validation Loss: 0.20126853386561075
# Epoch Training Duration: 00:00:48
#
# - EPOCH 4 -
# Dice: 0.6568
# IoU: 0.4954
# Training Loss: 0.2635248653093974
# Validation Loss: 0.19630783082296452
# Epoch Training Duration: 00:00:48
#
# - EPOCH 5 -
# Dice: 0.6365
# IoU: 0.4729
# Training Loss: 0.2625624434153239
# Validation Loss: 0.19978847727179527
# Epoch Training Duration: 00:00:48
#
# - EPOCH 6 -
# Dice: 0.7015
# IoU: 0.5496
# Training Loss: 0.2555372063318888
# Validation Loss: 0.20444515145694217
# Epoch Training Duration: 00:00:48
#
# - EPOCH 7 -
# Dice: 0.6849
# IoU: 0.5285
# Training Loss: 0.24964808066685995
# Validation Loss: 0.19461181915054718
# Epoch Training Duration: 00:00:49
#
# - EPOCH 8 -
# Dice: 0.6524
# IoU: 0.4908
# Training Loss: 0.2454957338174184
# Validation Loss: 0.1905603357590735
# Epoch Training Duration: 00:00:48
#
# - EPOCH 9 -
# Dice: 0.6871
# IoU: 0.5318
# Training Loss: 0.24673093060652415
# Validation Loss: 0.19478789328907928
# Epoch Training Duration: 00:00:49
#
# - EPOCH 10 -
# Dice: 0.6698
# IoU: 0.5112
# Training Loss: 0.24326953053474426
# Validation Loss: 0.1980968814653655
# Epoch Training Duration: 00:00:48
#
# - EPOCH 11 -
# Dice: 0.6233
# IoU: 0.4596
# Training Loss: 0.2401648759841919
# Validation Loss: 0.19424896718313298
# Epoch Training Duration: 00:00:48
#
# - EPOCH 12 -
# Dice: 0.6809
# IoU: 0.5238
# Training Loss: 0.231274902621905
# Validation Loss: 0.20051846699789166
# Epoch Training Duration: 00:00:48
#
# - EPOCH 13 -
# Dice: 0.6758
# IoU: 0.5185
# Training Loss: 0.23625221371650695
# Validation Loss: 0.20105403289198875
# Epoch Training Duration: 00:00:48
#
# - EPOCH 14 -
# Dice: 0.6354
# IoU: 0.4719
# Training Loss: 0.23315835118293762
# Validation Loss: 0.1920597773666183
# Epoch Training Duration: 00:00:48
#
# - EPOCH 15 -
# Dice: 0.6940
# IoU: 0.5394
# Training Loss: 0.22771506985028586
# Validation Loss: 0.18774051017438373
# Epoch Training Duration: 00:00:49
#
# - EPOCH 16 -
# Dice: 0.6271
# IoU: 0.4623
# Training Loss: 0.22563335200150808
# Validation Loss: 0.19611035147681832
# Epoch Training Duration: 00:00:49
#
# - EPOCH 17 -
# Dice: 0.7205
# IoU: 0.5748
# Training Loss: 0.2379416545232137
# Validation Loss: 0.18768265346686044
# Epoch Training Duration: 00:00:49
#
# - EPOCH 18 -
# Dice: 0.7001
# IoU: 0.5484
# Training Loss: 0.22433069785435994
# Validation Loss: 0.18655596068128943
# Epoch Training Duration: 00:00:48
#
# - EPOCH 19 -
# Dice: 0.6953
# IoU: 0.5410
# Training Loss: 0.22158439179261524
# Validation Loss: 0.1762654511258006
# Epoch Training Duration: 00:00:48
#
# - EPOCH 20 -
# Dice: 0.6960
# IoU: 0.5419
# Training Loss: 0.21942020038763682
# Validation Loss: 0.18869740888476372
# Epoch Training Duration: 00:00:48
#
# - EPOCH 21 -
# Dice: 0.7133
# IoU: 0.5649
# Training Loss: 0.21707358956336975
# Validation Loss: 0.18409015207240978
# Epoch Training Duration: 00:00:48
#
# - EPOCH 22 -
# Dice: 0.6459
# IoU: 0.4827
# Training Loss: 0.21099772016207377
# Validation Loss: 0.19524558323125044
# Epoch Training Duration: 00:00:48
#
# - EPOCH 23 -
# Dice: 0.7160
# IoU: 0.5676
# Training Loss: 0.21287181278069814
# Validation Loss: 0.17742158472537994
# Epoch Training Duration: 00:00:48
#
# - EPOCH 24 -
# Dice: 0.7230
# IoU: 0.5776
# Training Loss: 0.2119649777809779
# Validation Loss: 0.178116701853772
# Epoch Training Duration: 00:00:49
#
# - EPOCH 25 -
# Dice: 0.6573
# IoU: 0.4961
# Training Loss: 0.21405822018782297
# Validation Loss: 0.1896353823443254
# Epoch Training Duration: 00:00:49
#
# - EPOCH 26 -
# Dice: 0.7015
# IoU: 0.5484
# Training Loss: 0.2107874228556951
# Validation Loss: 0.18397768447175622
# Epoch Training Duration: 00:00:49
#
# - EPOCH 27 -
# Dice: 0.7034
# IoU: 0.5515
# Training Loss: 0.20623726705710094
# Validation Loss: 0.1821857726511856
# Epoch Training Duration: 00:00:48
#
# - EPOCH 28 -
# Dice: 0.7138
# IoU: 0.5641
# Training Loss: 0.2073338117202123
# Validation Loss: 0.18177089669431248
# Epoch Training Duration: 00:00:48
#
# - EPOCH 29 -
# Dice: 0.6824
# IoU: 0.5249
# Training Loss: 0.20226327002048491
# Validation Loss: 0.18311016044269005
# Epoch Training Duration: 00:00:48
#
# - EPOCH 30 -
# Dice: 0.7005
# IoU: 0.5476
# Training Loss: 0.20173832138379416
# Validation Loss: 0.1793737863190472
# Epoch Training Duration: 00:00:48
#
# - EPOCH 31 -
# Dice: 0.7198
# IoU: 0.5734
# Training Loss: 0.20498783926169079
# Validation Loss: 0.1886867145076394
# Epoch Training Duration: 00:00:48
#
# - EPOCH 32 -
# Dice: 0.7300
# IoU: 0.5877
# Training Loss: 0.19646742602189382
# Validation Loss: 0.1924308342859149
# Epoch Training Duration: 00:00:48
#
# - EPOCH 33 -
# Dice: 0.7208
# IoU: 0.5745
# Training Loss: 0.19842866003513338
# Validation Loss: 0.18398458627052605
# Epoch Training Duration: 00:00:48
#
# - EPOCH 34 -
# Dice: 0.7118
# IoU: 0.5627
# Training Loss: 0.20088322579860687
# Validation Loss: 0.1765829339468231
# Epoch Training Duration: 00:00:48
#
# - EPOCH 35 -
# Dice: 0.7315
# IoU: 0.5880
# Training Loss: 0.1957420484224955
# Validation Loss: 0.17871100222691894
# Epoch Training Duration: 00:00:48
#
# - EPOCH 36 -
# Dice: 0.7192
# IoU: 0.5726
# Training Loss: 0.192814293106397
# Validation Loss: 0.18808030632014075
# Epoch Training Duration: 00:00:48
#
# - EPOCH 37 -
# Dice: 0.7251
# IoU: 0.5796
# Training Loss: 0.19633993049462636
# Validation Loss: 0.19973496533930302
# Epoch Training Duration: 00:00:48
#
# - EPOCH 38 -
# Dice: 0.6997
# IoU: 0.5471
# Training Loss: 0.1922385102510452
# Validation Loss: 0.1756866225041449
# Epoch Training Duration: 00:00:48
#
# - EPOCH 39 -
# Dice: 0.7010
# IoU: 0.5489
# Training Loss: 0.18929610073566436
# Validation Loss: 0.1874474559444934
# Epoch Training Duration: 00:00:48
#
# - EPOCH 40 -
# Dice: 0.6913
# IoU: 0.5364
# Training Loss: 0.19191417594750723
# Validation Loss: 0.18574076207975546
# Epoch Training Duration: 00:00:48
#
# - EPOCH 41 -
# Dice: 0.7014
# IoU: 0.5485
# Training Loss: 0.19840281208356222
# Validation Loss: 0.18267371489976844
# Epoch Training Duration: 00:00:48
#
# - EPOCH 42 -
# Dice: 0.7308
# IoU: 0.5872
# Training Loss: 0.19019074161847432
# Validation Loss: 0.18129497657840452
# Epoch Training Duration: 00:00:48
#
# - EPOCH 43 -
# Dice: 0.7159
# IoU: 0.5687
# Training Loss: 0.1903089871009191
# Validation Loss: 0.17966128326952457
# Epoch Training Duration: 00:00:49
#
# - EPOCH 44 -
# Dice: 0.7039
# IoU: 0.5519
# Training Loss: 0.1890192534526189
# Validation Loss: 0.18388658156618476
# Epoch Training Duration: 00:00:48
#
# - EPOCH 45 -
# Dice: 0.7134
# IoU: 0.5643
# Training Loss: 0.1841867999235789
# Validation Loss: 0.1842905688099563
# Epoch Training Duration: 00:00:48
#
# - EPOCH 46 -
# Dice: 0.7361
# IoU: 0.5940
# Training Loss: 0.18234742919603983
# Validation Loss: 0.1872517311324676
# Epoch Training Duration: 00:00:48
#
# - EPOCH 47 -
# Dice: 0.7031
# IoU: 0.5521
# Training Loss: 0.18528663337230683
# Validation Loss: 0.1853963383473456
# Epoch Training Duration: 00:00:48
#
# - EPOCH 48 -
# Dice: 0.7172
# IoU: 0.5700
# Training Loss: 0.18388927926619847
# Validation Loss: 0.17388336112101874
# Epoch Training Duration: 00:00:48
#
# - EPOCH 49 -
# Dice: 0.7369
# IoU: 0.5956
# Training Loss: 0.18037346402804058
# Validation Loss: 0.1813226738013327
# Epoch Training Duration: 00:00:48
#
# - EPOCH 50 -
# Dice: 0.7310
# IoU: 0.5874
# Training Loss: 0.17945999801158904
# Validation Loss: 0.18912897383173308
# Epoch Training Duration: 00:00:49
#
# Total Training Duration for Threshold 0.2: 00:45:29
#
# -- TRAINING WITH THRESHOLD OF 0.3 --
#
# - EPOCH 1 -
# Dice: 0.6394
# IoU: 0.4785
# Training Loss: 0.3181245009104411
# Validation Loss: 0.2228434750189384
# Epoch Training Duration: 00:00:55
#
# - EPOCH 2 -
# Dice: 0.6791
# IoU: 0.5223
# Training Loss: 0.27084958453973135
# Validation Loss: 0.19969123601913452
# Epoch Training Duration: 00:00:49
#
# - EPOCH 3 -
# Dice: 0.7026
# IoU: 0.5532
# Training Loss: 0.2640541628996531
# Validation Loss: 0.2173588906104366
# Epoch Training Duration: 00:00:49
#
# - EPOCH 4 -
# Dice: 0.7129
# IoU: 0.5665
# Training Loss: 0.2621339988708496
# Validation Loss: 0.19582460060094795
# Epoch Training Duration: 00:00:48
#
# - EPOCH 5 -
# Dice: 0.7005
# IoU: 0.5495
# Training Loss: 0.2549366949001948
# Validation Loss: 0.19558904320001602
# Epoch Training Duration: 00:00:48
#
# - EPOCH 6 -
# Dice: 0.6569
# IoU: 0.4964
# Training Loss: 0.24882089734077453
# Validation Loss: 0.2036606449012955
# Epoch Training Duration: 00:00:49
#
# - EPOCH 7 -
# Dice: 0.6960
# IoU: 0.5431
# Training Loss: 0.248297691543897
# Validation Loss: 0.19247032733013233
# Epoch Training Duration: 00:00:49
#
# - EPOCH 8 -
# Dice: 0.6945
# IoU: 0.5412
# Training Loss: 0.2430129663149516
# Validation Loss: 0.2019156349512438
# Epoch Training Duration: 00:00:49
#
# - EPOCH 9 -
# Dice: 0.6766
# IoU: 0.5187
# Training Loss: 0.24476912260055542
# Validation Loss: 0.200243073515594
# Epoch Training Duration: 00:00:48
#
# - EPOCH 10 -
# Dice: 0.7110
# IoU: 0.5622
# Training Loss: 0.23765629986921946
# Validation Loss: 0.18767091818153858
# Epoch Training Duration: 00:00:48
#
# - EPOCH 11 -
# Dice: 0.7098
# IoU: 0.5606
# Training Loss: 0.23695586562156679
# Validation Loss: 0.18971296663706502
# Epoch Training Duration: 00:00:48
#
# - EPOCH 12 -
# Dice: 0.7192
# IoU: 0.5732
# Training Loss: 0.23240864932537078
# Validation Loss: 0.18722212221473455
# Epoch Training Duration: 00:00:48
#
# - EPOCH 13 -
# Dice: 0.7149
# IoU: 0.5674
# Training Loss: 0.22975355247656504
# Validation Loss: 0.18802897228548923
# Epoch Training Duration: 00:00:48
#
# - EPOCH 14 -
# Dice: 0.7083
# IoU: 0.5585
# Training Loss: 0.22803036709626515
# Validation Loss: 0.18967166480918726
# Epoch Training Duration: 00:00:49
#
# - EPOCH 15 -
# Dice: 0.7039
# IoU: 0.5527
# Training Loss: 0.2266775139172872
# Validation Loss: 0.19325521914288402
# Epoch Training Duration: 00:00:49
#
# - EPOCH 16 -
# Dice: 0.6935
# IoU: 0.5391
# Training Loss: 0.22074763357639313
# Validation Loss: 0.18604376011838517
# Epoch Training Duration: 00:00:49
#
# - EPOCH 17 -
# Dice: 0.6962
# IoU: 0.5431
# Training Loss: 0.22113743126392366
# Validation Loss: 0.187975920115908
# Epoch Training Duration: 00:00:48
#
# - EPOCH 18 -
# Dice: 0.6838
# IoU: 0.5280
# Training Loss: 0.22209993640581766
# Validation Loss: 0.19875699638699493
# Epoch Training Duration: 00:00:48
#
# - EPOCH 19 -
# Dice: 0.7049
# IoU: 0.5547
# Training Loss: 0.22067580898602804
# Validation Loss: 0.19124342175200582
# Epoch Training Duration: 00:00:48
#
# - EPOCH 20 -
# Dice: 0.7125
# IoU: 0.5634
# Training Loss: 0.21906336188316344
# Validation Loss: 0.18132938972363868
# Epoch Training Duration: 00:00:48
#
# - EPOCH 21 -
# Dice: 0.6975
# IoU: 0.5442
# Training Loss: 0.21787309686342876
# Validation Loss: 0.18571458384394646
# Epoch Training Duration: 00:00:48
#
# - EPOCH 22 -
# Dice: 0.7267
# IoU: 0.5820
# Training Loss: 0.21096963425477347
# Validation Loss: 0.1808414418871204
# Epoch Training Duration: 00:00:48
#
# - EPOCH 23 -
# Dice: 0.7232
# IoU: 0.5775
# Training Loss: 0.20864160160223644
# Validation Loss: 0.17947189851353565
# Epoch Training Duration: 00:00:48
#
# - EPOCH 24 -
# Dice: 0.7304
# IoU: 0.5877
# Training Loss: 0.20551908751328787
# Validation Loss: 0.18876361660659313
# Epoch Training Duration: 00:00:48
#
# - EPOCH 25 -
# Dice: 0.7290
# IoU: 0.5858
# Training Loss: 0.20994711418946585
# Validation Loss: 0.1879950181270639
# Epoch Training Duration: 00:00:48
#
# - EPOCH 26 -
# Dice: 0.7186
# IoU: 0.5719
# Training Loss: 0.20844845672448475
# Validation Loss: 0.1865583766872684
# Epoch Training Duration: 00:00:48
#
# - EPOCH 27 -
# Dice: 0.7314
# IoU: 0.5892
# Training Loss: 0.20688376645247142
# Validation Loss: 0.18808049786215028
# Epoch Training Duration: 00:00:48
#
# - EPOCH 28 -
# Dice: 0.7158
# IoU: 0.5674
# Training Loss: 0.20068600634733835
# Validation Loss: 0.18341063692544898
# Epoch Training Duration: 00:00:48
#
# - EPOCH 29 -
# Dice: 0.7342
# IoU: 0.5929
# Training Loss: 0.20082686762015026
# Validation Loss: 0.17588228033855557
# Epoch Training Duration: 00:00:48
#
# - EPOCH 30 -
# Dice: 0.7293
# IoU: 0.5865
# Training Loss: 0.19705122629801433
# Validation Loss: 0.1875541782937944
# Epoch Training Duration: 00:00:48
#
# - EPOCH 31 -
# Dice: 0.7173
# IoU: 0.5704
# Training Loss: 0.1959945124387741
# Validation Loss: 0.1912295289027194
# Epoch Training Duration: 00:00:49
#
# - EPOCH 32 -
# Dice: 0.7345
# IoU: 0.5920
# Training Loss: 0.20053087592124938
# Validation Loss: 0.18686474029285213
# Epoch Training Duration: 00:00:49
#
# - EPOCH 33 -
# Dice: 0.7408
# IoU: 0.6020
# Training Loss: 0.1969712326924006
# Validation Loss: 0.19267011930545172
# Epoch Training Duration: 00:00:49
#
# - EPOCH 34 -
# Dice: 0.7285
# IoU: 0.5839
# Training Loss: 0.1945731476942698
# Validation Loss: 0.18664283258840442
# Epoch Training Duration: 00:00:49
#
# - EPOCH 35 -
# Dice: 0.7354
# IoU: 0.5938
# Training Loss: 0.195124662121137
# Validation Loss: 0.18041883020972213
# Epoch Training Duration: 00:00:49
#
# - EPOCH 36 -
# Dice: 0.7369
# IoU: 0.5969
# Training Loss: 0.19093782524267833
# Validation Loss: 0.17856466056158146
# Epoch Training Duration: 00:00:48
#
# - EPOCH 37 -
# Dice: 0.7386
# IoU: 0.5981
# Training Loss: 0.18909802675247192
# Validation Loss: 0.18411669585232934
# Epoch Training Duration: 00:00:48
#
# - EPOCH 38 -
# Dice: 0.7352
# IoU: 0.5929
# Training Loss: 0.1901830852031708
# Validation Loss: 0.1780130312157174
# Epoch Training Duration: 00:00:49
#
# - EPOCH 39 -
# Dice: 0.7214
# IoU: 0.5759
# Training Loss: 0.1888386090596517
# Validation Loss: 0.1876122816465795
# Epoch Training Duration: 00:00:49
#
# - EPOCH 40 -
# Dice: 0.7341
# IoU: 0.5920
# Training Loss: 0.19355033278465272
# Validation Loss: 0.19194468017667532
# Epoch Training Duration: 00:00:49
#
# - EPOCH 41 -
# Dice: 0.7272
# IoU: 0.5817
# Training Loss: 0.19721291224161783
# Validation Loss: 0.17967727376768985
# Epoch Training Duration: 00:00:49
#
# - EPOCH 42 -
# Dice: 0.7421
# IoU: 0.6026
# Training Loss: 0.18884295384089153
# Validation Loss: 0.17764957171554366
# Epoch Training Duration: 00:00:49
#
# - EPOCH 43 -
# Dice: 0.7384
# IoU: 0.5967
# Training Loss: 0.1844786074757576
# Validation Loss: 0.17903219303116202
# Epoch Training Duration: 00:00:49
#
# - EPOCH 44 -
# Dice: 0.7397
# IoU: 0.5994
# Training Loss: 0.185355175336202
# Validation Loss: 0.18208905650923649
# Epoch Training Duration: 00:00:49
#
# - EPOCH 45 -
# Dice: 0.7312
# IoU: 0.5889
# Training Loss: 0.1847121399641037
# Validation Loss: 0.19828938661764064
# Epoch Training Duration: 00:00:49
#
# - EPOCH 46 -
# Dice: 0.7240
# IoU: 0.5774
# Training Loss: 0.18486848791440327
# Validation Loss: 0.18155516932408014
# Epoch Training Duration: 00:00:49
#
# - EPOCH 47 -
# Dice: 0.7278
# IoU: 0.5833
# Training Loss: 0.18372961183389028
# Validation Loss: 0.18023461429402232
# Epoch Training Duration: 00:00:49
#
# - EPOCH 48 -
# Dice: 0.7315
# IoU: 0.5883
# Training Loss: 0.1816011177500089
# Validation Loss: 0.18866810326774916
# Epoch Training Duration: 00:00:50
#
# - EPOCH 49 -
# Dice: 0.7405
# IoU: 0.6005
# Training Loss: 0.18089800576368967
# Validation Loss: 0.19029506016522646
# Epoch Training Duration: 00:00:49
#
# - EPOCH 50 -
# Dice: 0.7308
# IoU: 0.5866
# Training Loss: 0.1781623387336731
# Validation Loss: 0.19070492420966426
# Epoch Training Duration: 00:00:49
#
# Total Training Duration for Threshold 0.3: 00:45:49
#
# -- TRAINING WITH THRESHOLD OF 0.4 --
#
# - EPOCH 1 -
# Dice: 0.6896
# IoU: 0.5371
# Training Loss: 0.35056898872057596
# Validation Loss: 0.21649317008753619
# Epoch Training Duration: 00:00:57
#
# - EPOCH 2 -
# Dice: 0.6503
# IoU: 0.4897
# Training Loss: 0.27882355213165283
# Validation Loss: 0.2643554260333379
# Epoch Training Duration: 00:00:48
#
# - EPOCH 3 -
# Dice: 0.6897
# IoU: 0.5392
# Training Loss: 0.2738119908173879
# Validation Loss: 0.20487737810860077
# Epoch Training Duration: 00:00:49
#
# - EPOCH 4 -
# Dice: 0.7064
# IoU: 0.5574
# Training Loss: 0.2611098309357961
# Validation Loss: 0.19666840322315693
# Epoch Training Duration: 00:00:49
#
# - EPOCH 5 -
# Dice: 0.7064
# IoU: 0.5580
# Training Loss: 0.2579760189851125
# Validation Loss: 0.19781452106932798
# Epoch Training Duration: 00:00:49
#
# - EPOCH 6 -
# Dice: 0.7077
# IoU: 0.5594
# Training Loss: 0.25844811062018075
# Validation Loss: 0.1961804412615796
# Epoch Training Duration: 00:00:48
#
# - EPOCH 7 -
# Dice: 0.7055
# IoU: 0.5558
# Training Loss: 0.24940896968046825
# Validation Loss: 0.19605488826831183
# Epoch Training Duration: 00:00:48
#
# - EPOCH 8 -
# Dice: 0.7033
# IoU: 0.5534
# Training Loss: 0.24875485380490622
# Validation Loss: 0.19595181057229638
# Epoch Training Duration: 00:00:48
#
# - EPOCH 9 -
# Dice: 0.7136
# IoU: 0.5681
# Training Loss: 0.24546062469482421
# Validation Loss: 0.1889101043343544
# Epoch Training Duration: 00:00:48
#
# - EPOCH 10 -
# Dice: 0.6480
# IoU: 0.4854
# Training Loss: 0.24218427141507468
# Validation Loss: 0.2248915353169044
# Epoch Training Duration: 00:00:48
#
# - EPOCH 11 -
# Dice: 0.7104
# IoU: 0.5633
# Training Loss: 0.23982713560263316
# Validation Loss: 0.18986876231307784
# Epoch Training Duration: 00:00:50
#
# - EPOCH 12 -
# Dice: 0.7094
# IoU: 0.5632
# Training Loss: 0.23246605475743612
# Validation Loss: 0.19619734724983573
# Epoch Training Duration: 00:00:48
#
# - EPOCH 13 -
# Dice: 0.7208
# IoU: 0.5754
# Training Loss: 0.24073626041412355
# Validation Loss: 0.18604085625459751
# Epoch Training Duration: 00:00:49
#
# - EPOCH 14 -
# Dice: 0.7147
# IoU: 0.5685
# Training Loss: 0.2334137233098348
# Validation Loss: 0.1937087974511087
# Epoch Training Duration: 00:00:48
#
# - EPOCH 15 -
# Dice: 0.7207
# IoU: 0.5768
# Training Loss: 0.2323483085632324
# Validation Loss: 0.1889134387796124
# Epoch Training Duration: 00:00:48
#
# - EPOCH 16 -
# Dice: 0.7159
# IoU: 0.5686
# Training Loss: 0.22649061679840088
# Validation Loss: 0.19395171043773493
# Epoch Training Duration: 00:00:48
#
# - EPOCH 17 -
# Dice: 0.7122
# IoU: 0.5640
# Training Loss: 0.22619134028752644
# Validation Loss: 0.19084720608467856
# Epoch Training Duration: 00:00:48
#
# - EPOCH 18 -
# Dice: 0.7314
# IoU: 0.5899
# Training Loss: 0.2251086695988973
# Validation Loss: 0.18739550157139698
# Epoch Training Duration: 00:00:48
#
# - EPOCH 19 -
# Dice: 0.7110
# IoU: 0.5622
# Training Loss: 0.22184661149978638
# Validation Loss: 0.19240005919709802
# Epoch Training Duration: 00:00:49
#
# - EPOCH 20 -
# Dice: 0.7195
# IoU: 0.5733
# Training Loss: 0.21744463880856832
# Validation Loss: 0.18888834677636623
# Epoch Training Duration: 00:00:49
#
# - EPOCH 21 -
# Dice: 0.7173
# IoU: 0.5713
# Training Loss: 0.21534128765265148
# Validation Loss: 0.1878511255296568
# Epoch Training Duration: 00:00:49
#
# - EPOCH 22 -
# Dice: 0.7333
# IoU: 0.5927
# Training Loss: 0.21148251513640084
# Validation Loss: 0.1835009567439556
# Epoch Training Duration: 00:00:48
#
# - EPOCH 23 -
# Dice: 0.7155
# IoU: 0.5687
# Training Loss: 0.21660348216692607
# Validation Loss: 0.19360943790525198
# Epoch Training Duration: 00:00:48
#
# - EPOCH 24 -
# Dice: 0.7298
# IoU: 0.5886
# Training Loss: 0.21068698525428772
# Validation Loss: 0.1826212713494897
# Epoch Training Duration: 00:00:48
#
# - EPOCH 25 -
# Dice: 0.7362
# IoU: 0.5971
# Training Loss: 0.20855124632517497
# Validation Loss: 0.17982617501790324
# Epoch Training Duration: 00:00:48
#
# - EPOCH 26 -
# Dice: 0.6897
# IoU: 0.5351
# Training Loss: 0.20859944661458332
# Validation Loss: 0.20856521309663853
# Epoch Training Duration: 00:00:48
#
# - EPOCH 27 -
# Dice: 0.7236
# IoU: 0.5812
# Training Loss: 0.21048769136269888
# Validation Loss: 0.1867051844795545
# Epoch Training Duration: 00:00:49
#
# - EPOCH 28 -
# Dice: 0.7377
# IoU: 0.5982
# Training Loss: 0.20821733216444652
# Validation Loss: 0.18072179441029826
# Epoch Training Duration: 00:00:48
#
# - EPOCH 29 -
# Dice: 0.7237
# IoU: 0.5807
# Training Loss: 0.20728434443473817
# Validation Loss: 0.1895859775443872
# Epoch Training Duration: 00:00:48
#
# - EPOCH 30 -
# Dice: 0.7374
# IoU: 0.5966
# Training Loss: 0.20304310858249663
# Validation Loss: 0.18291622928033272
# Epoch Training Duration: 00:00:48
#
# - EPOCH 31 -
# Dice: 0.7412
# IoU: 0.6028
# Training Loss: 0.20119305471579232
# Validation Loss: 0.1809065849520266
# Epoch Training Duration: 00:00:48
#
# - EPOCH 32 -
# Dice: 0.7337
# IoU: 0.5922
# Training Loss: 0.19916921277840932
# Validation Loss: 0.18085097800940275
# Epoch Training Duration: 00:00:48
#
# - EPOCH 33 -
# Dice: 0.7320
# IoU: 0.5910
# Training Loss: 0.21911375006039938
# Validation Loss: 0.18345628213137388
# Epoch Training Duration: 00:00:48
#
# - EPOCH 34 -
# Dice: 0.7169
# IoU: 0.5700
# Training Loss: 0.20327003022034962
# Validation Loss: 0.19537159769485393
# Epoch Training Duration: 00:00:48
#
# - EPOCH 35 -
# Dice: 0.7391
# IoU: 0.6012
# Training Loss: 0.2015273888905843
# Validation Loss: 0.18650214048102498
# Epoch Training Duration: 00:00:48
#
# - EPOCH 36 -
# Dice: 0.7384
# IoU: 0.5994
# Training Loss: 0.19772838254769642
# Validation Loss: 0.18628213445966443
# Epoch Training Duration: 00:00:48
#
# - EPOCH 37 -
# Dice: 0.7468
# IoU: 0.6094
# Training Loss: 0.19488537013530732
# Validation Loss: 0.17823124630376697
# Epoch Training Duration: 00:00:48
#
# - EPOCH 38 -
# Dice: 0.7416
# IoU: 0.6030
# Training Loss: 0.19268763144810994
# Validation Loss: 0.179910807715108
# Epoch Training Duration: 00:00:47
#
# - EPOCH 39 -
# Dice: 0.7396
# IoU: 0.6008
# Training Loss: 0.19266639192899068
# Validation Loss: 0.17817636268834272
# Epoch Training Duration: 00:00:48
#
# - EPOCH 40 -
# Dice: 0.7413
# IoU: 0.6035
# Training Loss: 0.19012279987335204
# Validation Loss: 0.1842600394350787
# Epoch Training Duration: 00:00:48
#
# - EPOCH 41 -
# Dice: 0.7370
# IoU: 0.5970
# Training Loss: 0.1903141540288925
# Validation Loss: 0.19220810492212573
# Epoch Training Duration: 00:00:48
#
# - EPOCH 42 -
# Dice: 0.7362
# IoU: 0.5970
# Training Loss: 0.19022420406341553
# Validation Loss: 0.18651163841908178
# Epoch Training Duration: 00:00:48
#
# - EPOCH 43 -
# Dice: 0.7477
# IoU: 0.6111
# Training Loss: 0.18912499010562897
# Validation Loss: 0.18438816792331636
# Epoch Training Duration: 00:00:48
#
# - EPOCH 44 -
# Dice: 0.7394
# IoU: 0.6015
# Training Loss: 0.18690483391284943
# Validation Loss: 0.18411769772258899
# Epoch Training Duration: 00:00:48
#
# - EPOCH 45 -
# Dice: 0.7280
# IoU: 0.5840
# Training Loss: 0.1885376981894175
# Validation Loss: 0.19757593780135116
# Epoch Training Duration: 00:00:47
#
# - EPOCH 46 -
# Dice: 0.7424
# IoU: 0.6030
# Training Loss: 0.18521100838979085
# Validation Loss: 0.18355362753694257
# Epoch Training Duration: 00:00:48
#
# - EPOCH 47 -
# Dice: 0.7436
# IoU: 0.6058
# Training Loss: 0.1825353733698527
# Validation Loss: 0.18333448035021624
# Epoch Training Duration: 00:00:48
#
# - EPOCH 48 -
# Dice: 0.7401
# IoU: 0.6014
# Training Loss: 0.1809727164109548
# Validation Loss: 0.19938880018889904
# Epoch Training Duration: 00:00:48
#
# - EPOCH 49 -
# Dice: 0.7458
# IoU: 0.6080
# Training Loss: 0.18197921971480052
# Validation Loss: 0.18510987469926476
# Epoch Training Duration: 00:00:49
#
# - EPOCH 50 -
# Dice: 0.7486
# IoU: 0.6128
# Training Loss: 0.17855434079964955
# Validation Loss: 0.18594767378332713
# Epoch Training Duration: 00:00:48
#
# Total Training Duration for Threshold 0.4: 00:45:24
#
# -- TRAINING WITH THRESHOLD OF 0.5 --
#
# - EPOCH 1 -
# Dice: 0.6879
# IoU: 0.5358
# Training Loss: 0.42989053765932717
# Validation Loss: 0.2591058388352394
# Epoch Training Duration: 00:00:54
#
# - EPOCH 2 -
# Dice: 0.6522
# IoU: 0.4992
# Training Loss: 0.30149733821551006
# Validation Loss: 0.21411561934898296
# Epoch Training Duration: 00:00:48
#
# - EPOCH 3 -
# Dice: 0.6140
# IoU: 0.4594
# Training Loss: 0.27789696911970774
# Validation Loss: 0.21453399490565062
# Epoch Training Duration: 00:00:49
#
# - EPOCH 4 -
# Dice: 0.6761
# IoU: 0.5248
# Training Loss: 0.26569584707419075
# Validation Loss: 0.19624593776340285
# Epoch Training Duration: 00:00:49
#
# - EPOCH 5 -
# Dice: 0.6862
# IoU: 0.5357
# Training Loss: 0.25960267504056295
# Validation Loss: 0.19445599988102913
# Epoch Training Duration: 00:00:48
#
# - EPOCH 6 -
# Dice: 0.6941
# IoU: 0.5442
# Training Loss: 0.25238165497779846
# Validation Loss: 0.19474464189261198
# Epoch Training Duration: 00:00:48
#
# - EPOCH 7 -
# Dice: 0.6725
# IoU: 0.5169
# Training Loss: 0.2528172322114309
# Validation Loss: 0.1974927494302392
# Epoch Training Duration: 00:00:47
#
# - EPOCH 8 -
# Dice: 0.6802
# IoU: 0.5278
# Training Loss: 0.25238507966200513
# Validation Loss: 0.20045098414023718
# Epoch Training Duration: 00:00:48
#
# - EPOCH 9 -
# Dice: 0.7068
# IoU: 0.5577
# Training Loss: 0.2468901401758194
# Validation Loss: 0.19638094026595354
# Epoch Training Duration: 00:00:48
#
# - EPOCH 10 -
# Dice: 0.6864
# IoU: 0.5367
# Training Loss: 0.24222421884536743
# Validation Loss: 0.19276619283482432
# Epoch Training Duration: 00:00:49
#
# - EPOCH 11 -
# Dice: 0.7112
# IoU: 0.5650
# Training Loss: 0.2371291927496592
# Validation Loss: 0.18576901219785213
# Epoch Training Duration: 00:00:49
#
# - EPOCH 12 -
# Dice: 0.7138
# IoU: 0.5679
# Training Loss: 0.23273487190405528
# Validation Loss: 0.18706681377564868
# Epoch Training Duration: 00:00:48
#
# - EPOCH 13 -
# Dice: 0.6946
# IoU: 0.5437
# Training Loss: 0.23621532917022706
# Validation Loss: 0.19138032725701729
# Epoch Training Duration: 00:00:48
#
# - EPOCH 14 -
# Dice: 0.7106
# IoU: 0.5645
# Training Loss: 0.2362161644299825
# Validation Loss: 0.18501706390331188
# Epoch Training Duration: 00:00:48
#
# - EPOCH 15 -
# Dice: 0.7126
# IoU: 0.5657
# Training Loss: 0.22852566003799438
# Validation Loss: 0.19357620241741338
# Epoch Training Duration: 00:00:48
#
# - EPOCH 16 -
# Dice: 0.7199
# IoU: 0.5753
# Training Loss: 0.22319142560164135
# Validation Loss: 0.1859521148726344
# Epoch Training Duration: 00:00:48
#
# - EPOCH 17 -
# Dice: 0.7005
# IoU: 0.5525
# Training Loss: 0.22848741948604584
# Validation Loss: 0.18564095068722963
# Epoch Training Duration: 00:00:48
#
# - EPOCH 18 -
# Dice: 0.7226
# IoU: 0.5780
# Training Loss: 0.22025506258010863
# Validation Loss: 0.18213197402656078
# Epoch Training Duration: 00:00:48
#
# - EPOCH 19 -
# Dice: 0.7245
# IoU: 0.5816
# Training Loss: 0.21705159684022268
# Validation Loss: 0.18229321840529641
# Epoch Training Duration: 00:00:48
#
# - EPOCH 20 -
# Dice: 0.7152
# IoU: 0.5697
# Training Loss: 0.217841361562411
# Validation Loss: 0.1888180955623587
# Epoch Training Duration: 00:00:48
#
# - EPOCH 21 -
# Dice: 0.7246
# IoU: 0.5812
# Training Loss: 0.215140829483668
# Validation Loss: 0.18643525258327523
# Epoch Training Duration: 00:00:48
#
# - EPOCH 22 -
# Dice: 0.7338
# IoU: 0.5926
# Training Loss: 0.2147950905561447
# Validation Loss: 0.17839595411593714
# Epoch Training Duration: 00:00:48
#
# - EPOCH 23 -
# Dice: 0.7170
# IoU: 0.5724
# Training Loss: 0.21126212139924366
# Validation Loss: 0.18853815086185932
# Epoch Training Duration: 00:00:48
#
# - EPOCH 24 -
# Dice: 0.7222
# IoU: 0.5780
# Training Loss: 0.21057402352492013
# Validation Loss: 0.18666848726570606
# Epoch Training Duration: 00:00:48
#
# - EPOCH 25 -
# Dice: 0.7217
# IoU: 0.5768
# Training Loss: 0.21429371535778047
# Validation Loss: 0.18965739710256457
# Epoch Training Duration: 00:00:48
#
# - EPOCH 26 -
# Dice: 0.7284
# IoU: 0.5864
# Training Loss: 0.2076264856259028
# Validation Loss: 0.17889273927236596
# Epoch Training Duration: 00:00:48
#
# - EPOCH 27 -
# Dice: 0.7378
# IoU: 0.5986
# Training Loss: 0.20762123107910158
# Validation Loss: 0.1767468792386353
# Epoch Training Duration: 00:00:48
#
# - EPOCH 28 -
# Dice: 0.7276
# IoU: 0.5856
# Training Loss: 0.20496997753779092
# Validation Loss: 0.18240597005933523
# Epoch Training Duration: 00:00:48
#
# - EPOCH 29 -
# Dice: 0.7381
# IoU: 0.5984
# Training Loss: 0.20384623567263285
# Validation Loss: 0.17727388689915338
# Epoch Training Duration: 00:00:48
#
# - EPOCH 30 -
# Dice: 0.7263
# IoU: 0.5839
# Training Loss: 0.20521116216977436
# Validation Loss: 0.18497564115871987
# Epoch Training Duration: 00:00:48
#
# - EPOCH 31 -
# Dice: 0.7352
# IoU: 0.5952
# Training Loss: 0.20192781329154968
# Validation Loss: 0.1772062936797738
# Epoch Training Duration: 00:00:48
#
# - EPOCH 32 -
# Dice: 0.7325
# IoU: 0.5912
# Training Loss: 0.2015867038567861
# Validation Loss: 0.1787928769675394
# Epoch Training Duration: 00:00:48
#
# - EPOCH 33 -
# Dice: 0.7254
# IoU: 0.5827
# Training Loss: 0.201276948650678
# Validation Loss: 0.18532780014599362
# Epoch Training Duration: 00:00:48
#
# - EPOCH 34 -
# Dice: 0.7330
# IoU: 0.5927
# Training Loss: 0.198927454551061
# Validation Loss: 0.17986072188553712
# Epoch Training Duration: 00:00:48
#
# - EPOCH 35 -
# Dice: 0.7297
# IoU: 0.5884
# Training Loss: 0.19433642188707986
# Validation Loss: 0.1830222561645011
# Epoch Training Duration: 00:00:48
#
# - EPOCH 36 -
# Dice: 0.7344
# IoU: 0.5944
# Training Loss: 0.19638324697812398
# Validation Loss: 0.1813522994828721
# Epoch Training Duration: 00:00:48
#
# - EPOCH 37 -
# Dice: 0.7348
# IoU: 0.5950
# Training Loss: 0.19709847172101339
# Validation Loss: 0.1756683699786663
# Epoch Training Duration: 00:00:48
#
# - EPOCH 38 -
# Dice: 0.7380
# IoU: 0.5995
# Training Loss: 0.1950303852558136
# Validation Loss: 0.17784331583728394
# Epoch Training Duration: 00:00:48
#
# - EPOCH 39 -
# Dice: 0.7392
# IoU: 0.6004
# Training Loss: 0.1985525131225586
# Validation Loss: 0.17751223252465329
# Epoch Training Duration: 00:00:48
#
# - EPOCH 40 -
# Dice: 0.7259
# IoU: 0.5839
# Training Loss: 0.1910196848710378
# Validation Loss: 0.1801300710067153
# Epoch Training Duration: 00:00:49
#
# - EPOCH 41 -
# Dice: 0.7415
# IoU: 0.6031
# Training Loss: 0.18962169488271077
# Validation Loss: 0.19784907003243765
# Epoch Training Duration: 00:00:48
#
# - EPOCH 42 -
# Dice: 0.7399
# IoU: 0.6018
# Training Loss: 0.18777225573857625
# Validation Loss: 0.18915611986691752
# Epoch Training Duration: 00:00:48
#
# - EPOCH 43 -
# Dice: 0.7139
# IoU: 0.5677
# Training Loss: 0.18715758899847668
# Validation Loss: 0.1997619092774888
# Epoch Training Duration: 00:00:48
#
# - EPOCH 44 -
# Dice: 0.7348
# IoU: 0.5948
# Training Loss: 0.19162880023320517
# Validation Loss: 0.18799057711536685
# Epoch Training Duration: 00:00:48
#
# - EPOCH 45 -
# Dice: 0.7312
# IoU: 0.5899
# Training Loss: 0.19090229471524556
# Validation Loss: 0.20391275578488907
# Epoch Training Duration: 00:00:48
#
# - EPOCH 46 -
# Dice: 0.7375
# IoU: 0.5979
# Training Loss: 0.1906729249159495
# Validation Loss: 0.18093997721249858
# Epoch Training Duration: 00:00:48
#
# - EPOCH 47 -
# Dice: 0.7347
# IoU: 0.5951
# Training Loss: 0.1902168548107147
# Validation Loss: 0.18241184297949076
# Epoch Training Duration: 00:00:49
#
# - EPOCH 48 -
# Dice: 0.7399
# IoU: 0.6004
# Training Loss: 0.18908332765102387
# Validation Loss: 0.17964902690922221
# Epoch Training Duration: 00:00:48
#
# - EPOCH 49 -
# Dice: 0.7417
# IoU: 0.6033
# Training Loss: 0.18149050116539
# Validation Loss: 0.18195086733127633
# Epoch Training Duration: 00:00:48
#
# - EPOCH 50 -
# Dice: 0.7357
# IoU: 0.5958
# Training Loss: 0.1812952713171641
# Validation Loss: 0.18329022669543824
# Epoch Training Duration: 00:00:48
#
# Total Training Duration for Threshold 0.5: 00:45:18
#
# -- TRAINING WITH THRESHOLD OF 0.6 --
#
# - EPOCH 1 -
# Dice: 0.6447
# IoU: 0.4891
# Training Loss: 0.3772636576493581
# Validation Loss: 0.23565369099378586
# Epoch Training Duration: 00:00:56
#
# - EPOCH 2 -
# Dice: 0.6397
# IoU: 0.4848
# Training Loss: 0.2901443221171697
# Validation Loss: 0.20648824516683817
# Epoch Training Duration: 00:00:49
#
# - EPOCH 3 -
# Dice: 0.6795
# IoU: 0.5253
# Training Loss: 0.275534232656161
# Validation Loss: 0.229553391225636
# Epoch Training Duration: 00:00:49
#
# - EPOCH 4 -
# Dice: 0.6666
# IoU: 0.5116
# Training Loss: 0.2663271180788676
# Validation Loss: 0.20569169086714587
# Epoch Training Duration: 00:00:49
#
# - EPOCH 5 -
# Dice: 0.6784
# IoU: 0.5258
# Training Loss: 0.2694458717107773
# Validation Loss: 0.1956368226868411
# Epoch Training Duration: 00:00:49
#
# - EPOCH 6 -
# Dice: 0.6704
# IoU: 0.5141
# Training Loss: 0.256300599972407
# Validation Loss: 0.2192432191222906
# Epoch Training Duration: 00:00:49
#
# - EPOCH 7 -
# Dice: 0.6042
# IoU: 0.4486
# Training Loss: 0.25386550227801
# Validation Loss: 0.21279262440900007
# Epoch Training Duration: 00:00:48
#
# - EPOCH 8 -
# Dice: 0.5823
# IoU: 0.4251
# Training Loss: 0.25319593330224355
# Validation Loss: 0.20991282258182764
# Epoch Training Duration: 00:00:48
#
# - EPOCH 9 -
# Dice: 0.6761
# IoU: 0.5241
# Training Loss: 0.24860047101974486
# Validation Loss: 0.18980534995595613
# Epoch Training Duration: 00:00:48
#
# - EPOCH 10 -
# Dice: 0.7019
# IoU: 0.5532
# Training Loss: 0.24571537752946218
# Validation Loss: 0.1894148748057584
# Epoch Training Duration: 00:00:48
#
# - EPOCH 11 -
# Dice: 0.6980
# IoU: 0.5498
# Training Loss: 0.24619880716005962
# Validation Loss: 0.1900191854995986
# Epoch Training Duration: 00:00:49
#
# - EPOCH 12 -
# Dice: 0.6703
# IoU: 0.5172
# Training Loss: 0.24131154934565227
# Validation Loss: 0.18556569811577597
# Epoch Training Duration: 00:00:48
#
# - EPOCH 13 -
# Dice: 0.6917
# IoU: 0.5421
# Training Loss: 0.23620680669943492
# Validation Loss: 0.1859211636086305
# Epoch Training Duration: 00:00:48
#
# - EPOCH 14 -
# Dice: 0.6672
# IoU: 0.5100
# Training Loss: 0.23257195929686228
# Validation Loss: 0.20095617696642876
# Epoch Training Duration: 00:00:48
#
# - EPOCH 15 -
# Dice: 0.6930
# IoU: 0.5435
# Training Loss: 0.23299851497014365
# Validation Loss: 0.1822138954885304
# Epoch Training Duration: 00:00:48
#
# - EPOCH 16 -
# Dice: 0.6885
# IoU: 0.5395
# Training Loss: 0.23826091130574545
# Validation Loss: 0.18956810251499215
# Epoch Training Duration: 00:00:48
#
# - EPOCH 17 -
# Dice: 0.7168
# IoU: 0.5716
# Training Loss: 0.22784919579823812
# Validation Loss: 0.1839775814053913
# Epoch Training Duration: 00:00:49
#
# - EPOCH 18 -
# Dice: 0.7066
# IoU: 0.5600
# Training Loss: 0.22526119748751322
# Validation Loss: 0.18620251569276056
# Epoch Training Duration: 00:00:49
#
# - EPOCH 19 -
# Dice: 0.6888
# IoU: 0.5388
# Training Loss: 0.22227059483528136
# Validation Loss: 0.191530955179284
# Epoch Training Duration: 00:00:49
#
# - EPOCH 20 -
# Dice: 0.6896
# IoU: 0.5386
# Training Loss: 0.21850994328657786
# Validation Loss: 0.18382605413595834
# Epoch Training Duration: 00:00:48
#
# - EPOCH 21 -
# Dice: 0.6907
# IoU: 0.5409
# Training Loss: 0.2186123687028885
# Validation Loss: 0.18705292899782458
# Epoch Training Duration: 00:00:48
#
# - EPOCH 22 -
# Dice: 0.6996
# IoU: 0.5521
# Training Loss: 0.21329977850119272
# Validation Loss: 0.1861910275183618
# Epoch Training Duration: 00:00:48
#
# - EPOCH 23 -
# Dice: 0.6708
# IoU: 0.5177
# Training Loss: 0.21432578384876252
# Validation Loss: 0.1878636386245489
# Epoch Training Duration: 00:00:49
#
# - EPOCH 24 -
# Dice: 0.7180
# IoU: 0.5736
# Training Loss: 0.21499070525169373
# Validation Loss: 0.18264080941056213
# Epoch Training Duration: 00:00:49
#
# - EPOCH 25 -
# Dice: 0.7057
# IoU: 0.5598
# Training Loss: 0.2146423582235972
# Validation Loss: 0.18519349031460783
# Epoch Training Duration: 00:00:49
#
# - EPOCH 26 -
# Dice: 0.7067
# IoU: 0.5610
# Training Loss: 0.2082896582285563
# Validation Loss: 0.1829733078678449
# Epoch Training Duration: 00:00:49
#
# - EPOCH 27 -
# Dice: 0.6948
# IoU: 0.5465
# Training Loss: 0.20888810813426972
# Validation Loss: 0.18733818735927343
# Epoch Training Duration: 00:00:49
#
# - EPOCH 28 -
# Dice: 0.7073
# IoU: 0.5615
# Training Loss: 0.21437703549861908
# Validation Loss: 0.1889904021906356
# Epoch Training Duration: 00:00:49
#
# - EPOCH 29 -
# Dice: 0.7098
# IoU: 0.5644
# Training Loss: 0.21344727536042532
# Validation Loss: 0.18066396626333395
# Epoch Training Duration: 00:00:49
#
# - EPOCH 30 -
# Dice: 0.7078
# IoU: 0.5634
# Training Loss: 0.20547256549199422
# Validation Loss: 0.18530253553763032
# Epoch Training Duration: 00:00:48
#
# - EPOCH 31 -
# Dice: 0.7178
# IoU: 0.5742
# Training Loss: 0.20004525045553842
# Validation Loss: 0.18085261806845665
# Epoch Training Duration: 00:00:48
#
# - EPOCH 32 -
# Dice: 0.7177
# IoU: 0.5740
# Training Loss: 0.2000424861907959
# Validation Loss: 0.18107433337718248
# Epoch Training Duration: 00:00:48
#
# - EPOCH 33 -
# Dice: 0.7047
# IoU: 0.5595
# Training Loss: 0.20011662582556405
# Validation Loss: 0.18369510405076048
# Epoch Training Duration: 00:00:48
#
# - EPOCH 34 -
# Dice: 0.7223
# IoU: 0.5794
# Training Loss: 0.19915742337703704
# Validation Loss: 0.18493519133577743
# Epoch Training Duration: 00:00:48
#
# - EPOCH 35 -
# Dice: 0.7158
# IoU: 0.5725
# Training Loss: 0.20117890655994417
# Validation Loss: 0.18497036575960615
# Epoch Training Duration: 00:00:48
#
# - EPOCH 36 -
# Dice: 0.7315
# IoU: 0.5914
# Training Loss: 0.1982623165845871
# Validation Loss: 0.17926247169574103
# Epoch Training Duration: 00:00:49
#
# - EPOCH 37 -
# Dice: 0.7176
# IoU: 0.5747
# Training Loss: 0.19407099505265554
# Validation Loss: 0.1790629414220651
# Epoch Training Duration: 00:00:49
#
# - EPOCH 38 -
# Dice: 0.7131
# IoU: 0.5687
# Training Loss: 0.19587708135445914
# Validation Loss: 0.1901940101136764
# Epoch Training Duration: 00:00:49
#
# - EPOCH 39 -
# Dice: 0.7029
# IoU: 0.5557
# Training Loss: 0.19067145248254141
# Validation Loss: 0.18724527675658464
# Epoch Training Duration: 00:00:48
#
# - EPOCH 40 -
# Dice: 0.7112
# IoU: 0.5671
# Training Loss: 0.19328107754389445
# Validation Loss: 0.19060825509950519
# Epoch Training Duration: 00:00:48
#
# - EPOCH 41 -
# Dice: 0.7133
# IoU: 0.5683
# Training Loss: 0.1910127055644989
# Validation Loss: 0.1791892796754837
# Epoch Training Duration: 00:00:48
#
# - EPOCH 42 -
# Dice: 0.7032
# IoU: 0.5567
# Training Loss: 0.1911383173863093
# Validation Loss: 0.1883182873328527
# Epoch Training Duration: 00:00:48
#
# - EPOCH 43 -
# Dice: 0.7224
# IoU: 0.5802
# Training Loss: 0.19038789331912995
# Validation Loss: 0.18413750423739353
# Epoch Training Duration: 00:00:48
#
# - EPOCH 44 -
# Dice: 0.7263
# IoU: 0.5852
# Training Loss: 0.18832657019297283
# Validation Loss: 0.18480657506734133
# Epoch Training Duration: 00:00:48
#
# - EPOCH 45 -
# Dice: 0.7169
# IoU: 0.5729
# Training Loss: 0.18500279108683268
# Validation Loss: 0.18562762423728904
# Epoch Training Duration: 00:00:49
#
# - EPOCH 46 -
# Dice: 0.7286
# IoU: 0.5882
# Training Loss: 0.1826466715335846
# Validation Loss: 0.18815311145347854
# Epoch Training Duration: 00:00:49
#
# - EPOCH 47 -
# Dice: 0.7304
# IoU: 0.5893
# Training Loss: 0.1834239399433136
# Validation Loss: 0.18946593518679342
# Epoch Training Duration: 00:00:49
#
# - EPOCH 48 -
# Dice: 0.7233
# IoU: 0.5811
# Training Loss: 0.18121530830860139
# Validation Loss: 0.18667660591502985
# Epoch Training Duration: 00:00:48
#
# - EPOCH 49 -
# Dice: 0.7297
# IoU: 0.5895
# Training Loss: 0.17869885484377543
# Validation Loss: 0.1829213957923154
# Epoch Training Duration: 00:00:48
#
# - EPOCH 50 -
# Dice: 0.7120
# IoU: 0.5676
# Training Loss: 0.17734621663888295
# Validation Loss: 0.1810916685499251
# Epoch Training Duration: 00:00:48
#
# Total Training Duration for Threshold 0.6: 00:45:40
#
# -- TRAINING WITH THRESHOLD OF 0.7 --
#
# - EPOCH 1 -
# Dice: 0.5506
# IoU: 0.3933
# Training Loss: 0.3460047328472137
# Validation Loss: 0.21557121134052673
# Epoch Training Duration: 00:00:58
#
# - EPOCH 2 -
# Dice: 0.5162
# IoU: 0.3601
# Training Loss: 0.281842746535937
# Validation Loss: 0.22907999840875468
# Epoch Training Duration: 00:00:48
#
# - EPOCH 3 -
# Dice: 0.4881
# IoU: 0.3393
# Training Loss: 0.2765232030550639
# Validation Loss: 0.22351054024572173
# Epoch Training Duration: 00:00:48
#
# - EPOCH 4 -
# Dice: 0.5838
# IoU: 0.4262
# Training Loss: 0.26693866670131683
# Validation Loss: 0.20273366135855517
# Epoch Training Duration: 00:00:48
#
# - EPOCH 5 -
# Dice: 0.6186
# IoU: 0.4614
# Training Loss: 0.26191713035106656
# Validation Loss: 0.19449237656469145
# Epoch Training Duration: 00:00:48
#
# - EPOCH 6 -
# Dice: 0.5975
# IoU: 0.4392
# Training Loss: 0.25594873905181886
# Validation Loss: 0.2018627350529035
# Epoch Training Duration: 00:00:48
#
# - EPOCH 7 -
# Dice: 0.6231
# IoU: 0.4651
# Training Loss: 0.2521843061844508
# Validation Loss: 0.20014938929428658
# Epoch Training Duration: 00:00:48
#
# - EPOCH 8 -
# Dice: 0.6072
# IoU: 0.4495
# Training Loss: 0.2500848680734634
# Validation Loss: 0.19951510103419423
# Epoch Training Duration: 00:00:48
#
# - EPOCH 9 -
# Dice: 0.6091
# IoU: 0.4507
# Training Loss: 0.24767718533674876
# Validation Loss: 0.21106561242292324
# Epoch Training Duration: 00:00:49
#
# - EPOCH 10 -
# Dice: 0.5763
# IoU: 0.4177
# Training Loss: 0.24536286433537802
# Validation Loss: 0.2048846047061185
# Epoch Training Duration: 00:00:49
#
# - EPOCH 11 -
# Dice: 0.6550
# IoU: 0.5005
# Training Loss: 0.24202035228411356
# Validation Loss: 0.19076724955812097
# Epoch Training Duration: 00:00:49
#
# - EPOCH 12 -
# Dice: 0.6194
# IoU: 0.4631
# Training Loss: 0.23567596673965455
# Validation Loss: 0.1940664784051478
# Epoch Training Duration: 00:00:49
#
# - EPOCH 13 -
# Dice: 0.6762
# IoU: 0.5237
# Training Loss: 0.23409078478813172
# Validation Loss: 0.1963089656395217
# Epoch Training Duration: 00:00:49
#
# - EPOCH 14 -
# Dice: 0.5216
# IoU: 0.3646
# Training Loss: 0.23181173861026763
# Validation Loss: 0.20412830170243979
# Epoch Training Duration: 00:00:48
#
# - EPOCH 15 -
# Dice: 0.6578
# IoU: 0.5029
# Training Loss: 0.23269024709860484
# Validation Loss: 0.18831045972183347
# Epoch Training Duration: 00:00:48
#
# - EPOCH 16 -
# Dice: 0.6624
# IoU: 0.5088
# Training Loss: 0.22866155604521435
# Validation Loss: 0.1891492617626985
# Epoch Training Duration: 00:00:48
#
# - EPOCH 17 -
# Dice: 0.6605
# IoU: 0.5068
# Training Loss: 0.22736141562461853
# Validation Loss: 0.1915990567455689
# Epoch Training Duration: 00:00:49
#
# - EPOCH 18 -
# Dice: 0.6586
# IoU: 0.5039
# Training Loss: 0.22988801379998525
# Validation Loss: 0.18947970230753222
# Epoch Training Duration: 00:00:49
#
# - EPOCH 19 -
# Dice: 0.6614
# IoU: 0.5076
# Training Loss: 0.2246471377213796
# Validation Loss: 0.18134169622013965
# Epoch Training Duration: 00:00:49
#
# - EPOCH 20 -
# Dice: 0.5962
# IoU: 0.4375
# Training Loss: 0.21821132163206736
# Validation Loss: 0.19878160705169043
# Epoch Training Duration: 00:00:48
#
# - EPOCH 21 -
# Dice: 0.5824
# IoU: 0.4232
# Training Loss: 0.22352143069108327
# Validation Loss: 0.19531516109903654
# Epoch Training Duration: 00:00:48
#
# - EPOCH 22 -
# Dice: 0.6786
# IoU: 0.5271
# Training Loss: 0.22000917355219524
# Validation Loss: 0.1801451596741875
# Epoch Training Duration: 00:00:48
#
# - EPOCH 23 -
# Dice: 0.6759
# IoU: 0.5238
# Training Loss: 0.2128441160917282
# Validation Loss: 0.18622580900167426
# Epoch Training Duration: 00:00:48
#
# - EPOCH 24 -
# Dice: 0.6360
# IoU: 0.4790
# Training Loss: 0.2157113508383433
# Validation Loss: 0.1868557972678294
# Epoch Training Duration: 00:00:48
#
# - EPOCH 25 -
# Dice: 0.6927
# IoU: 0.5430
# Training Loss: 0.21211958348751067
# Validation Loss: 0.18738335526237884
# Epoch Training Duration: 00:00:48
#
# - EPOCH 26 -
# Dice: 0.6755
# IoU: 0.5233
# Training Loss: 0.2079557337363561
# Validation Loss: 0.1800435030212005
# Epoch Training Duration: 00:00:48
#
# - EPOCH 27 -
# Dice: 0.6989
# IoU: 0.5507
# Training Loss: 0.21099588294823965
# Validation Loss: 0.18211453578745326
# Epoch Training Duration: 00:00:48
#
# - EPOCH 28 -
# Dice: 0.6659
# IoU: 0.5123
# Training Loss: 0.20747686048348746
# Validation Loss: 0.17897941156600913
# Epoch Training Duration: 00:00:48
#
# - EPOCH 29 -
# Dice: 0.6744
# IoU: 0.5216
# Training Loss: 0.20698158005873363
# Validation Loss: 0.19511716968069473
# ...
# Epoch Training Duration: 00:00:49
#
# - EPOCH 42 -
# Dice: 0.6774
# IoU: 0.5258
# Training Loss: 0.19419974426428477
# Validation Loss: 0.18524910928681493
# Epoch Training Duration: 00:00:49
#
# - EPOCH 43 -
# Dice: 0.6747
# IoU: 0.5222
# Training Loss: 0.20621072749296823
# Validation Loss: 0.17869772234310707
# Epoch Training Duration: 00:00:48
#
# - EPOCH 44 -
# Dice: 0.7020
# IoU: 0.5550
# Training Loss: 0.19227899154027303
# Validation Loss: 0.18475598834144571
# Epoch Training Duration: 00:00:48
#
# - EPOCH 45 -
# Dice: 0.6865
# IoU: 0.5365
# Training Loss: 0.18883175114790599
# Validation Loss: 0.17437304525325695
# Epoch Training Duration: 00:00:48
#
# - EPOCH 46 -
# Dice: 0.6744
# IoU: 0.5217
# Training Loss: 0.18692796170711518
# Validation Loss: 0.1845757506477336
# Epoch Training Duration: 00:00:48
#
# - EPOCH 47 -
# Dice: 0.6907
# IoU: 0.5409
# Training Loss: 0.18645572582880657
# Validation Loss: 0.1878979361305634
# Epoch Training Duration: 00:00:49
#
# - EPOCH 48 -
# Dice: 0.6824
# IoU: 0.5312
# Training Loss: 0.18709080497423808
# Validation Loss: 0.18704877917965254
# Epoch Training Duration: 00:00:48
#
# - EPOCH 49 -
# Dice: 0.6981
# IoU: 0.5496
# Training Loss: 0.18458029826482136
# Validation Loss: 0.18999445469429097
# Epoch Training Duration: 00:00:49
#
# - EPOCH 50 -
# Dice: 0.6935
# IoU: 0.5432
# Training Loss: 0.18219385663668314
# Validation Loss: 0.17943028158818683
# Epoch Training Duration: 00:00:48
#
# Total Training Duration for Threshold 0.7: 00:45:34
#
# -- TRAINING WITH THRESHOLD OF 0.8 --
#
# - EPOCH 1 -
# Dice: 0.5882
# IoU: 0.4296
# Training Loss: 0.34425747136274976
# Validation Loss: 0.22075095462302366
# Epoch Training Duration: 00:00:55
#
# - EPOCH 2 -
# Dice: 0.5968
# IoU: 0.4369
# Training Loss: 0.2819141374031703
# Validation Loss: 0.22004510617504516
# Epoch Training Duration: 00:00:48
#
# - EPOCH 3 -
# Dice: 0.5806
# IoU: 0.4195
# Training Loss: 0.2678311105569204
# Validation Loss: 0.2148022816206018
# Epoch Training Duration: 00:00:49
#
# - EPOCH 4 -
# Dice: 0.5708
# IoU: 0.4120
# Training Loss: 0.26609326899051666
# Validation Loss: 0.21307534538209438
# Epoch Training Duration: 00:00:49
#
# - EPOCH 5 -
# Dice: 0.4344
# IoU: 0.2879
# Training Loss: 0.25986676673094433
# Validation Loss: 0.20257197987909117
# Epoch Training Duration: 00:00:48
#
# - EPOCH 6 -
# Dice: 0.5950
# IoU: 0.4371
# Training Loss: 0.25312713702519735
# Validation Loss: 0.2024429840967059
# Epoch Training Duration: 00:00:48
#
# - EPOCH 7 -
# Dice: 0.6326
# IoU: 0.4755
# Training Loss: 0.251927209297816
# Validation Loss: 0.20933134124303857
# Epoch Training Duration: 00:00:48
#
# - EPOCH 8 -
# Dice: 0.4610
# IoU: 0.3129
# Training Loss: 0.2452119521299998
# Validation Loss: 0.20345110772177577
# Epoch Training Duration: 00:00:48
#
# - EPOCH 9 -
# Dice: 0.5433
# IoU: 0.3867
# Training Loss: 0.24521310846010844
# Validation Loss: 0.1934065551807483
# Epoch Training Duration: 00:00:49
#
# - EPOCH 10 -
# Dice: 0.6327
# IoU: 0.4757
# Training Loss: 0.24230723857879638
# Validation Loss: 0.18873652629554272
# Epoch Training Duration: 00:00:49
#
# - EPOCH 11 -
# Dice: 0.6379
# IoU: 0.4817
# Training Loss: 0.23853328287601472
# Validation Loss: 0.18855632282793522
# Epoch Training Duration: 00:00:49
#
# - EPOCH 12 -
# Dice: 0.6498
# IoU: 0.4936
# Training Loss: 0.2355968733628591
# Validation Loss: 0.2156010034183661
# Epoch Training Duration: 00:00:49
#
# - EPOCH 13 -
# Dice: 0.5438
# IoU: 0.3854
# Training Loss: 0.231730441848437
# Validation Loss: 0.18991492595523596
# Epoch Training Duration: 00:00:48
#
# - EPOCH 14 -
# Dice: 0.5708
# IoU: 0.4092
# Training Loss: 0.23466133058071137
# Validation Loss: 0.1899159892151753
# Epoch Training Duration: 00:00:49
#
# - EPOCH 15 -
# Dice: 0.5846
# IoU: 0.4271
# Training Loss: 0.22797745207945505
# Validation Loss: 0.18395280977711082
# Epoch Training Duration: 00:00:48
#
# - EPOCH 16 -
# Dice: 0.5789
# IoU: 0.4193
# Training Loss: 0.2318649019797643
# Validation Loss: 0.19073056367536387
# Epoch Training Duration: 00:00:48
#
# - EPOCH 17 -
# Dice: 0.6358
# IoU: 0.4780
# Training Loss: 0.22076373020807902
# Validation Loss: 0.19258536025881767
# Epoch Training Duration: 00:00:49
#
# - EPOCH 18 -
# Dice: 0.5785
# IoU: 0.4189
# Training Loss: 0.22170959254105885
# Validation Loss: 0.18301049697523317
# Epoch Training Duration: 00:00:49
#
# - EPOCH 19 -
# Dice: 0.5873
# IoU: 0.4281
# Training Loss: 0.21948225637276966
# Validation Loss: 0.18180054907376567
# Epoch Training Duration: 00:00:49
#
# - EPOCH 20 -
# Dice: 0.6097
# IoU: 0.4505
# Training Loss: 0.21382201115290325
# Validation Loss: 0.1836633311274151
# Epoch Training Duration: 00:00:48
#
# - EPOCH 21 -
# Dice: 0.5838
# IoU: 0.4260
# Training Loss: 0.21834971646467843
# Validation Loss: 0.18511729020004472
# Epoch Training Duration: 00:00:48
#
# - EPOCH 22 -
# Dice: 0.6100
# IoU: 0.4510
# Training Loss: 0.2126142168045044
# Validation Loss: 0.18828837868447104
# Epoch Training Duration: 00:00:48
#
# - EPOCH 23 -
# Dice: 0.5991
# IoU: 0.4406
# Training Loss: 0.2120118792851766
# Validation Loss: 0.1859258369076997
# Epoch Training Duration: 00:00:48
#
# - EPOCH 24 -
# Dice: 0.6574
# IoU: 0.5035
# Training Loss: 0.21231643776098888
# Validation Loss: 0.18150427037229142
# Epoch Training Duration: 00:00:49
#
# - EPOCH 25 -
# Dice: 0.6443
# IoU: 0.4880
# Training Loss: 0.2130379823843638
# Validation Loss: 0.18079443741589785
# Epoch Training Duration: 00:00:49
#
# - EPOCH 26 -
# Dice: 0.6501
# IoU: 0.4951
# Training Loss: 0.20654803077379863
# Validation Loss: 0.17461548388625184
# Epoch Training Duration: 00:00:48
#
# - EPOCH 27 -
# Dice: 0.5643
# IoU: 0.4042
# Training Loss: 0.20915375689665477
# Validation Loss: 0.18621405384813747
# Epoch Training Duration: 00:00:48
#
# - EPOCH 28 -
# Dice: 0.6287
# IoU: 0.4715
# Training Loss: 0.2057824033498764
# Validation Loss: 0.17932577695076665
# Epoch Training Duration: 00:00:48
#
# - EPOCH 29 -
# Dice: 0.6020
# IoU: 0.4429
# Training Loss: 0.20501849631468455
# Validation Loss: 0.18170226008320847
# Epoch Training Duration: 00:00:48
#
# - EPOCH 30 -
# Dice: 0.6702
# IoU: 0.5190
# Training Loss: 0.21923750420411428
# Validation Loss: 0.18405740126036108
# Epoch Training Duration: 00:00:48
#
# - EPOCH 31 -
# Dice: 0.6124
# IoU: 0.4530
# Training Loss: 0.20417010207970937
# Validation Loss: 0.1841596090234816
# Epoch Training Duration: 00:00:48
#
# - EPOCH 32 -
# Dice: 0.6164
# IoU: 0.4579
# Training Loss: 0.20372056881586711
# Validation Loss: 0.18233664170838892
# Epoch Training Duration: 00:00:48
#
# - EPOCH 33 -
# Dice: 0.6103
# IoU: 0.4507
# Training Loss: 0.19773419797420502
# Validation Loss: 0.1853018873371184
# Epoch Training Duration: 00:00:48
#
# - EPOCH 34 -
# Dice: 0.5949
# IoU: 0.4358
# Training Loss: 0.19680883804957072
# Validation Loss: 0.17863883962854743
# Epoch Training Duration: 00:00:49
#
# - EPOCH 35 -
# Dice: 0.6388
# IoU: 0.4819
# Training Loss: 0.19869490146636962
# Validation Loss: 0.1825548093765974
# Epoch Training Duration: 00:00:48
#
# - EPOCH 36 -
# Dice: 0.5926
# IoU: 0.4333
# Training Loss: 0.19740781446297964
# Validation Loss: 0.1770808376992742
# Epoch Training Duration: 00:00:48
#
# - EPOCH 37 -
# Dice: 0.5919
# IoU: 0.4316
# Training Loss: 0.1941582018136978
# Validation Loss: 0.20037118919814625
# Epoch Training Duration: 00:00:49
#
# - EPOCH 38 -
# Dice: 0.6015
# IoU: 0.4424
# Training Loss: 0.19705667157967885
# Validation Loss: 0.18742174888029695
# Epoch Training Duration: 00:00:48
#
# - EPOCH 39 -
# Dice: 0.6386
# IoU: 0.4829
# Training Loss: 0.19391055683294933
# Validation Loss: 0.17942439415492117
# Epoch Training Duration: 00:00:48
#
# - EPOCH 40 -
# Dice: 0.6367
# IoU: 0.4804
# Training Loss: 0.19060218950112662
# Validation Loss: 0.17664798768237233
# Epoch Training Duration: 00:00:48
#
# - EPOCH 41 -
# Dice: 0.6590
# IoU: 0.5044
# Training Loss: 0.19135384599367777
# Validation Loss: 0.18294354574754834
# Epoch Training Duration: 00:00:48
#
# - EPOCH 42 -
# Dice: 0.6475
# IoU: 0.4916
# Training Loss: 0.18979598979155224
# Validation Loss: 0.17999814543873072
# Epoch Training Duration: 00:00:48
#
# - EPOCH 43 -
# Dice: 0.6105
# IoU: 0.4518
# Training Loss: 0.18931249062220257
# Validation Loss: 0.17735172901302576
# Epoch Training Duration: 00:00:49
#
# - EPOCH 44 -
# Dice: 0.6372
# IoU: 0.4793
# Training Loss: 0.18773009608189264
# Validation Loss: 0.183276634508123
# Epoch Training Duration: 00:00:50
#
# - EPOCH 45 -
# Dice: 0.6563
# IoU: 0.5007
# Training Loss: 0.1846661964058876
# Validation Loss: 0.1776319157021741
# Epoch Training Duration: 00:00:51
#
# - EPOCH 46 -
# Dice: 0.6321
# IoU: 0.4732
# Training Loss: 0.18570134103298186
# Validation Loss: 0.18054535814250508
# Epoch Training Duration: 00:00:51
#
# - EPOCH 47 -
# Dice: 0.6161
# IoU: 0.4566
# Training Loss: 0.1847164088487625
# Validation Loss: 0.17915064934641123
# Epoch Training Duration: 00:00:49
#
# - EPOCH 48 -
# Dice: 0.6393
# IoU: 0.4822
# Training Loss: 0.1845196505387624
# Validation Loss: 0.18726608265812197
# Epoch Training Duration: 00:00:49
#
# - EPOCH 49 -
# Dice: 0.6329
# IoU: 0.4736
# Training Loss: 0.1825230630238851
# Validation Loss: 0.18026011250913143
# Epoch Training Duration: 00:00:52
#
# - EPOCH 50 -
# Dice: 0.6671
# IoU: 0.5141
# Training Loss: 0.1801254677772522
# Validation Loss: 0.18413825193420053
# Epoch Training Duration: 00:00:52
#
# Total Training Duration for Threshold 0.8: 00:45:50
#
# -- TRAINING WITH THRESHOLD OF 0.9 --
#
# - EPOCH 1 -
# Dice: 0.4073
# IoU: 0.2665
# Training Loss: 0.345122034351031
# Validation Loss: 0.2224723200003306
# Epoch Training Duration: 00:01:10
#
# - EPOCH 2 -
# Dice: 0.4001
# IoU: 0.2553
# Training Loss: 0.28271610220273335
# Validation Loss: 0.20862531661987305
# Epoch Training Duration: 00:00:53
#
# - EPOCH 3 -
# Dice: 0.4339
# IoU: 0.2893
# Training Loss: 0.2690844359000524
# Validation Loss: 0.19938419852405787
# Epoch Training Duration: 00:00:53
#
# - EPOCH 4 -
# Dice: 0.2618
# IoU: 0.1539
# Training Loss: 0.2603280727068583
# Validation Loss: 0.20509324331457415
# Epoch Training Duration: 00:00:52
#
# - EPOCH 5 -
# Dice: 0.4881
# IoU: 0.3323
# Training Loss: 0.2597139177719752
# Validation Loss: 0.21468473939845958
# Epoch Training Duration: 00:00:52
#
# - EPOCH 6 -
# Dice: 0.4604
# IoU: 0.3083
# Training Loss: 0.25558157364527384
# Validation Loss: 0.19416176915789643
# Epoch Training Duration: 00:00:52
#
# - EPOCH 7 -
# Dice: 0.3487
# IoU: 0.2195
# Training Loss: 0.25347710092862447
# Validation Loss: 0.19143860352536043
# Epoch Training Duration: 00:00:52
#
# - EPOCH 8 -
# Dice: 0.3837
# IoU: 0.2452
# Training Loss: 0.24811173856258392
# Validation Loss: 0.1924479897134006
# Epoch Training Duration: 00:00:52
#
# - EPOCH 9 -
# Dice: 0.4440
# IoU: 0.2951
# Training Loss: 0.24970503389835358
# Validation Loss: 0.19436010314772525
# Epoch Training Duration: 00:00:53
#
# - EPOCH 10 -
# Dice: 0.3881
# IoU: 0.2483
# Training Loss: 0.2468128752708435
# Validation Loss: 0.19442332458371916
# Epoch Training Duration: 00:00:53
#
# - EPOCH 11 -
# Dice: 0.3994
# IoU: 0.2537
# Training Loss: 0.23874818940957387
# Validation Loss: 0.19893472533052167
# Epoch Training Duration: 00:00:53
#
# - EPOCH 12 -
# Dice: 0.3449
# IoU: 0.2160
# Training Loss: 0.23983220756053925
# Validation Loss: 0.1952891155766944
# Epoch Training Duration: 00:00:50
#
# - EPOCH 13 -
# Dice: 0.3587
# IoU: 0.2334
# Training Loss: 0.23623357772827147
# Validation Loss: 0.19541350845247507
# Epoch Training Duration: 00:00:52
#
# - EPOCH 14 -
# Dice: 0.2012
# IoU: 0.1147
# Training Loss: 0.23730117619037627
# Validation Loss: 0.19639769926046333
# Epoch Training Duration: 00:00:52
#
# - EPOCH 15 -
# Dice: 0.2686
# IoU: 0.1609
# Training Loss: 0.2312388002872467
# Validation Loss: 0.19084346015006304
# Epoch Training Duration: 00:00:53
#
# - EPOCH 16 -
# Dice: 0.5115
# IoU: 0.3576
# Training Loss: 0.22570355713367463
# Validation Loss: 0.18474375441049537
# Epoch Training Duration: 00:00:54
#
# - EPOCH 17 -
# Dice: 0.4754
# IoU: 0.3247
# Training Loss: 0.2254609650373459
# Validation Loss: 0.1833553776765863
# Epoch Training Duration: 00:00:49
#
# - EPOCH 18 -
# Dice: 0.5527
# IoU: 0.3938
# Training Loss: 0.22162939528624218
# Validation Loss: 0.1795783618775507
# Epoch Training Duration: 00:00:49
#
# - EPOCH 19 -
# Dice: 0.5278
# IoU: 0.3673
# Training Loss: 0.22867647449175516
# Validation Loss: 0.2123249595363935
# Epoch Training Duration: 00:00:48
#
# - EPOCH 20 -
# Dice: 0.4529
# IoU: 0.3058
# Training Loss: 0.21996767083803812
# Validation Loss: 0.18883200137255093
# Epoch Training Duration: 00:00:48
#
# - EPOCH 21 -
# Dice: 0.4794
# IoU: 0.3262
# Training Loss: 0.21472423255443573
# Validation Loss: 0.1816717148758471
# Epoch Training Duration: 00:00:49
#
# - EPOCH 22 -
# Dice: 0.4452
# IoU: 0.2961
# Training Loss: 0.21512903074423473
# Validation Loss: 0.18296871101483703
# Epoch Training Duration: 00:00:49
#
# - EPOCH 23 -
# Dice: 0.5306
# IoU: 0.3740
# Training Loss: 0.21378449161847432
# Validation Loss: 0.17698655696585774
# Epoch Training Duration: 00:00:48
#
# - EPOCH 24 -
# Dice: 0.5636
# IoU: 0.4022
# Training Loss: 0.20952492316563925
# Validation Loss: 0.21234111208468676
# Epoch Training Duration: 00:00:49
#
# - EPOCH 25 -
# Dice: 0.4925
# IoU: 0.3388
# Training Loss: 0.21102229615052542
# Validation Loss: 0.18137052205080786
# Epoch Training Duration: 00:00:49
#
# - EPOCH 26 -
# Dice: 0.3928
# IoU: 0.2517
# Training Loss: 0.20978954553604126
# Validation Loss: 0.1909537541990479
# Epoch Training Duration: 00:00:48
#
# - EPOCH 27 -
# Dice: 0.5160
# IoU: 0.3595
# Training Loss: 0.21143108427524568
# Validation Loss: 0.18460693707068762
# Epoch Training Duration: 00:00:48
#
# - EPOCH 28 -
# Dice: 0.4696
# IoU: 0.3169
# Training Loss: 0.20429456690947215
# Validation Loss: 0.18264247096764544
# Epoch Training Duration: 00:00:49
#
# - EPOCH 29 -
# Dice: 0.5841
# IoU: 0.4242
# Training Loss: 0.20388267894585926
# Validation Loss: 0.18330826393018165
# Epoch Training Duration: 00:00:50
#
# - EPOCH 30 -
# Dice: 0.4184
# IoU: 0.2708
# Training Loss: 0.20121272166570028
# Validation Loss: 0.17995721163849035
# Epoch Training Duration: 00:00:48
#
# - EPOCH 31 -
# Dice: 0.5713
# IoU: 0.4108
# Training Loss: 0.20181838711102804
# Validation Loss: 0.17953434446826577
# Epoch Training Duration: 00:00:48
#
# - EPOCH 32 -
# Dice: 0.4783
# IoU: 0.3215
# Training Loss: 0.19868206004301706
# Validation Loss: 0.17795911710709333
# Epoch Training Duration: 00:00:48
#
# - EPOCH 33 -
# Dice: 0.5172
# IoU: 0.3587
# Training Loss: 0.20128841718037924
# Validation Loss: 0.18008154832447568
# Epoch Training Duration: 00:00:48
#
# - EPOCH 34 -
# Dice: 0.5935
# IoU: 0.4333
# Training Loss: 0.19521422286828358
# Validation Loss: 0.18468993762508035
# Epoch Training Duration: 00:00:48
#
# - EPOCH 35 -
# Dice: 0.5345
# IoU: 0.3744
# Training Loss: 0.19641257007916768
# Validation Loss: 0.1807536605435113
# Epoch Training Duration: 00:00:48
#
# - EPOCH 36 -
# Dice: 0.4403
# IoU: 0.2895
# Training Loss: 0.20359442015488943
# Validation Loss: 0.1914443589436511
# Epoch Training Duration: 00:00:48
#
# - EPOCH 37 -
# Dice: 0.5159
# IoU: 0.3586
# Training Loss: 0.20742985467116037
# Validation Loss: 0.18507001223042607
# Epoch Training Duration: 00:00:48
#
# - EPOCH 38 -
# Dice: 0.5160
# IoU: 0.3575
# Training Loss: 0.19611923317114513
# Validation Loss: 0.18778220346818367
# Epoch Training Duration: 00:00:48
#
# - EPOCH 39 -
# Dice: 0.5152
# IoU: 0.3550
# Training Loss: 0.1930765343705813
# Validation Loss: 0.17836527526378632
# Epoch Training Duration: 00:00:48
#
# - EPOCH 40 -
# Dice: 0.5421
# IoU: 0.3813
# Training Loss: 0.19224555055300394
# Validation Loss: 0.18364059800903001
# Epoch Training Duration: 00:00:48
#
# - EPOCH 41 -
# Dice: 0.5412
# IoU: 0.3827
# Training Loss: 0.1923448449373245
# Validation Loss: 0.18949732650071383
# Epoch Training Duration: 00:00:48
#
# - EPOCH 42 -
# Dice: 0.4923
# IoU: 0.3336
# Training Loss: 0.18874161620934804
# Validation Loss: 0.17286845141400894
# Epoch Training Duration: 00:00:47
#
# - EPOCH 43 -
# Dice: 0.4481
# IoU: 0.2971
# Training Loss: 0.18848083198070525
# Validation Loss: 0.18365525966510177
# Epoch Training Duration: 00:00:47
#
# - EPOCH 44 -
# Dice: 0.5704
# IoU: 0.4092
# Training Loss: 0.1866727993885676
# Validation Loss: 0.18301538424566388
# Epoch Training Duration: 00:00:48
#
# - EPOCH 45 -
# Dice: 0.5681
# IoU: 0.4062
# Training Loss: 0.18639781296253205
# Validation Loss: 0.1816292884759605
# Epoch Training Duration: 00:00:48
#
# - EPOCH 46 -
# Dice: 0.4627
# IoU: 0.3095
# Training Loss: 0.18753341674804688
# Validation Loss: 0.18149851681664586
# Epoch Training Duration: 00:00:48
#
# - EPOCH 47 -
# Dice: 0.5195
# IoU: 0.3602
# Training Loss: 0.1827824173370997
# Validation Loss: 0.1820081522067388
# Epoch Training Duration: 00:00:48
#
# - EPOCH 48 -
# Dice: 0.5272
# IoU: 0.3669
# Training Loss: 0.18358391880989075
# Validation Loss: 0.1810267555216948
# Epoch Training Duration: 00:00:48
#
# - EPOCH 49 -
# Dice: 0.5495
# IoU: 0.3867
# Training Loss: 0.19406805992126464
# Validation Loss: 0.21070625446736813
# Epoch Training Duration: 00:00:48
#
# - EPOCH 50 -
# Dice: 0.5031
# IoU: 0.3449
# Training Loss: 0.19301970521608988
# Validation Loss: 0.1846960412027935
# Epoch Training Duration: 00:00:47
#
# Total Training Duration for Threshold 0.9: 00:46:53

# %% [markdown]
# # Plotting Statistics

# %% [markdown]
# Two main categories of statistics concerning the model are:
#
# * **Dice and IoU Scores** (plotted separately)
# * **Training and Validation Losses** (plotted together)

# %% [markdown]
# Plotting Dice and IoU.

# %%
def plot_metric(thresholds, scores, number_of_epochs, label, locator = False):
  fig, axes = plt.subplots(3, 3, figsize=(10, 10), sharey = True)
  axes = axes.flatten()

  for ax, threshold in zip(axes, thresholds):
    epochs = range(1, number_of_epochs + 1)
    ax.plot(epochs, scores[threshold], label = label)

    ax.set_xlabel('Epoch')
    ax.set_ylabel(label)
    ax.set_title(f'{label} | Threshold {threshold:.1f}')
    ax.legend()
    ax.grid(True)

    if locator:
      ax.yaxis.set_major_locator(MultipleLocator(0.05))

  plt.tight_layout()
  plt.show()

# %%
plot_metric(thresholds, all_dice_scores, number_of_epochs, 'Dice', True)
print()
plot_metric(thresholds, all_mean_iou_scores, number_of_epochs, 'IoU', True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Plotting Training and Validation losses.

# %%
def plot_losses(thresholds, all_train_losses, all_val_losses, number_of_epochs):
  fig, axes = plt.subplots(3, 3, figsize = (15, 10), sharey = True)
  axes = axes.flatten()

  for ax, threshold in zip(axes, thresholds):
    epochs = range(1, number_of_epochs + 1)
    ax.plot(epochs, all_train_losses[threshold], label = 'Training Loss')
    ax.plot(epochs, all_validation_losses[threshold], label = 'Validation Loss')

    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.set_title(f'Training and Validation Loss | Threshold {threshold:.1f}')
    ax.legend()
    ax.grid(True)

  plt.tight_layout()
  plt.show()

plot_losses(thresholds, all_train_losses, all_validation_losses, number_of_epochs)

# %% [markdown]
# # Downloading the Output – Predictions and Models

# %%
# !zip -r /predictions.zip /predictions
# !zip -r /models.zip /models

from google.colab import files

files.download("/predictions.zip")
files.download("/models.zip")
# Out:
#   adding: predictions/ (stored 0%)
#   adding: predictions/threshold_0.9/ (stored 0%)
#   adding: predictions/threshold_0.9/4.png (deflated 3%)
#   adding: predictions/threshold_0.9/predicted_11.png (deflated 6%)
#   adding: predictions/threshold_0.9/10.png (deflated 11%)
#   adding: predictions/threshold_0.9/7.png (deflated 5%)
#   adding: predictions/threshold_0.9/3.png (deflated 30%)
#   adding: predictions/threshold_0.9/predicted_9.png (deflated 57%)
#   adding: predictions/threshold_0.9/11.png (stored 0%)
#   adding: predictions/threshold_0.9/predicted_3.png (deflated 34%)
#   adding: predictions/threshold_0.9/predicted_7.png (deflated 9%)
#   adding: predictions/threshold_0.9/predicted_4.png (deflated 5%)
#   adding: predictions/threshold_0.9/predicted_8.png (deflated 9%)
#   adding: predictions/threshold_0.9/predicted_1.png (deflated 5%)
#   adding: predictions/threshold_0.9/1.png (deflated 3%)
#   adding: predictions/threshold_0.9/0.png (deflated 12%)
#   adding: predictions/threshold_0.9/9.png (deflated 56%)
#   adding: predictions/threshold_0.9/2.png (deflated 13%)
#   adding: predictions/threshold_0.9/predicted_2.png (deflated 10%)
#   adding: predictions/threshold_0.9/5.png (deflated 9%)
#   adding: predictions/threshold_0.9/predicted_5.png (deflated 7%)
#   adding: predictions/threshold_0.9/8.png (deflated 9%)
#   adding: predictions/threshold_0.9/predicted_10.png (deflated 15%)
#   adding: predictions/threshold_0.9/predicted_6.png (deflated 70%)
#   adding: predictions/threshold_0.9/6.png (deflated 64%)
#   adding: predictions/threshold_0.9/predicted_0.png (deflated 23%)
#   adding: predictions/threshold_0.5/ (stored 0%)
#   adding: predictions/threshold_0.5/4.png (deflated 3%)
#   adding: predictions/threshold_0.5/predicted_11.png (deflated 1%)
#   adding: predictions/threshold_0.5/10.png (deflated 11%)
#   adding: predictions/threshold_0.5/7.png (deflated 5%)
#   adding: predictions/threshold_0.5/3.png (deflated 30%)
#   adding: predictions/threshold_0.5/predicted_9.png (deflated 51%)
#   adding: predictions/threshold_0.5/11.png (stored 0%)
#   adding: predictions/threshold_0.5/predicted_3.png (deflated 29%)
#   adding: predictions/threshold_0.5/predicted_7.png (deflated 5%)
#   adding: predictions/threshold_0.5/predicted_4.png (deflated 2%)
#   adding: predictions/threshold_0.5/predicted_8.png (deflated 4%)
#   adding: predictions/threshold_0.5/predicted_1.png (deflated 2%)
#   adding: predictions/threshold_0.5/1.png (deflated 3%)
#   adding: predictions/threshold_0.5/0.png (deflated 12%)
#   adding: predictions/threshold_0.5/9.png (deflated 56%)
#   adding: predictions/threshold_0.5/2.png (deflated 13%)
#   adding: predictions/threshold_0.5/predicted_2.png (deflated 6%)
#   adding: predictions/threshold_0.5/5.png (deflated 9%)
#   adding: predictions/threshold_0.5/predicted_5.png (deflated 3%)
#   adding: predictions/threshold_0.5/8.png (deflated 9%)
#   adding: predictions/threshold_0.5/predicted_10.png (deflated 11%)
#   adding: predictions/threshold_0.5/predicted_6.png (deflated 68%)
#   adding: predictions/threshold_0.5/6.png (deflated 64%)
#   adding: predictions/threshold_0.5/predicted_0.png (deflated 14%)
#   adding: predictions/threshold_0.1/ (stored 0%)
#   adding: predictions/threshold_0.1/4.png (deflated 3%)
#   adding: predictions/threshold_0.1/predicted_11.png (stored 0%)
#   adding: predictions/threshold_0.1/10.png (deflated 11%)
#   adding: predictions/threshold_0.1/7.png (deflated 5%)
#   adding: predictions/threshold_0.1/3.png (deflated 30%)
#   adding: predictions/threshold_0.1/predicted_9.png (deflated 26%)
#   adding: predictions/threshold_0.1/11.png (stored 0%)
#   adding: predictions/threshold_0.1/predicted_3.png (deflated 17%)
#   adding: predictions/threshold_0.1/predicted_7.png (deflated 3%)
#   adding: predictions/threshold_0.1/predicted_4.png (deflated 1%)
#   adding: predictions/threshold_0.1/predicted_8.png (deflated 1%)
#   adding: predictions/threshold_0.1/predicted_1.png (deflated 1%)
#   adding: predictions/threshold_0.1/1.png (deflated 3%)
#   adding: predictions/threshold_0.1/0.png (deflated 12%)
#   adding: predictions/threshold_0.1/9.png (deflated 56%)
#   adding: predictions/threshold_0.1/2.png (deflated 13%)
#   adding: predictions/threshold_0.1/predicted_2.png (deflated 2%)
#   adding: predictions/threshold_0.1/5.png (deflated 9%)
#   adding: predictions/threshold_0.1/predicted_5.png (deflated 1%)
#   adding: predictions/threshold_0.1/8.png (deflated 9%)
#   adding: predictions/threshold_0.1/predicted_10.png (deflated 6%)
#   adding: predictions/threshold_0.1/predicted_6.png (deflated 36%)
#   adding: predictions/threshold_0.1/6.png (deflated 64%)
#   adding: predictions/threshold_0.1/predicted_0.png (deflated 9%)
#   adding: predictions/threshold_0.4/ (stored 0%)
#   adding: predictions/threshold_0.4/4.png (deflated 3%)
#   adding: predictions/threshold_0.4/predicted_11.png (deflated 1%)
#   adding: predictions/threshold_0.4/10.png (deflated 11%)
#   adding: predictions/threshold_0.4/7.png (deflated 5%)
#   adding: predictions/threshold_0.4/3.png (deflated 30%)
#   adding: predictions/threshold_0.4/predicted_9.png (deflated 48%)
#   adding: predictions/threshold_0.4/11.png (stored 0%)
#   adding: predictions/threshold_0.4/predicted_3.png (deflated 28%)
#   adding: predictions/threshold_0.4/predicted_7.png (deflated 5%)
#   adding: predictions/threshold_0.4/predicted_4.png (deflated 2%)
#   adding: predictions/threshold_0.4/predicted_8.png (deflated 3%)
#   adding: predictions/threshold_0.4/predicted_1.png (deflated 1%)
#   adding: predictions/threshold_0.4/1.png (deflated 3%)
#   adding: predictions/threshold_0.4/0.png (deflated 12%)
#   adding: predictions/threshold_0.4/9.png (deflated 56%)
#   adding: predictions/threshold_0.4/2.png (deflated 13%)
#   adding: predictions/threshold_0.4/predicted_2.png (deflated 5%)
#   adding: predictions/threshold_0.4/5.png (deflated 9%)
#   adding: predictions/threshold_0.4/predicted_5.png (deflated 2%)
#   adding: predictions/threshold_0.4/8.png (deflated 9%)
#   adding: predictions/threshold_0.4/predicted_10.png (deflated 11%)
#   adding: predictions/threshold_0.4/predicted_6.png (deflated 65%)
#   adding: predictions/threshold_0.4/6.png (deflated 64%)
#   adding: predictions/threshold_0.4/predicted_0.png (deflated 11%)
#   adding: predictions/threshold_0.6/ (stored 0%)
#   adding: predictions/threshold_0.6/4.png (deflated 3%)
#   adding: predictions/threshold_0.6/predicted_11.png (deflated 1%)
#   adding: predictions/threshold_0.6/10.png (deflated 11%)
#   adding: predictions/threshold_0.6/7.png (deflated 5%)
#   adding: predictions/threshold_0.6/3.png (deflated 30%)
#   adding: predictions/threshold_0.6/predicted_9.png (deflated 52%)
#   adding: predictions/threshold_0.6/11.png (stored 0%)
#   adding: predictions/threshold_0.6/predicted_3.png (deflated 30%)
#   adding: predictions/threshold_0.6/predicted_7.png (deflated 5%)
#   adding: predictions/threshold_0.6/predicted_4.png (deflated 2%)
#   adding: predictions/threshold_0.6/predicted_8.png (deflated 4%)
#   adding: predictions/threshold_0.6/predicted_1.png (deflated 2%)
#   adding: predictions/threshold_0.6/1.png (deflated 3%)
#   adding: predictions/threshold_0.6/0.png (deflated 12%)
#   adding: predictions/threshold_0.6/9.png (deflated 56%)
#   adding: predictions/threshold_0.6/2.png (deflated 13%)
#   adding: predictions/threshold_0.6/predicted_2.png (deflated 6%)
#   adding: predictions/threshold_0.6/5.png (deflated 9%)
#   adding: predictions/threshold_0.6/predicted_5.png (deflated 4%)
#   adding: predictions/threshold_0.6/8.png (deflated 9%)
#   adding: predictions/threshold_0.6/predicted_10.png (deflated 12%)
#   adding: predictions/threshold_0.6/predicted_6.png (deflated 68%)
#   adding: predictions/threshold_0.6/6.png (deflated 64%)
#   adding: predictions/threshold_0.6/predicted_0.png (deflated 14%)
#   adding: predictions/threshold_0.2/ (stored 0%)
#   adding: predictions/threshold_0.2/4.png (deflated 3%)
#   adding: predictions/threshold_0.2/predicted_11.png (deflated 1%)
#   adding: predictions/threshold_0.2/10.png (deflated 11%)
#   adding: predictions/threshold_0.2/7.png (deflated 5%)
#   adding: predictions/threshold_0.2/3.png (deflated 30%)
#   adding: predictions/threshold_0.2/predicted_9.png (deflated 42%)
#   adding: predictions/threshold_0.2/11.png (stored 0%)
#   adding: predictions/threshold_0.2/predicted_3.png (deflated 27%)
#   adding: predictions/threshold_0.2/predicted_7.png (deflated 5%)
#   adding: predictions/threshold_0.2/predicted_4.png (deflated 1%)
#   adding: predictions/threshold_0.2/predicted_8.png (deflated 2%)
#   adding: predictions/threshold_0.2/predicted_1.png (deflated 1%)
#   adding: predictions/threshold_0.2/1.png (deflated 3%)
#   adding: predictions/threshold_0.2/0.png (deflated 12%)
#   adding: predictions/threshold_0.2/9.png (deflated 56%)
#   adding: predictions/threshold_0.2/2.png (deflated 13%)
#   adding: predictions/threshold_0.2/predicted_2.png (deflated 3%)
#   adding: predictions/threshold_0.2/5.png (deflated 9%)
#   adding: predictions/threshold_0.2/predicted_5.png (deflated 1%)
#   adding: predictions/threshold_0.2/8.png (deflated 9%)
#   adding: predictions/threshold_0.2/predicted_10.png (deflated 11%)
#   adding: predictions/threshold_0.2/predicted_6.png (deflated 65%)
#   adding: predictions/threshold_0.2/6.png (deflated 64%)
#   adding: predictions/threshold_0.2/predicted_0.png (deflated 11%)
#   adding: predictions/threshold_0.3/ (stored 0%)
#   adding: predictions/threshold_0.3/4.png (deflated 3%)
#   adding: predictions/threshold_0.3/predicted_11.png (deflated 0%)
#   adding: predictions/threshold_0.3/10.png (deflated 11%)
#   adding: predictions/threshold_0.3/7.png (deflated 5%)
#   adding: predictions/threshold_0.3/3.png (deflated 30%)
#   adding: predictions/threshold_0.3/predicted_9.png (deflated 41%)
#   adding: predictions/threshold_0.3/11.png (stored 0%)
#   adding: predictions/threshold_0.3/predicted_3.png (deflated 24%)
#   adding: predictions/threshold_0.3/predicted_7.png (deflated 5%)
#   adding: predictions/threshold_0.3/predicted_4.png (deflated 1%)
#   adding: predictions/threshold_0.3/predicted_8.png (deflated 2%)
#   adding: predictions/threshold_0.3/predicted_1.png (deflated 1%)
#   adding: predictions/threshold_0.3/1.png (deflated 3%)
#   adding: predictions/threshold_0.3/0.png (deflated 12%)
#   adding: predictions/threshold_0.3/9.png (deflated 56%)
#   adding: predictions/threshold_0.3/2.png (deflated 13%)
#   adding: predictions/threshold_0.3/predicted_2.png (deflated 3%)
#   adding: predictions/threshold_0.3/5.png (deflated 9%)
#   adding: predictions/threshold_0.3/predicted_5.png (deflated 1%)
#   adding: predictions/threshold_0.3/8.png (deflated 9%)
#   adding: predictions/threshold_0.3/predicted_10.png (deflated 8%)
#   adding: predictions/threshold_0.3/predicted_6.png (deflated 44%)
#   adding: predictions/threshold_0.3/6.png (deflated 64%)
#   adding: predictions/threshold_0.3/predicted_0.png (deflated 10%)
#   adding: predictions/threshold_0.8/ (stored 0%)
#   adding: predictions/threshold_0.8/4.png (deflated 3%)
#   adding: predictions/threshold_0.8/predicted_11.png (deflated 3%)
#   adding: predictions/threshold_0.8/10.png (deflated 11%)
#   adding: predictions/threshold_0.8/7.png (deflated 5%)
#   adding: predictions/threshold_0.8/3.png (deflated 30%)
#   adding: predictions/threshold_0.8/predicted_9.png (deflated 57%)
#   adding: predictions/threshold_0.8/11.png (stored 0%)
#   adding: predictions/threshold_0.8/predicted_3.png (deflated 31%)
#   adding: predictions/threshold_0.8/predicted_7.png (deflated 5%)
#   adding: predictions/threshold_0.8/predicted_4.png (deflated 2%)
#   adding: predictions/threshold_0.8/predicted_8.png (deflated 6%)
#   adding: predictions/threshold_0.8/predicted_1.png (deflated 3%)
#   adding: predictions/threshold_0.8/1.png (deflated 3%)
#   adding: predictions/threshold_0.8/0.png (deflated 12%)
#   adding: predictions/threshold_0.8/9.png (deflated 56%)
#   adding: predictions/threshold_0.8/2.png (deflated 13%)
#   adding: predictions/threshold_0.8/predicted_2.png (deflated 8%)
#   adding: predictions/threshold_0.8/5.png (deflated 9%)
#   adding: predictions/threshold_0.8/predicted_5.png (deflated 5%)
#   adding: predictions/threshold_0.8/8.png (deflated 9%)
#   adding: predictions/threshold_0.8/predicted_10.png (deflated 12%)
#   adding: predictions/threshold_0.8/predicted_6.png (deflated 69%)
#   adding: predictions/threshold_0.8/6.png (deflated 64%)
#   adding: predictions/threshold_0.8/predicted_0.png (deflated 16%)
#   adding: predictions/threshold_0.7/ (stored 0%)
#   adding: predictions/threshold_0.7/4.png (deflated 3%)
#   adding: predictions/threshold_0.7/predicted_11.png (deflated 0%)
#   adding: predictions/threshold_0.7/10.png (deflated 11%)
#   adding: predictions/threshold_0.7/7.png (deflated 5%)
#   adding: predictions/threshold_0.7/3.png (deflated 30%)
#   adding: predictions/threshold_0.7/predicted_9.png (deflated 50%)
#   adding: predictions/threshold_0.7/11.png (stored 0%)
#   adding: predictions/threshold_0.7/predicted_3.png (deflated 29%)
#   adding: predictions/threshold_0.7/predicted_7.png (deflated 6%)
#   adding: predictions/threshold_0.7/predicted_4.png (deflated 2%)
#   adding: predictions/threshold_0.7/predicted_8.png (deflated 5%)
#   adding: predictions/threshold_0.7/predicted_1.png (deflated 2%)
#   adding: predictions/threshold_0.7/1.png (deflated 3%)
#   adding: predictions/threshold_0.7/0.png (deflated 12%)
#   adding: predictions/threshold_0.7/9.png (deflated 56%)
#   adding: predictions/threshold_0.7/2.png (deflated 13%)
#   adding: predictions/threshold_0.7/predicted_2.png (deflated 7%)
#   adding: predictions/threshold_0.7/5.png (deflated 9%)
#   adding: predictions/threshold_0.7/predicted_5.png (deflated 4%)
#   adding: predictions/threshold_0.7/8.png (deflated 9%)
#   adding: predictions/threshold_0.7/predicted_10.png (deflated 12%)
#   adding: predictions/threshold_0.7/predicted_6.png (deflated 63%)
#   adding: predictions/threshold_0.7/6.png (deflated 64%)
#   adding: predictions/threshold_0.7/predicted_0.png (deflated 16%)
#   adding: models/ (stored 0%)
#   adding: models/UNet_Threshold_0.3.pth (deflated 7%)
#   adding: models/UNet_Threshold_0.2.pth (deflated 7%)
#   adding: models/UNet_Threshold_0.8.pth (deflated 7%)
#   adding: models/UNet_Threshold_0.7.pth (deflated 7%)
#   adding: models/UNet_Threshold_0.9.pth (deflated 7%)
#   adding: models/UNet_Threshold_0.1.pth (deflated 7%)
#   adding: models/UNet_Threshold_0.4.pth (deflated 7%)
#   adding: models/UNet_Threshold_0.5.pth (deflated 7%)
#   adding: models/UNet_Threshold_0.6.pth (deflated 7%)

# %% [markdown]
# ## API ##

# %% [markdown]
# API should be used for testing purposes. A user may upload an image and get the mask of buildings back.
#
# **File segmentator.html must be added to the root folder for the API interface to work!**
#
# **Likewise, a model must be provided!**
#
# API selects the best model based on Dice score and passes user input to it in order to get the mask and display it to the user.

# %% [markdown]
# Use the link as the API interface.

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(5000)"))
# Out:
# https://cyg8kyiosvg-496ff2e9c6d22116-5000-colab.googleusercontent.com/

# %% [markdown]
# Selecting and loading the best model available.

# %%
# Get the threshold with highest Dice score
best_threshold = max(all_dice_scores, key = all_dice_scores.get)
best_dice_score = all_dice_scores[best_threshold][-1]

print(f'Best threshold: {best_threshold} with Dice score: {best_dice_score}')

# Load the appropriate model based on the highest Dice score
best_model = UNet(in_channels = 3, out_channels = 1).to(device)
model_path = f'../models/UNet_Threshold_{best_threshold}.pth'

best_model.load_state_dict(torch.load(model_path))
# Out:
# Best threshold: 0.4 with Dice score: 0.7486291776100794
# <All keys matched successfully>

# %% [markdown]
# Using Flask to handle user requests.

# %%
from flask import Flask, render_template, request
import torchvision.transforms as transforms
import io
import base64

app = Flask(__name__, template_folder='../')

@app.route('/', methods=['GET', 'POST'])
def index():
  original_image_base64 = None
  mask_base64 = None

  if request.method == 'POST':

    file = request.files['file']
    original_image = np.array(Image.open(file).convert("RGB"))

    transformed_image = validation_transform(image = original_image)['image']

    predicted_mask = best_model(torch.unsqueeze(transformed_image, 0).to(device))
    predicted_mask = torch.sigmoid(predicted_mask)
    predicted_mask = (predicted_mask > best_threshold).float().cpu().squeeze().numpy()

    mask_pil = transforms.ToPILImage()(predicted_mask)

    original_image_buffered = io.BytesIO()
    mask_buffered = io.BytesIO()

    Image.fromarray(original_image).save(original_image_buffered, format = "PNG")
    mask_pil.save(mask_buffered, format = "PNG")

    original_image_base64 = base64.b64encode(original_image_buffered.getvalue()).decode('utf-8')
    mask_base64 = base64.b64encode(mask_buffered.getvalue()).decode('utf-8')

  # Don't forget to upload segmentator.html to main folder!
  return render_template('segmentator.html', original_image = original_image_base64, mask = mask_base64)

if __name__ == "__main__":
  app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [17/May/2024 20:47:32] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/May/2024 20:47:33] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [17/May/2024 20:47:36] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/May/2024 20:47:38] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [17/May/2024 20:47:50] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/May/2024 20:47:52] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [17/May/2024 20:49:52] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/May/2024 20:49:54] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [17/May/2024 21:12:11] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/May/2024 21:12:13] "GET /favicon.ico HTTP/1.1" 404 -

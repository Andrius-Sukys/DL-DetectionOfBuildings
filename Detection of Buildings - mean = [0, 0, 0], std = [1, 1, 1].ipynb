# %% [markdown]
# # **Detection of Buildings (using mean = [0, 0, 0], std = [1, 1, 1])**
#
# #### **Team Bag – Andrius Šukys, Benas Skripkiūnas, Greta Virpšaitė**
#
# **The Objective.** The main purpose of the task was to create a UNet-based binary semantic segmentation model that would be able to recognize buildings in the given satellite pictures as accurately as possible.
#
# **The Process.** Two models were run in parallel:
# * one with common ImageNet weights of *`mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225]`* which in turn made it a fine-tuning task,
#
# * the other model was given weights of *`mean = [0, 0, 0], std = [1, 1, 1]`* to train the model from scratch.
#
# Both models were trained on thresholds from 0.1 to 0.9 (with step of 0.1) to determine which threshold works best for the aforementioned given weights. Then the models of both weight sets using their best threshold values were compared in practice using a test dataset.
#
# **The Results.** The results of the aforementioned process were analyzed in the final report.
#
# #### **The source codes and the final report of the project are all available on [GitHub](https://github.com/Andrius-Sukys/DL-DetectionOfBuildings).**
#
# #### **The datasets, predictions and output models due to their big size (GitHub does not allow to save them there) of the project are all available on [Google Drive](https://drive.google.com/drive/folders/1jMvX0dYo60M-s_ZaNAo_Fe_TC1f5Tut7?usp=sharing).**

# %% [markdown]
# # Setup of needed Modules and Libraries

# %%
from albumentations.pytorch import ToTensorV2
from matplotlib.ticker import MultipleLocator
from PIL import Image
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import albumentations as alb
import matplotlib.pyplot as plt
import numpy as np
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms.functional as F

# %% [markdown]
# # Mounting on Google Drive

# %% [markdown]
# In order to avoid having to upload the images and masks each time the project is run, they were placed in Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Getting the images and masks, testing if they were obtained correctly.

# %%
# Images and masks for training
train_image_dir = '/content/drive/My Drive/images/train'
train_mask_dir = '/content/drive/My Drive/masks/train'

# Images and masks for validation
validation_image_dir = '/content/drive/My Drive/images/validation'
validation_mask_dir = '/content/drive/My Drive/masks/validation'

# Function to print image names to ensure mounting works as expected
def print_image_names(image_dir, mask_dir):

  image_names = sorted(os.listdir(image_dir))
  mask_names = sorted(os.listdir(mask_dir))

  print(image_names)
  print(mask_names)

print("Training Set:")
print_image_names(train_image_dir, train_mask_dir)

print("\nValidation Set:")
print_image_names(validation_image_dir, validation_mask_dir)
# Out:
# Training Set:
# ['image_01.png', 'image_02.png', 'image_03.png', 'image_04.png', 'image_05.png', 'image_06.png', 'image_07.png', 'image_08.png', 'image_09.png', 'image_10.png', 'image_100.png', 'image_1000.png', 'image_1001.png', 'image_1002.png', 'image_1003.png', 'image_1004.png', 'image_1005.png', 'image_1006.png', 'image_1007.png', 'image_1008.png', 'image_1009.png', 'image_101.png', 'image_1010.png', 'image_1011.png', 'image_1012.png', 'image_1013.png', 'image_1014.png', 'image_1015.png', 'image_1016.png', 'image_1017.png', 'image_1018.png', 'image_1019.png', 'image_102.png', 'image_1020.png', 'image_1021.png', 'image_1022.png', 'image_1023.png', 'image_1024.png', 'image_1025.png', 'image_1026.png', 'image_1027.png', 'image_1028.png', 'image_1029.png', 'image_103.png', 'image_1030.png', 'image_1031.png', 'image_1032.png', 'image_1033.png', 'image_1034.png', 'image_1035.png', 'image_1036.png', 'image_1037.png', 'image_1038.png', 'image_1039.png', 'image_104.png', 'image_1040.png', 'image_1041.png', 'image_1042.png', 'image_1043.png', 'image_1044.png', 'image_1045.png', 'image_1046.png', 'image_1047.png', 'image_1048.png', 'image_1049.png', 'image_105.png', 'image_1050.png', 'image_1051.png', 'image_1052.png', 'image_1053.png', 'image_1054.png', 'image_1055.png', 'image_1056.png', 'image_1057.png', 'image_1058.png', 'image_1059.png', 'image_106.png', 'image_1060.png', 'image_1061.png', 'image_1062.png', 'image_1063.png', 'image_1064.png', 'image_1065.png', 'image_1066.png', 'image_1067.png', 'image_1068.png', 'image_1069.png', 'image_107.png', 'image_1070.png', 'image_1071.png', 'image_1072.png', 'image_1073.png', 'image_1074.png', 'image_1075.png', 'image_1076.png', 'image_1077.png', 'image_1078.png', 'image_1079.png', 'image_108.png', 'image_1080.png', 'image_1081.png', 'image_1082.png', 'image_1083.png', 'image_1084.png', 'image_1085.png', 'image_1086.png', 'image_1087.png', 'image_1088.png', 'image_1089.png', 'image_109.png', 'image_1090.png', 'image_1091.png', 'image_1092.png', 'image_1093.png', 'image_1094.png', 'image_1095.png', 'image_1096.png', 'image_1097.png', 'image_1098.png', 'image_1099.png', 'image_11.png', 'image_110.png', 'image_1100.png', 'image_1101.png', 'image_1102.png', 'image_1103.png', 'image_1104.png', 'image_1105.png', 'image_1106.png', 'image_1107.png', 'image_1108.png', 'image_1109.png', 'image_111.png', 'image_1110.png', 'image_1111.png', 'image_1112.png', 'image_1113.png', 'image_1114.png', 'image_1115.png', 'image_1116.png', 'image_1117.png', 'image_1118.png', 'image_1119.png', 'image_112.png', 'image_1120.png', 'image_1121.png', 'image_1122.png', 'image_1123.png', 'image_1124.png', 'image_1125.png', 'image_1126.png', 'image_1127.png', 'image_1128.png', 'image_1129.png', 'image_113.png', 'image_1130.png', 'image_1131.png', 'image_1132.png', 'image_1133.png', 'image_1134.png', 'image_1135.png', 'image_1136.png', 'image_1137.png', 'image_1138.png', 'image_1139.png', 'image_114.png', 'image_1140.png', 'image_1141.png', 'image_1142.png', 'image_1143.png', 'image_1144.png', 'image_1145.png', 'image_1146.png', 'image_1147.png', 'image_1148.png', 'image_1149.png', 'image_115.png', 'image_1150.png', 'image_1151.png', 'image_1152.png', 'image_1153.png', 'image_1154.png', 'image_1155.png', 'image_1156.png', 'image_1157.png', 'image_1158.png', 'image_1159.png', 'image_116.png', 'image_1160.png', 'image_1161.png', 'image_1162.png', 'image_1163.png', 'image_1164.png', 'image_1165.png', 'image_1166.png', 'image_1167.png', 'image_1168.png', 'image_1169.png', 'image_117.png', 'image_1170.png', 'image_1171.png', 'image_1172.png', 'image_1173.png', 'image_1174.png', 'image_1175.png', 'image_1176.png', 'image_1177.png', 'image_1178.png', 'image_1179.png', 'image_118.png', 'image_1180.png', 'image_1181.png', 'image_1182.png', 'image_1183.png', 'image_1184.png', 'image_1185.png', 'image_1186.png', 'image_1187.png', 'image_1188.png', 'image_1189.png', 'image_119.png', 'image_1190.png', 'image_1191.png', 'image_1192.png', 'image_11 ...
# ['mask_01.png', 'mask_02.png', 'mask_03.png', 'mask_04.png', 'mask_05.png', 'mask_06.png', 'mask_07.png', 'mask_08.png', 'mask_09.png', 'mask_10.png', 'mask_100.png', 'mask_1000.png', 'mask_1001.png', 'mask_1002.png', 'mask_1003.png', 'mask_1004.png', 'mask_1005.png', 'mask_1006.png', 'mask_1007.png', 'mask_1008.png', 'mask_1009.png', 'mask_101.png', 'mask_1010.png', 'mask_1011.png', 'mask_1012.png', 'mask_1013.png', 'mask_1014.png', 'mask_1015.png', 'mask_1016.png', 'mask_1017.png', 'mask_1018.png', 'mask_1019.png', 'mask_102.png', 'mask_1020.png', 'mask_1021.png', 'mask_1022.png', 'mask_1023.png', 'mask_1024.png', 'mask_1025.png', 'mask_1026.png', 'mask_1027.png', 'mask_1028.png', 'mask_1029.png', 'mask_103.png', 'mask_1030.png', 'mask_1031.png', 'mask_1032.png', 'mask_1033.png', 'mask_1034.png', 'mask_1035.png', 'mask_1036.png', 'mask_1037.png', 'mask_1038.png', 'mask_1039.png', 'mask_104.png', 'mask_1040.png', 'mask_1041.png', 'mask_1042.png', 'mask_1043.png', 'mask_1044.png', 'mask_1045.png', 'mask_1046.png', 'mask_1047.png', 'mask_1048.png', 'mask_1049.png', 'mask_105.png', 'mask_1050.png', 'mask_1051.png', 'mask_1052.png', 'mask_1053.png', 'mask_1054.png', 'mask_1055.png', 'mask_1056.png', 'mask_1057.png', 'mask_1058.png', 'mask_1059.png', 'mask_106.png', 'mask_1060.png', 'mask_1061.png', 'mask_1062.png', 'mask_1063.png', 'mask_1064.png', 'mask_1065.png', 'mask_1066.png', 'mask_1067.png', 'mask_1068.png', 'mask_1069.png', 'mask_107.png', 'mask_1070.png', 'mask_1071.png', 'mask_1072.png', 'mask_1073.png', 'mask_1074.png', 'mask_1075.png', 'mask_1076.png', 'mask_1077.png', 'mask_1078.png', 'mask_1079.png', 'mask_108.png', 'mask_1080.png', 'mask_1081.png', 'mask_1082.png', 'mask_1083.png', 'mask_1084.png', 'mask_1085.png', 'mask_1086.png', 'mask_1087.png', 'mask_1088.png', 'mask_1089.png', 'mask_109.png', 'mask_1090.png', 'mask_1091.png', 'mask_1092.png', 'mask_1093.png', 'mask_1094.png', 'mask_1095.png', 'mask_1096.png', 'mask_1097.png', 'mask_1098.png', 'mask_1099.png', 'mask_11.png', 'mask_110.png', 'mask_1100.png', 'mask_1101.png', 'mask_1102.png', 'mask_1103.png', 'mask_1104.png', 'mask_1105.png', 'mask_1106.png', 'mask_1107.png', 'mask_1108.png', 'mask_1109.png', 'mask_111.png', 'mask_1110.png', 'mask_1111.png', 'mask_1112.png', 'mask_1113.png', 'mask_1114.png', 'mask_1115.png', 'mask_1116.png', 'mask_1117.png', 'mask_1118.png', 'mask_1119.png', 'mask_112.png', 'mask_1120.png', 'mask_1121.png', 'mask_1122.png', 'mask_1123.png', 'mask_1124.png', 'mask_1125.png', 'mask_1126.png', 'mask_1127.png', 'mask_1128.png', 'mask_1129.png', 'mask_113.png', 'mask_1130.png', 'mask_1131.png', 'mask_1132.png', 'mask_1133.png', 'mask_1134.png', 'mask_1135.png', 'mask_1136.png', 'mask_1137.png', 'mask_1138.png', 'mask_1139.png', 'mask_114.png', 'mask_1140.png', 'mask_1141.png', 'mask_1142.png', 'mask_1143.png', 'mask_1144.png', 'mask_1145.png', 'mask_1146.png', 'mask_1147.png', 'mask_1148.png', 'mask_1149.png', 'mask_115.png', 'mask_1150.png', 'mask_1151.png', 'mask_1152.png', 'mask_1153.png', 'mask_1154.png', 'mask_1155.png', 'mask_1156.png', 'mask_1157.png', 'mask_1158.png', 'mask_1159.png', 'mask_116.png', 'mask_1160.png', 'mask_1161.png', 'mask_1162.png', 'mask_1163.png', 'mask_1164.png', 'mask_1165.png', 'mask_1166.png', 'mask_1167.png', 'mask_1168.png', 'mask_1169.png', 'mask_117.png', 'mask_1170.png', 'mask_1171.png', 'mask_1172.png', 'mask_1173.png', 'mask_1174.png', 'mask_1175.png', 'mask_1176.png', 'mask_1177.png', 'mask_1178.png', 'mask_1179.png', 'mask_118.png', 'mask_1180.png', 'mask_1181.png', 'mask_1182.png', 'mask_1183.png', 'mask_1184.png', 'mask_1185.png', 'mask_1186.png', 'mask_1187.png', 'mask_1188.png', 'mask_1189.png', 'mask_119.png', 'mask_1190.png', 'mask_1191.png', 'mask_1192.png', 'mask_1193.png', 'mask_1194.png', 'mask_1195.png', 'mask_1196.png', 'mask_1197.png', 'mask_1198.png', 'mask_1199.png', 'mask_12.png', 'mask_120.png', 'mask_1200.png', 'mask_121.png', 'mask_122.png', 'mask_123.png', 'mask_124.png', 'm ...
#
# Validation Set:
# ['image_1201.png', 'image_1202.png', 'image_1203.png', 'image_1204.png', 'image_1205.png', 'image_1206.png', 'image_1207.png', 'image_1208.png', 'image_1209.png', 'image_1210.png', 'image_1211.png', 'image_1212.png', 'image_1213.png', 'image_1214.png', 'image_1215.png', 'image_1216.png', 'image_1217.png', 'image_1218.png', 'image_1219.png', 'image_1220.png', 'image_1221.png', 'image_1222.png', 'image_1223.png', 'image_1224.png', 'image_1225.png', 'image_1226.png', 'image_1227.png', 'image_1228.png', 'image_1229.png', 'image_1230.png', 'image_1231.png', 'image_1232.png', 'image_1233.png', 'image_1234.png', 'image_1235.png', 'image_1236.png', 'image_1237.png', 'image_1238.png', 'image_1239.png', 'image_1240.png', 'image_1241.png', 'image_1242.png', 'image_1243.png', 'image_1244.png', 'image_1245.png', 'image_1246.png', 'image_1247.png', 'image_1248.png', 'image_1249.png', 'image_1250.png', 'image_1251.png', 'image_1252.png', 'image_1253.png', 'image_1254.png', 'image_1255.png', 'image_1256.png', 'image_1257.png', 'image_1258.png', 'image_1259.png', 'image_1260.png', 'image_1261.png', 'image_1262.png', 'image_1263.png', 'image_1264.png', 'image_1265.png', 'image_1266.png', 'image_1267.png', 'image_1268.png', 'image_1269.png', 'image_1270.png', 'image_1271.png', 'image_1272.png', 'image_1273.png', 'image_1274.png', 'image_1275.png', 'image_1276.png', 'image_1277.png', 'image_1278.png', 'image_1279.png', 'image_1280.png', 'image_1281.png', 'image_1282.png', 'image_1283.png', 'image_1284.png', 'image_1285.png', 'image_1286.png', 'image_1287.png', 'image_1288.png', 'image_1289.png', 'image_1290.png', 'image_1291.png', 'image_1292.png', 'image_1293.png', 'image_1294.png', 'image_1295.png', 'image_1296.png', 'image_1297.png', 'image_1298.png', 'image_1299.png', 'image_1300.png', 'image_1301.png', 'image_1302.png', 'image_1303.png', 'image_1304.png', 'image_1305.png', 'image_1306.png', 'image_1307.png', 'image_1308.png', 'image_1309.png', 'image_1310.png', 'image_1311.png', 'image_1312.png', 'image_1313.png', 'image_1314.png', 'image_1315.png', 'image_1316.png', 'image_1317.png', 'image_1318.png', 'image_1319.png', 'image_1320.png', 'image_1321.png', 'image_1322.png', 'image_1323.png', 'image_1324.png', 'image_1325.png', 'image_1326.png', 'image_1327.png', 'image_1328.png', 'image_1329.png', 'image_1330.png', 'image_1331.png', 'image_1332.png', 'image_1333.png', 'image_1334.png', 'image_1335.png', 'image_1336.png', 'image_1337.png', 'image_1338.png', 'image_1339.png', 'image_1340.png', 'image_1341.png', 'image_1342.png', 'image_1343.png', 'image_1344.png', 'image_1345.png', 'image_1346.png', 'image_1347.png', 'image_1348.png', 'image_1349.png', 'image_1350.png', 'image_1351.png', 'image_1352.png', 'image_1353.png', 'image_1354.png', 'image_1355.png', 'image_1356.png', 'image_1357.png', 'image_1358.png', 'image_1359.png', 'image_1360.png', 'image_1361.png', 'image_1362.png', 'image_1363.png', 'image_1364.png', 'image_1365.png', 'image_1366.png', 'image_1367.png', 'image_1368.png', 'image_1369.png', 'image_1370.png', 'image_1371.png', 'image_1372.png', 'image_1373.png', 'image_1374.png', 'image_1375.png', 'image_1376.png', 'image_1377.png']
# ['mask_1201.png', 'mask_1202.png', 'mask_1203.png', 'mask_1204.png', 'mask_1205.png', 'mask_1206.png', 'mask_1207.png', 'mask_1208.png', 'mask_1209.png', 'mask_1210.png', 'mask_1211.png', 'mask_1212.png', 'mask_1213.png', 'mask_1214.png', 'mask_1215.png', 'mask_1216.png', 'mask_1217.png', 'mask_1218.png', 'mask_1219.png', 'mask_1220.png', 'mask_1221.png', 'mask_1222.png', 'mask_1223.png', 'mask_1224.png', 'mask_1225.png', 'mask_1226.png', 'mask_1227.png', 'mask_1228.png', 'mask_1229.png', 'mask_1230.png', 'mask_1231.png', 'mask_1232.png', 'mask_1233.png', 'mask_1234.png', 'mask_1235.png', 'mask_1236.png', 'mask_1237.png', 'mask_1238.png', 'mask_1239.png', 'mask_1240.png', 'mask_1241.png', 'mask_1242.png', 'mask_1243.png', 'mask_1244.png', 'mask_1245.png', 'mask_1246.png', 'mask_1247.png', 'mask_1248.png', 'mask_1249.png', 'mask_1250.png', 'mask_1251.png', 'mask_1252.png', 'mask_1253.png', 'mask_1254.png', 'mask_1255.png', 'mask_1256.png', 'mask_1257.png', 'mask_1258.png', 'mask_1259.png', 'mask_1260.png', 'mask_1261.png', 'mask_1262.png', 'mask_1263.png', 'mask_1264.png', 'mask_1265.png', 'mask_1266.png', 'mask_1267.png', 'mask_1268.png', 'mask_1269.png', 'mask_1270.png', 'mask_1271.png', 'mask_1272.png', 'mask_1273.png', 'mask_1274.png', 'mask_1275.png', 'mask_1276.png', 'mask_1277.png', 'mask_1278.png', 'mask_1279.png', 'mask_1280.png', 'mask_1281.png', 'mask_1282.png', 'mask_1283.png', 'mask_1284.png', 'mask_1285.png', 'mask_1286.png', 'mask_1287.png', 'mask_1288.png', 'mask_1289.png', 'mask_1290.png', 'mask_1291.png', 'mask_1292.png', 'mask_1293.png', 'mask_1294.png', 'mask_1295.png', 'mask_1296.png', 'mask_1297.png', 'mask_1298.png', 'mask_1299.png', 'mask_1300.png', 'mask_1301.png', 'mask_1302.png', 'mask_1303.png', 'mask_1304.png', 'mask_1305.png', 'mask_1306.png', 'mask_1307.png', 'mask_1308.png', 'mask_1309.png', 'mask_1310.png', 'mask_1311.png', 'mask_1312.png', 'mask_1313.png', 'mask_1314.png', 'mask_1315.png', 'mask_1316.png', 'mask_1317.png', 'mask_1318.png', 'mask_1319.png', 'mask_1320.png', 'mask_1321.png', 'mask_1322.png', 'mask_1323.png', 'mask_1324.png', 'mask_1325.png', 'mask_1326.png', 'mask_1327.png', 'mask_1328.png', 'mask_1329.png', 'mask_1330.png', 'mask_1331.png', 'mask_1332.png', 'mask_1333.png', 'mask_1334.png', 'mask_1335.png', 'mask_1336.png', 'mask_1337.png', 'mask_1338.png', 'mask_1339.png', 'mask_1340.png', 'mask_1341.png', 'mask_1342.png', 'mask_1343.png', 'mask_1344.png', 'mask_1345.png', 'mask_1346.png', 'mask_1347.png', 'mask_1348.png', 'mask_1349.png', 'mask_1350.png', 'mask_1351.png', 'mask_1352.png', 'mask_1353.png', 'mask_1354.png', 'mask_1355.png', 'mask_1356.png', 'mask_1357.png', 'mask_1358.png', 'mask_1359.png', 'mask_1360.png', 'mask_1361.png', 'mask_1362.png', 'mask_1363.png', 'mask_1364.png', 'mask_1365.png', 'mask_1366.png', 'mask_1367.png', 'mask_1368.png', 'mask_1369.png', 'mask_1370.png', 'mask_1371.png', 'mask_1372.png', 'mask_1373.png', 'mask_1374.png', 'mask_1375.png', 'mask_1376.png', 'mask_1377.png']

# %% [markdown]
# Creating folders to store models and predicted masks that are downloaded later.

# %%
if not os.path.exists('../models/'):
  os.makedirs('../models/')

if not os.path.exists('../predictions/'):
  os.makedirs('../predictions/')

# %% [markdown]
# # Creation of Custom Dataset
#
# * __init__ takes the directories of images and masks as well as transformations that are applied onto them, then sorts the images and masks by names so they are aligned with each other as expected.
#
# * __len__ returns the total number of images in the dataset.
#
# * __getitem__ takes a pair of image and mask specified by index from given directories. Both the image and mask are opened as images, transformed into arrays and then converted to type of *float32* to ensure they work with the UNet model architecture. Finally, the same transformation is applied on both the image and the mask and this pair gets returned.

# %%
class CustomDataset(Dataset):
  def __init__(self,image_dir, mask_dir, transform):
    self.image_dir = image_dir
    self.mask_dir = mask_dir
    self.transform = transform

    self.image_paths = sorted(os.listdir(image_dir))
    self.mask_paths = sorted(os.listdir(mask_dir))

  def __len__(self):
    return len(self.image_paths)

  def __getitem__(self, index):
    image_path = os.path.join(self.image_dir, self.image_paths[index])
    mask_path = os.path.join(self.mask_dir, self.mask_paths[index])

    image = np.array(Image.open(image_path).convert('RGB')).astype(np.float32)
    mask = np.array(Image.open(mask_path).convert('L')).astype(bool).astype(np.float32)

    transformed = self.transform(image = image, mask = mask)

    return transformed['image'], transformed['mask']

# %% [markdown]
# # Transformations for both Training and Validation
#
# Transformations for both training and validation datasets are described.
#
# They differ as images in the validation dataset must only be resized to expected size, normalized and converted to tensor type.
#
# Other augmentations are not applied to keep the image as close to the actual input as possible .

# %%
# Set of transformations for training set
train_transform = alb.Compose([alb.Resize(height = 224, width = 224),
                               alb.Rotate(limit = 10, p = 0.5),
                               alb.HorizontalFlip(p = 0.5),
                               alb.Normalize(mean = [0, 0, 0], std = [1, 1, 1], max_pixel_value=255.0),
                               ToTensorV2()])

# Set of transformations for validation set
validation_transform = alb.Compose([alb.Resize(height = 224, width = 224),
                                    alb.Normalize(mean = [0, 0, 0], std = [1, 1, 1], max_pixel_value=255.0),
                                    ToTensorV2()])

# %% [markdown]
# # Model based on UNet Architecture

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Generally used to deepen the neural network for better performance
class DoubleConvolution(nn.Module):
  def __init__(self, in_channels, out_channels):
    super().__init__()

    # Double convolution as a sequence of operations applied to data
    self.double_conv = nn.Sequential(nn.Conv2d(in_channels, out_channels, kernel_size = 3, padding = 1), # 2D convolution
                                     nn.BatchNorm2d(out_channels), # Batch normalization
                                     nn.ReLU(inplace = True), # The original input is modified instead of creating a new tensor
                                     nn.Conv2d(out_channels, out_channels, kernel_size = 3, padding = 1), # 2D convolution
                                     nn.BatchNorm2d(out_channels), # Batch normalization
                                     nn.ReLU(inplace = True)) # The original input is modified instead of creating a new tensor

  def forward(self, x):
    return self.double_conv(x)

# Used to reduce the dimensions of input feature maps and increase receptive field
class DownSample(nn.Module):
  def __init__(self, in_channels, out_channels):
    super().__init__()

    # Performs max pooling and double convolution on reduced feature maps while increasing channels
    self.maxpool_conv = nn.Sequential(nn.MaxPool2d(2), DoubleConvolution(in_channels, out_channels))

  def forward(self, x):
    return self.maxpool_conv(x)

# Used to increase the dimensions of the downsampled feature maps
class UpSample(nn.Module):
  def __init__(self, in_channels, out_channels):
    super().__init__()

    # Used to increase the spatial dimensions of feature maps while decreasing the number of channels
    # The feature map grows twice each time because of kernel_size and stride but the channels get reduced
    self.up = nn.ConvTranspose2d(in_channels, in_channels // 2, kernel_size = 2, stride = 2)
    self.conv = DoubleConvolution(in_channels, out_channels)

  def forward(self, x1, x2):
    x1 = self.up(x1)

    # x2 is cropped to match the dimensions of x1
    # shape[1] is the number of channels, shape[2] is for height, shape[3] is for width
    x2 = F.center_crop(x2, [x1.shape[2], x1.shape[3]])

    # Combines both feature maps to preserve both deep and shallow level details, concatenated horizontally
    x1 = torch.cat([x2, x1], dim = 1)

    return self.conv(x1)

class UNet(nn.Module):
  def __init__(self, in_channels, out_channels):
    super(UNet, self).__init__()
    self.inc = (DoubleConvolution(in_channels, 64))
    self.down1 = (DownSample(64, 128))
    self.down2 = (DownSample(128, 256))
    self.down3 = (DownSample(256, 512))
    self.down4 = (DownSample(512, 1024))
    self.up1 = (UpSample(1024, 512))
    self.up2 = (UpSample(512, 256))
    self.up3 = (UpSample(256, 128))
    self.up4 = (UpSample(128, 64))
    # Used to decrease the number of channels so the kernel_size is 1
    self.outc = nn.Conv2d(64, out_channels, kernel_size = 1)

  def forward(self, x):
    x1 = self.inc(x)
    x2 = self.down1(x1)
    x3 = self.down2(x2)
    x4 = self.down3(x3)
    x5 = self.down4(x4)
    x = self.up1(x5, x4)
    x = self.up2(x, x3)
    x = self.up3(x, x2)
    x = self.up4(x, x1)
    logits = self.outc(x)
    return logits

# %% [markdown]
# # Initialization of Device
#
# Recommended to use GPU *(cuda:0)* for optimal performance.

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Used device type is', device)
# Out:
# Used device type is cuda:0

# %% [markdown]
# # Calculation of Statistics
#
# **Intersection over Union (IoU)**
#
# > $\text{IoU} = \frac{|A \cap B|}{|A \cup B|}$
#
# * Measures the overlap between two sets divided by their union.
# * Ranges from 0 to 1, where 0 indicates no overlap and 1 indicates perfect overlap.
# * Direct measure of overlapping.
# * Also known as Jaccard Index.
#
#
# **Dice**
#
# > $\text{Dice} = \frac{2|A \cap B|}{|A| + |B|}$
#
# * Measures the overlap between two sets.
# * Ranges from 0 to 1, where 0 indicates no overlap and 1 indicates perfect overlap.
# * Dice emphasizes the overlap between two sets more strongly because there is a 2 in the numerator, making it more sensitive to overlaps.
# * Practically the same as F1 score in the context of binary classification.

# %%
# Smooth is a small value that has litle impact, used to prevent division by zero

def iou(predictions, targets):
  smooth = 0.00001
  intersection = torch.sum(predictions * targets)
  union = torch.sum(predictions) + torch.sum(targets) - intersection
  iou = (intersection + smooth) / (union + smooth)
  return iou

def dice_coefficient(predictions, targets):
  smooth = 0.00001
  intersection = torch.sum(predictions * targets)
  union = torch.sum(predictions) + torch.sum(targets)
  dice = (2.0 * intersection + smooth) / (union + smooth)
  return dice

# %% [markdown]
# Used to calculate IoU and Dice using evaluation mode of the model.

# %%
def calculate_statistics(loader, model, threshold):
  dice_total = 0
  iou_total = 0
  all_predictions = []
  all_targets = []

  # Setting the model to evaluation mode
  model.eval()

  with torch.no_grad():
    for x, y in loader:
      # x is for the image, y is for the mask
      x = x.to(device)
      y = y.to(device).unsqueeze(1)

      # Sigmoid is used as it is a binary classification task
      predictions = torch.sigmoid(model(x))
      # Threshold is applied
      predictions = (predictions > threshold).float()

      # Calculating Dice and IoU
      dice_total += dice_coefficient(predictions, y).item()
      iou_total += iou(predictions, y).item()

      all_predictions.extend(predictions.cpu().numpy().flatten())
      all_targets.extend(y.cpu().numpy().flatten())

  dice = dice_total / len(loader)
  mean_iou = iou_total / len(loader)

  print(f"Dice: {dice:.4f}")
  print(f"IoU: {mean_iou:.4f}")

  # Setting the model back to training mode
  model.train()

  return dice, mean_iou

# %% [markdown]
# # Saving Predictions as Images
#
# In order to keep the document as concise as possible, images are saved to folder *predictions* instead of displaying them in the file.
#
# Each threshold has a dedicated folder so the list of folders inside predictions should go as follows:
#
# *   predictions/threshold_0.1
# *   predictions/threshold_0.2
# *   predictions/threshold_0.3
# *   predictions/threshold_0.4
# *   predictions/threshold_0.5
# *   predictions/threshold_0.6
# *   predictions/threshold_0.7
# *   predictions/threshold_0.8
# *   predictions/threshold_0.9
#
# In each folder, two groups of files are present:
#
# *   $x$.png, where $x$ is a number of the given (expected) mask set.
# *   $predicted\_x$.png, where $x$ is a number of the predicted mask set.
# *   So, for example, *1.png* is the set of expected masks for the first 16 images in the validation set, while *predicted_1.png* is the prediction of the model for these 16 images.
#
# Each image file should contain 16 images as it is the size of the loader.

# %%
def save_predictions_as_imgs(loader, model, folder, threshold):
  # Setting the model to evaluation mode
  model.eval()

  # x is for the image, y is for the mask
  for index, (x, y) in enumerate(loader):

    # Passing the image to device
    x = x.to(device)

    with torch.no_grad():

      # Sigmoid is used as it is a binary classification task
      predictions = torch.sigmoid(model(x))

      # Threshold is applied
      predictions = (predictions > threshold).float()

    # Saving both predicted and original masks so they can be compared later
    torchvision.utils.save_image(predictions, f"{folder}/predicted_{index}.png")
    torchvision.utils.save_image(y.unsqueeze(1), f"{folder}{index}.png")

  # Setting the model back to training mode
  model.train()

# %% [markdown]
# # Training Functions

# %% [markdown]
# Used to calculate validation loss.

# %%
def calculate_validation_loss(loader, model, loss_function):
  model.eval()
  val_losses = []

  with torch.no_grad():
    for x, y in loader:
      x = x.to(device)
      y = y.to(device).unsqueeze(1)

      predictions = model(x)
      loss = loss_function(predictions, y)
      val_losses.append(loss.item())

  avg_val_loss = sum(val_losses) / len(val_losses)

  return avg_val_loss

# %% [markdown]
# Used to train a single epoch.

# %%
def training_function(loader, model, optimizer, loss_function, scaler):
  model.train()
  train_losses = []

  for _, (data, targets) in enumerate(loader):
    data = data.to(device)
    targets = targets.float().unsqueeze(1).to(device)

    # Enables automatic casting to improve performance
    with torch.cuda.amp.autocast():
      predictions = model(data)
      # Calculates loss
      loss = loss_function(predictions, targets)

    # Clears gradients
    optimizer.zero_grad()
    # Scales the loss and computes the gradient of the loss
    scaler.scale(loss).backward()
    # Updates model parameters based on the calculated gradients
    scaler.step(optimizer)
    # Updates the scaler for the next iteration
    scaler.update()

    train_losses.append(loss.item())

  avg_train_loss = sum(train_losses) / len(train_losses)

  return avg_train_loss

# %% [markdown]
# The main training loop for all epochs.

# %%
def train_model(number_of_epochs, lr, model, threshold):
  loss_function = nn.BCEWithLogitsLoss() # Loss function specifically for binary segmentation
  optimizer = optim.Adam(model.parameters(), lr = lr)

  # Creating datasets and dataloaders
  train_dataset = CustomDataset(image_dir = train_image_dir, mask_dir = train_mask_dir, transform = train_transform)
  train_dataloader = DataLoader(train_dataset, batch_size = 16, shuffle = True)

  validation_dataset = CustomDataset(image_dir = validation_image_dir, mask_dir = validation_mask_dir, transform = validation_transform)
  validation_dataloader = DataLoader(validation_dataset, batch_size = 16, shuffle = False)

  scaler = torch.cuda.amp.GradScaler()

  train_losses = []
  validation_losses = []
  dice_scores = []
  mean_iou_scores = []
  epoch_times = []

  # Starting the timer to calculate total training time for a threshold
  total_start_time = time.time()

  for epoch in range(number_of_epochs):
    print(f"- EPOCH {epoch + 1} -")

    # Starting the timer to calculate training time for an epoch
    start_time = time.time()

    # Training the model
    train_loss = training_function(train_dataloader, model, optimizer, loss_function, scaler)
    train_losses.append(train_loss)

    # Calculating validation loss
    validation_loss = calculate_validation_loss(validation_dataloader, model, loss_function)
    validation_losses.append(validation_loss)

    # Calculating Dice and IoU
    dice, mean_iou = calculate_statistics(validation_dataloader, model, threshold)
    dice_scores.append(dice)
    mean_iou_scores.append(mean_iou)

    # Stopping the timer to calculate duration of training time for an epoch
    end_time = time.time()
    epoch_duration = end_time - start_time
    epoch_times.append(epoch_duration)

    # Converting seconds to more appropriate units of time
    hours, rem = divmod(epoch_duration, 3600)
    minutes, seconds = divmod(rem, 60)
    duration_str = f"{int(hours):02}:{int(minutes):02}:{int(seconds):02}"

    # Printing results for the epoch
    print("Training Loss:", train_loss)
    print("Validation Loss:", validation_loss)
    print("Epoch Training Duration:", duration_str)
    print()

    # Creating a folder to save predictions if it does not yet exist
    threshold_dir = f"../predictions/threshold_{threshold}/"
    if not os.path.exists(threshold_dir):
      os.makedirs(threshold_dir)

    # Saving these predictions in the folder
    save_predictions_as_imgs(validation_dataloader, model, threshold_dir, threshold)

    # If it is the last epoch
    if epoch == (number_of_epochs - 1):

      # Stopping the timer to calculate duration of total training time for a threshold
      total_end_time = time.time()
      total_duration = total_end_time - total_start_time

      # Converting seconds to more appropriate units of time
      total_hours, total_rem = divmod(total_duration, 3600)
      total_minutes, total_seconds = divmod(total_rem, 60)
      total_duration_str = f"{int(total_hours):02}:{int(total_minutes):02}:{int(total_seconds):02}"

      print(f"Total Training Duration for Threshold {threshold}:", total_duration_str)
      print()

      # Returning all of the relevant data to plot it later
      return train_losses, validation_losses, dice_scores, mean_iou_scores

# %% [markdown]
# # Training Cycle for each Threshold

# %% [markdown]
# Training parameters.

# %%
# Learning rate
lr = 0.001
number_of_epochs = 50

# Background threshold, goes from 0.1 to 0.9 with step of 0.1
thresholds = np.linspace(0.1, 0.9, num = 9)
thresholds = np.round(thresholds, 1)

# %% [markdown]
# Training loop.

# %%
# Dictionaries to store data for each threshold
all_dice_scores = {}
all_mean_iou_scores = {}
all_train_losses = {}
all_validation_losses = {}

# Training for each threshold
for index, threshold in enumerate(thresholds, start = 1):
  print(f'-- TRAINING WITH THRESHOLD OF {threshold:.1f} -- ')
  print()

  # Creating the model
  model = UNet(in_channels = 3, out_channels = 1).to(device)

  # Training the model
  train_losses, validation_losses, dice, mean_iou = train_model(number_of_epochs, lr, model, threshold)

  # Saving the model to a file
  torch.save(model.state_dict(), f'../models/UNet_Threshold_{threshold}.pth')

  # Adding the statistics for each threshold
  all_dice_scores[threshold] = dice
  all_mean_iou_scores[threshold] = mean_iou
  all_train_losses[threshold] = train_losses
  all_validation_losses[threshold] = validation_losses
# Out:
# -- TRAINING WITH THRESHOLD OF 0.1 --
#
# - EPOCH 1 -
# Dice: 0.5330
# IoU: 0.3704
# Training Loss: 0.34135374625523884
# Validation Loss: 0.2635711381832759
# Epoch Training Duration: 00:09:21
#
# - EPOCH 2 -
# Dice: 0.5463
# IoU: 0.3802
# Training Loss: 0.27593161940574645
# Validation Loss: 0.20576520171016455
# Epoch Training Duration: 00:00:48
#
# - EPOCH 3 -
# Dice: 0.5300
# IoU: 0.3665
# Training Loss: 0.2646187380949656
# Validation Loss: 0.21453569394846758
# Epoch Training Duration: 00:00:47
#
# - EPOCH 4 -
# Dice: 0.6055
# IoU: 0.4392
# Training Loss: 0.2609301002820333
# Validation Loss: 0.193377158138901
# Epoch Training Duration: 00:00:47
#
# - EPOCH 5 -
# Dice: 0.5380
# IoU: 0.3746
# Training Loss: 0.2604964182774226
# Validation Loss: 0.2271920886511604
# Epoch Training Duration: 00:00:48
#
# - EPOCH 6 -
# Dice: 0.6342
# IoU: 0.4696
# Training Loss: 0.2546696307261785
# Validation Loss: 0.19351220969110727
# Epoch Training Duration: 00:00:48
#
# - EPOCH 7 -
# Dice: 0.5584
# IoU: 0.3911
# Training Loss: 0.24756574153900146
# Validation Loss: 0.20127092705418667
# Epoch Training Duration: 00:00:48
#
# - EPOCH 8 -
# Dice: 0.4591
# IoU: 0.3030
# Training Loss: 0.24664014557997385
# Validation Loss: 0.2654882539063692
# Epoch Training Duration: 00:00:47
#
# - EPOCH 9 -
# Dice: 0.6477
# IoU: 0.4855
# Training Loss: 0.2397634075085322
# Validation Loss: 0.2032153794231514
# Epoch Training Duration: 00:00:47
#
# - EPOCH 10 -
# Dice: 0.4560
# IoU: 0.2997
# Training Loss: 0.2406263369321823
# Validation Loss: 0.2699789398660262
# Epoch Training Duration: 00:00:47
#
# - EPOCH 11 -
# Dice: 0.6263
# IoU: 0.4618
# Training Loss: 0.23794285317262015
# Validation Loss: 0.19438303199907145
# Epoch Training Duration: 00:00:47
#
# - EPOCH 12 -
# Dice: 0.5798
# IoU: 0.4160
# Training Loss: 0.23431024730205535
# Validation Loss: 0.19340556239088377
# Epoch Training Duration: 00:00:48
#
# - EPOCH 13 -
# Dice: 0.6552
# IoU: 0.4936
# Training Loss: 0.22887926697731018
# Validation Loss: 0.2054826853175958
# Epoch Training Duration: 00:00:47
#
# - EPOCH 14 -
# Dice: 0.6729
# IoU: 0.5138
# Training Loss: 0.22823171039422352
# Validation Loss: 0.18943604982147613
# Epoch Training Duration: 00:00:47
#
# - EPOCH 15 -
# Dice: 0.6127
# IoU: 0.4462
# Training Loss: 0.2277099907398224
# Validation Loss: 0.18643711740151048
# Epoch Training Duration: 00:00:47
#
# - EPOCH 16 -
# Dice: 0.6555
# IoU: 0.4941
# Training Loss: 0.22076872686545054
# Validation Loss: 0.18811286085595688
# Epoch Training Duration: 00:00:47
#
# - EPOCH 17 -
# Dice: 0.6456
# IoU: 0.4836
# Training Loss: 0.21912223021189373
# Validation Loss: 0.1891329356779655
# Epoch Training Duration: 00:00:47
#
# - EPOCH 18 -
# Dice: 0.6721
# IoU: 0.5140
# Training Loss: 0.219175852338473
# Validation Loss: 0.19736200260619322
# Epoch Training Duration: 00:00:47
#
# - EPOCH 19 -
# Dice: 0.5520
# IoU: 0.3852
# Training Loss: 0.21650989691416422
# Validation Loss: 0.2139505373003582
# Epoch Training Duration: 00:00:47
#
# - EPOCH 20 -
# Dice: 0.6594
# IoU: 0.4997
# Training Loss: 0.2133153643210729
# Validation Loss: 0.18866887766246995
# Epoch Training Duration: 00:00:47
#
# - EPOCH 21 -
# Dice: 0.7106
# IoU: 0.5621
# Training Loss: 0.2143628313144048
# Validation Loss: 0.27280152061333257
# Epoch Training Duration: 00:00:47
#
# - EPOCH 22 -
# Dice: 0.5992
# IoU: 0.4325
# Training Loss: 0.22180036544799805
# Validation Loss: 0.18672915222123265
# Epoch Training Duration: 00:00:47
#
# - EPOCH 23 -
# Dice: 0.6316
# IoU: 0.4669
# Training Loss: 0.21353061278661092
# Validation Loss: 0.18751135685791573
# Epoch Training Duration: 00:00:47
#
# - EPOCH 24 -
# Dice: 0.6741
# IoU: 0.5163
# Training Loss: 0.20884956061840057
# Validation Loss: 0.1860224918151895
# Epoch Training Duration: 00:00:47
#
# - EPOCH 25 -
# Dice: 0.6231
# IoU: 0.4582
# Training Loss: 0.21186932384967805
# Validation Loss: 0.19774766763051352
# Epoch Training Duration: 00:00:47
#
# - EPOCH 26 -
# Dice: 0.6680
# IoU: 0.5087
# Training Loss: 0.20606455544630686
# Validation Loss: 0.1863626631287237
# Epoch Training Duration: 00:00:47
#
# - EPOCH 27 -
# Dice: 0.6593
# IoU: 0.4992
# Training Loss: 0.20515208423137665
# Validation Loss: 0.1799730882048607
# Epoch Training Duration: 00:00:47
#
# - EPOCH 28 -
# Dice: 0.6667
# IoU: 0.5081
# Training Loss: 0.2018529599905014
# Validation Loss: 0.18165110362072787
# Epoch Training Duration: 00:00:47
#
# - EPOCH 29 -
# Dice: 0.6558
# IoU: 0.4946
# Training Loss: 0.20516657729943594
# Validation Loss: 0.1806951748828093
# Epoch Training Duration: 00:00:47
#
# - EPOCH 30 -
# Dice: 0.6775
# IoU: 0.5204
# Training Loss: 0.19988817711671195
# Validation Loss: 0.1858338168822229
# Epoch Training Duration: 00:00:47
#
# - EPOCH 31 -
# Dice: 0.6585
# IoU: 0.4968
# Training Loss: 0.19654681881268818
# Validation Loss: 0.18770974284658828
# Epoch Training Duration: 00:00:47
#
# - EPOCH 32 -
# Dice: 0.6702
# IoU: 0.5123
# Training Loss: 0.19708363791306813
# Validation Loss: 0.19409870511541763
# Epoch Training Duration: 00:00:47
#
# - EPOCH 33 -
# Dice: 0.6721
# IoU: 0.5142
# Training Loss: 0.19844432254632313
# Validation Loss: 0.18207708140835166
# Epoch Training Duration: 00:00:47
#
# - EPOCH 34 -
# Dice: 0.6940
# IoU: 0.5410
# Training Loss: 0.19705483357111614
# Validation Loss: 0.1882354679207007
# Epoch Training Duration: 00:00:47
#
# - EPOCH 35 -
# Dice: 0.6331
# IoU: 0.4692
# Training Loss: 0.195492399930954
# Validation Loss: 0.18731065094470978
# Epoch Training Duration: 00:00:47
#
# - EPOCH 36 -
# Dice: 0.5877
# IoU: 0.4206
# Training Loss: 0.19219858566919962
# Validation Loss: 0.18834476390232643
# Epoch Training Duration: 00:00:47
#
# - EPOCH 37 -
# Dice: 0.7121
# IoU: 0.5636
# Training Loss: 0.19209042449792227
# Validation Loss: 0.19191299068431059
# Epoch Training Duration: 00:00:47
#
# - EPOCH 38 -
# Dice: 0.6418
# IoU: 0.4797
# Training Loss: 0.19187070608139037
# Validation Loss: 0.18914170345912376
# Epoch Training Duration: 00:00:47
#
# - EPOCH 39 -
# Dice: 0.6863
# IoU: 0.5314
# Training Loss: 0.1916003523270289
# Validation Loss: 0.18246727840354046
# Epoch Training Duration: 00:00:47
#
# - EPOCH 40 -
# Dice: 0.7061
# IoU: 0.5560
# Training Loss: 0.18700533330440522
# Validation Loss: 0.18117212356689075
# Epoch Training Duration: 00:00:47
#
# - EPOCH 41 -
# Dice: 0.7095
# IoU: 0.5593
# Training Loss: 0.18595704555511475
# Validation Loss: 0.18718241977815828
# Epoch Training Duration: 00:00:47
#
# - EPOCH 42 -
# Dice: 0.6864
# IoU: 0.5319
# Training Loss: 0.1856958296895027
# Validation Loss: 0.1950947024549047
# Epoch Training Duration: 00:00:47
#
# - EPOCH 43 -
# Dice: 0.6984
# IoU: 0.5468
# Training Loss: 0.18616678635279338
# Validation Loss: 0.1989073365305861
# Epoch Training Duration: 00:00:47
#
# - EPOCH 44 -
# Dice: 0.7143
# IoU: 0.5665
# Training Loss: 0.18798412561416625
# Validation Loss: 0.20368389009187618
# Epoch Training Duration: 00:00:47
#
# - EPOCH 45 -
# Dice: 0.6615
# IoU: 0.5024
# Training Loss: 0.1820216808716456
# Validation Loss: 0.19003346717605987
# Epoch Training Duration: 00:00:47
#
# - EPOCH 46 -
# Dice: 0.6692
# IoU: 0.5096
# Training Loss: 0.1846767012278239
# Validation Loss: 0.18461836781352758
# Epoch Training Duration: 00:00:47
#
# - EPOCH 47 -
# Dice: 0.6892
# IoU: 0.5352
# Training Loss: 0.18234989643096924
# Validation Loss: 0.1970502637947599
# Epoch Training Duration: 00:00:47
#
# - EPOCH 48 -
# Dice: 0.6507
# IoU: 0.4886
# Training Loss: 0.1839036879936854
# Validation Loss: 0.1876366858681043
# Epoch Training Duration: 00:00:47
#
# - EPOCH 49 -
# Dice: 0.6398
# IoU: 0.4759
# Training Loss: 0.19437613427639008
# Validation Loss: 0.18154443614184856
# Epoch Training Duration: 00:00:47
#
# - EPOCH 50 -
# Dice: 0.6796
# IoU: 0.5239
# Training Loss: 0.18456658323605854
# Validation Loss: 0.17948607456249496
# Epoch Training Duration: 00:00:47
#
# Total Training Duration for Threshold 0.1: 00:52:56
#
# -- TRAINING WITH THRESHOLD OF 0.2 --
#
# - EPOCH 1 -
# Dice: 0.5594
# IoU: 0.3987
# Training Loss: 0.3353956337769826
# Validation Loss: 0.2248703616981705
# Epoch Training Duration: 00:00:54
#
# - EPOCH 2 -
# Dice: 0.6972
# IoU: 0.5461
# Training Loss: 0.2740731465816498
# Validation Loss: 0.216252699183921
# Epoch Training Duration: 00:00:47
#
# - EPOCH 3 -
# Dice: 0.4101
# IoU: 0.2638
# Training Loss: 0.26754014412562055
# Validation Loss: 0.33102521548668545
# Epoch Training Duration: 00:00:48
#
# - EPOCH 4 -
# Dice: 0.6219
# IoU: 0.4568
# Training Loss: 0.26237182358900707
# Validation Loss: 0.20460509695112705
# Epoch Training Duration: 00:00:48
#
# - EPOCH 5 -
# Dice: 0.6815
# IoU: 0.5264
# Training Loss: 0.255134538213412
# Validation Loss: 0.2037494626517097
# Epoch Training Duration: 00:00:47
#
# - EPOCH 6 -
# Dice: 0.6683
# IoU: 0.5092
# Training Loss: 0.25741991500059763
# Validation Loss: 0.2019952692401906
# Epoch Training Duration: 00:00:47
#
# - EPOCH 7 -
# Dice: 0.6692
# IoU: 0.5094
# Training Loss: 0.2564738694826762
# Validation Loss: 0.19325070347016057
# Epoch Training Duration: 00:00:47
#
# - EPOCH 8 -
# Dice: 0.6752
# IoU: 0.5174
# Training Loss: 0.2532977499564489
# Validation Loss: 0.19255481753498316
# Epoch Training Duration: 00:00:47
#
# - EPOCH 9 -
# Dice: 0.6625
# IoU: 0.5029
# Training Loss: 0.2492800537745158
# Validation Loss: 0.20142784963051477
# Epoch Training Duration: 00:00:47
#
# - EPOCH 10 -
# Dice: 0.5620
# IoU: 0.3952
# Training Loss: 0.24305877645810445
# Validation Loss: 0.213910692371428
# Epoch Training Duration: 00:00:47
#
# - EPOCH 11 -
# Dice: 0.6787
# IoU: 0.5212
# Training Loss: 0.23880377888679505
# Validation Loss: 0.18994400510564446
# Epoch Training Duration: 00:00:47
#
# - EPOCH 12 -
# Dice: 0.6483
# IoU: 0.4864
# Training Loss: 0.2347470086812973
# Validation Loss: 0.1966741761813561
# Epoch Training Duration: 00:00:47
#
# - EPOCH 13 -
# Dice: 0.6648
# IoU: 0.5049
# Training Loss: 0.23785460114479065
# Validation Loss: 0.19456292844067016
# Epoch Training Duration: 00:00:48
#
# - EPOCH 14 -
# Dice: 0.6121
# IoU: 0.4462
# Training Loss: 0.23081618746121724
# Validation Loss: 0.20150764239951968
# Epoch Training Duration: 00:00:47
#
# - EPOCH 15 -
# Dice: 0.7080
# IoU: 0.5597
# Training Loss: 0.23168220440546672
# Validation Loss: 0.19763676449656487
# Epoch Training Duration: 00:00:47
#
# - EPOCH 16 -
# Dice: 0.6694
# IoU: 0.5096
# Training Loss: 0.2264987510442734
# Validation Loss: 0.18989394589637718
# Epoch Training Duration: 00:00:47
#
# - EPOCH 17 -
# Dice: 0.6869
# IoU: 0.5331
# Training Loss: 0.22217070440451303
# Validation Loss: 0.1868894180903832
# Epoch Training Duration: 00:00:47
#
# - EPOCH 18 -
# Dice: 0.6563
# IoU: 0.4948
# Training Loss: 0.22033472816149394
# Validation Loss: 0.1912210782368978
# Epoch Training Duration: 00:00:47
#
# - EPOCH 19 -
# Dice: 0.6316
# IoU: 0.4676
# Training Loss: 0.22083769261837005
# Validation Loss: 0.19906857796013355
# Epoch Training Duration: 00:00:47
#
# - EPOCH 20 -
# Dice: 0.7168
# IoU: 0.5698
# Training Loss: 0.21557053407033286
# Validation Loss: 0.1819212225576242
# Epoch Training Duration: 00:00:47
#
# - EPOCH 21 -
# Dice: 0.7148
# IoU: 0.5670
# Training Loss: 0.21843938847382863
# Validation Loss: 0.20624162380894026
# Epoch Training Duration: 00:00:47
#
# - EPOCH 22 -
# Dice: 0.7097
# IoU: 0.5609
# Training Loss: 0.21226335783799488
# Validation Loss: 0.1896012251575788
# Epoch Training Duration: 00:00:47
#
# - EPOCH 23 -
# Dice: 0.7077
# IoU: 0.5567
# Training Loss: 0.21534848709901175
# Validation Loss: 0.18138663300002614
# Epoch Training Duration: 00:00:48
#
# - EPOCH 24 -
# Dice: 0.6807
# IoU: 0.5238
# Training Loss: 0.21974908192952475
# Validation Loss: 0.19566749300186834
# Epoch Training Duration: 00:00:47
#
# - EPOCH 25 -
# Dice: 0.6924
# IoU: 0.5385
# Training Loss: 0.21222834090391796
# Validation Loss: 0.19170821566755572
# Epoch Training Duration: 00:00:47
#
# - EPOCH 26 -
# Dice: 0.7118
# IoU: 0.5629
# Training Loss: 0.20901346166928608
# Validation Loss: 0.183919467497617
# Epoch Training Duration: 00:00:47
#
# - EPOCH 27 -
# Dice: 0.7162
# IoU: 0.5687
# Training Loss: 0.20492811878522238
# Validation Loss: 0.1890476274614533
# Epoch Training Duration: 00:00:47
#
# - EPOCH 28 -
# Dice: 0.7218
# IoU: 0.5758
# Training Loss: 0.20583945135275522
# Validation Loss: 0.1972816016835471
# Epoch Training Duration: 00:00:47
#
# - EPOCH 29 -
# Dice: 0.7119
# IoU: 0.5642
# Training Loss: 0.20588161766529084
# Validation Loss: 0.20233360732284686
# Epoch Training Duration: 00:00:47
#
# - EPOCH 30 -
# Dice: 0.7202
# IoU: 0.5738
# Training Loss: 0.20273543337980907
# Validation Loss: 0.18709462648257613
# Epoch Training Duration: 00:00:47
#
# - EPOCH 31 -
# Dice: 0.6776
# IoU: 0.5202
# Training Loss: 0.2012257464726766
# Validation Loss: 0.20248226386805376
# Epoch Training Duration: 00:00:47
#
# - EPOCH 32 -
# Dice: 0.6345
# IoU: 0.4703
# Training Loss: 0.20223709424336753
# Validation Loss: 0.204265176008145
# Epoch Training Duration: 00:00:48
#
# - EPOCH 33 -
# Dice: 0.6688
# IoU: 0.5094
# Training Loss: 0.20214424630006153
# Validation Loss: 0.19057488550121585
# Epoch Training Duration: 00:00:47
#
# - EPOCH 34 -
# Dice: 0.7087
# IoU: 0.5591
# Training Loss: 0.19905923068523407
# Validation Loss: 0.18288047751411796
# Epoch Training Duration: 00:00:47
#
# - EPOCH 35 -
# Dice: 0.7132
# IoU: 0.5642
# Training Loss: 0.19567169686158498
# Validation Loss: 0.17958515665183464
# Epoch Training Duration: 00:00:47
#
# - EPOCH 36 -
# Dice: 0.7327
# IoU: 0.5896
# Training Loss: 0.19630278607209523
# Validation Loss: 0.19682287129883966
# Epoch Training Duration: 00:00:47
#
# - EPOCH 37 -
# Dice: 0.7215
# IoU: 0.5755
# Training Loss: 0.1953920167684555
# Validation Loss: 0.19814406599228582
# Epoch Training Duration: 00:00:47
#
# - EPOCH 38 -
# Dice: 0.6821
# IoU: 0.5249
# Training Loss: 0.19391270677248637
# Validation Loss: 0.1829601749777794
# Epoch Training Duration: 00:00:47
#
# - EPOCH 39 -
# Dice: 0.7381
# IoU: 0.5972
# Training Loss: 0.19693832159042357
# Validation Loss: 0.1889418801292777
# Epoch Training Duration: 00:00:47
#
# - EPOCH 40 -
# Dice: 0.7319
# IoU: 0.5889
# Training Loss: 0.19466343482335408
# Validation Loss: 0.18491283959398666
# Epoch Training Duration: 00:00:47
#
# - EPOCH 41 -
# Dice: 0.7120
# IoU: 0.5619
# Training Loss: 0.1882759557167689
# Validation Loss: 0.1756263131586214
# Epoch Training Duration: 00:00:47
#
# - EPOCH 42 -
# Dice: 0.7324
# IoU: 0.5887
# Training Loss: 0.1888051281372706
# Validation Loss: 0.19141082170729837
# Epoch Training Duration: 00:00:47
#
# - EPOCH 43 -
# Dice: 0.7200
# IoU: 0.5737
# Training Loss: 0.18897763033707937
# Validation Loss: 0.1905757999047637
# Epoch Training Duration: 00:00:47
#
# - EPOCH 44 -
# Dice: 0.7238
# IoU: 0.5789
# Training Loss: 0.1901183158159256
# Validation Loss: 0.18499338471641144
# Epoch Training Duration: 00:00:47
#
# - EPOCH 45 -
# Dice: 0.6963
# IoU: 0.5419
# Training Loss: 0.18365677138169606
# Validation Loss: 0.18322347306335965
# Epoch Training Duration: 00:00:46
#
# - EPOCH 46 -
# Dice: 0.7199
# IoU: 0.5731
# Training Loss: 0.18231657306353252
# Validation Loss: 0.18168562153975168
# Epoch Training Duration: 00:00:47
#
# - EPOCH 47 -
# Dice: 0.7303
# IoU: 0.5864
# Training Loss: 0.18252813339233398
# Validation Loss: 0.18963253498077393
# Epoch Training Duration: 00:00:46
#
# - EPOCH 48 -
# Dice: 0.7011
# IoU: 0.5481
# Training Loss: 0.1819294766585032
# Validation Loss: 0.18824961502104998
# Epoch Training Duration: 00:00:47
#
# - EPOCH 49 -
# Dice: 0.7268
# IoU: 0.5809
# Training Loss: 0.18101976414521534
# Validation Loss: 0.18646123399958014
# Epoch Training Duration: 00:00:47
#
# - EPOCH 50 -
# Dice: 0.6422
# IoU: 0.4794
# Training Loss: 0.1794431757926941
# Validation Loss: 0.21689919040848812
# Epoch Training Duration: 00:00:48
#
# Total Training Duration for Threshold 0.2: 00:44:26
#
# -- TRAINING WITH THRESHOLD OF 0.3 --
#
# - EPOCH 1 -
# Dice: 0.5206
# IoU: 0.3637
# Training Loss: 0.34219950159390766
# Validation Loss: 0.30075879395008087
# Epoch Training Duration: 00:00:54
#
# - EPOCH 2 -
# Dice: 0.6625
# IoU: 0.5048
# Training Loss: 0.28421634833017984
# Validation Loss: 0.21660441967348257
# Epoch Training Duration: 00:00:46
#
# - EPOCH 3 -
# Dice: 0.6589
# IoU: 0.5001
# Training Loss: 0.27471773107846575
# Validation Loss: 0.21240233505765596
# Epoch Training Duration: 00:00:47
#
# - EPOCH 4 -
# Dice: 0.5165
# IoU: 0.3568
# Training Loss: 0.2642594655354818
# Validation Loss: 0.2925533540546894
# Epoch Training Duration: 00:00:47
#
# - EPOCH 5 -
# Dice: 0.5755
# IoU: 0.4107
# Training Loss: 0.2583931424220403
# Validation Loss: 0.251608669757843
# Epoch Training Duration: 00:00:47
#
# - EPOCH 6 -
# Dice: 0.6835
# IoU: 0.5269
# Training Loss: 0.2541186328728994
# Validation Loss: 0.20076683846612772
# Epoch Training Duration: 00:00:47
#
# - EPOCH 7 -
# Dice: 0.6665
# IoU: 0.5067
# Training Loss: 0.25370008846124015
# Validation Loss: 0.20392767852172256
# Epoch Training Duration: 00:00:47
#
# - EPOCH 8 -
# Dice: 0.6879
# IoU: 0.5329
# Training Loss: 0.2543721596399943
# Validation Loss: 0.19622229939947525
# Epoch Training Duration: 00:00:47
#
# - EPOCH 9 -
# Dice: 0.5306
# IoU: 0.3695
# Training Loss: 0.24547508080800373
# Validation Loss: 0.25116046518087387
# Epoch Training Duration: 00:00:47
#
# - EPOCH 10 -
# Dice: 0.6936
# IoU: 0.5425
# Training Loss: 0.24452831784884135
# Validation Loss: 0.2159271965113779
# Epoch Training Duration: 00:00:47
#
# - EPOCH 11 -
# Dice: 0.6516
# IoU: 0.4902
# Training Loss: 0.2368298671642939
# Validation Loss: 0.20578229473903775
# Epoch Training Duration: 00:00:47
#
# - EPOCH 12 -
# Dice: 0.6125
# IoU: 0.4479
# Training Loss: 0.238009894490242
# Validation Loss: 0.23176571913063526
# Epoch Training Duration: 00:00:47
#
# - EPOCH 13 -
# Dice: 0.7193
# IoU: 0.5744
# Training Loss: 0.23490149199962615
# Validation Loss: 0.2016852074302733
# Epoch Training Duration: 00:00:47
#
# - EPOCH 14 -
# Dice: 0.6856
# IoU: 0.5298
# Training Loss: 0.23013968348503114
# Validation Loss: 0.19322394641737142
# Epoch Training Duration: 00:00:47
#
# - EPOCH 15 -
# Dice: 0.7220
# IoU: 0.5780
# Training Loss: 0.22721191585063935
# Validation Loss: 0.18708702828735113
# Epoch Training Duration: 00:00:47
#
# - EPOCH 16 -
# Dice: 0.7213
# IoU: 0.5760
# Training Loss: 0.2270988271633784
# Validation Loss: 0.18746140444030365
# Epoch Training Duration: 00:00:47
#
# - EPOCH 17 -
# Dice: 0.6882
# IoU: 0.5334
# Training Loss: 0.22612752278645834
# Validation Loss: 0.19045844953507185
# Epoch Training Duration: 00:00:47
#
# - EPOCH 18 -
# Dice: 0.7058
# IoU: 0.5561
# Training Loss: 0.2206516146659851
# Validation Loss: 0.19228990779568753
# Epoch Training Duration: 00:00:47
#
# - EPOCH 19 -
# Dice: 0.7216
# IoU: 0.5767
# Training Loss: 0.22079863985379536
# Validation Loss: 0.18786427937448025
# Epoch Training Duration: 00:00:47
#
# - EPOCH 20 -
# Dice: 0.7198
# IoU: 0.5741
# Training Loss: 0.21689037760098775
# Validation Loss: 0.19413051071266332
# Epoch Training Duration: 00:00:47
#
# - EPOCH 21 -
# Dice: 0.6634
# IoU: 0.5026
# Training Loss: 0.21724455495675404
# Validation Loss: 0.201360783384492
# Epoch Training Duration: 00:00:47
#
# - EPOCH 22 -
# Dice: 0.7006
# IoU: 0.5508
# Training Loss: 0.21757678071657816
# Validation Loss: 0.19159699774657687
# Epoch Training Duration: 00:00:47
#
# - EPOCH 23 -
# Dice: 0.7224
# IoU: 0.5775
# Training Loss: 0.21144696791966755
# Validation Loss: 0.18499367979044715
# Epoch Training Duration: 00:00:47
#
# - EPOCH 24 -
# Dice: 0.7313
# IoU: 0.5887
# Training Loss: 0.2198767493168513
# Validation Loss: 0.18425864183033505
# Epoch Training Duration: 00:00:47
#
# - EPOCH 25 -
# Dice: 0.7112
# IoU: 0.5637
# Training Loss: 0.20955729266007742
# Validation Loss: 0.19925578186909357
# Epoch Training Duration: 00:00:47
#
# - EPOCH 26 -
# Dice: 0.7342
# IoU: 0.5928
# Training Loss: 0.21309221863746644
# Validation Loss: 0.19503883474195996
# Epoch Training Duration: 00:00:47
#
# - EPOCH 27 -
# Dice: 0.7308
# IoU: 0.5888
# Training Loss: 0.2060268074274063
# Validation Loss: 0.18157087258684138
# Epoch Training Duration: 00:00:47
#
# - EPOCH 28 -
# Dice: 0.7097
# IoU: 0.5600
# Training Loss: 0.20358247260252635
# Validation Loss: 0.1853528395295143
# Epoch Training Duration: 00:00:47
#
# - EPOCH 29 -
# Dice: 0.7274
# IoU: 0.5824
# Training Loss: 0.20311763167381286
# Validation Loss: 0.17988988431170583
# Epoch Training Duration: 00:00:47
#
# - EPOCH 30 -
# Dice: 0.7320
# IoU: 0.5899
# Training Loss: 0.2012042933702469
# Validation Loss: 0.18690118783464035
# Epoch Training Duration: 00:00:47
#
# - EPOCH 31 -
# Dice: 0.7271
# IoU: 0.5842
# Training Loss: 0.1992194910844167
# Validation Loss: 0.1929009387580057
# Epoch Training Duration: 00:00:47
#
# - EPOCH 32 -
# Dice: 0.7300
# IoU: 0.5869
# Training Loss: 0.1988092984755834
# Validation Loss: 0.1839194082034131
# Epoch Training Duration: 00:00:48
#
# - EPOCH 33 -
# Dice: 0.7324
# IoU: 0.5908
# Training Loss: 0.19757946292559306
# Validation Loss: 0.19674391283964118
# Epoch Training Duration: 00:00:47
#
# - EPOCH 34 -
# Dice: 0.7327
# IoU: 0.5909
# Training Loss: 0.1986580733458201
# Validation Loss: 0.1951989627753695
# Epoch Training Duration: 00:00:47
#
# - EPOCH 35 -
# Dice: 0.7195
# IoU: 0.5723
# Training Loss: 0.19790696422259013
# Validation Loss: 0.185695074343433
# Epoch Training Duration: 00:00:47
#
# - EPOCH 36 -
# Dice: 0.7293
# IoU: 0.5862
# Training Loss: 0.19321039060751596
# Validation Loss: 0.19056775172551474
# Epoch Training Duration: 00:00:47
#
# - EPOCH 37 -
# Dice: 0.7330
# IoU: 0.5907
# Training Loss: 0.1916059696674347
# Validation Loss: 0.18900514502699176
# Epoch Training Duration: 00:00:47
#
# - EPOCH 38 -
# Dice: 0.7283
# IoU: 0.5859
# Training Loss: 0.19332208236058554
# Validation Loss: 0.19539463566616178
# Epoch Training Duration: 00:00:47
#
# - EPOCH 39 -
# Dice: 0.7319
# IoU: 0.5887
# Training Loss: 0.19221417744954428
# Validation Loss: 0.18102790818860134
# Epoch Training Duration: 00:00:47
#
# - EPOCH 40 -
# Dice: 0.7331
# IoU: 0.5920
# Training Loss: 0.19064430276552835
# Validation Loss: 0.20084388515291116
# Epoch Training Duration: 00:00:47
#
# - EPOCH 41 -
# Dice: 0.7466
# IoU: 0.6090
# Training Loss: 0.19050427337487538
# Validation Loss: 0.1770373434604456
# Epoch Training Duration: 00:00:47
#
# - EPOCH 42 -
# Dice: 0.7412
# IoU: 0.6010
# Training Loss: 0.1855865051349004
# Validation Loss: 0.1820834355118374
# Epoch Training Duration: 00:00:47
#
# - EPOCH 43 -
# Dice: 0.7390
# IoU: 0.6000
# Training Loss: 0.18597608466943105
# Validation Loss: 0.19181456378040215
# Epoch Training Duration: 00:00:47
#
# - EPOCH 44 -
# Dice: 0.7336
# IoU: 0.5916
# Training Loss: 0.18771285076936087
# Validation Loss: 0.19483625004068017
# Epoch Training Duration: 00:00:47
#
# - EPOCH 45 -
# Dice: 0.7367
# IoU: 0.5950
# Training Loss: 0.18397247503201167
# Validation Loss: 0.19368747008653978
# Epoch Training Duration: 00:00:47
#
# - EPOCH 46 -
# Dice: 0.7462
# IoU: 0.6081
# Training Loss: 0.1814635545015335
# Validation Loss: 0.18592633089671531
# Epoch Training Duration: 00:00:47
#
# - EPOCH 47 -
# Dice: 0.7373
# IoU: 0.5961
# Training Loss: 0.18234053611755371
# Validation Loss: 0.19710886121417084
# Epoch Training Duration: 00:00:47
#
# - EPOCH 48 -
# Dice: 0.7375
# IoU: 0.5963
# Training Loss: 0.18426674465338388
# Validation Loss: 0.19264499455069503
# Epoch Training Duration: 00:00:47
#
# - EPOCH 49 -
# Dice: 0.7331
# IoU: 0.5898
# Training Loss: 0.18021257360776266
# Validation Loss: 0.18723741794625917
# Epoch Training Duration: 00:00:47
#
# - EPOCH 50 -
# Dice: 0.6994
# IoU: 0.5469
# Training Loss: 0.19560028215249378
# Validation Loss: 0.19458310026675463
# Epoch Training Duration: 00:00:47
#
# Total Training Duration for Threshold 0.3: 00:44:23
#
# -- TRAINING WITH THRESHOLD OF 0.4 --
#
# - EPOCH 1 -
# Dice: 0.6501
# IoU: 0.4893
# Training Loss: 0.3705070823431015
# Validation Loss: 0.2599491222451131
# Epoch Training Duration: 00:00:55
#
# - EPOCH 2 -
# Dice: 0.6048
# IoU: 0.4431
# Training Loss: 0.28189283986886343
# Validation Loss: 0.2696181492259105
# Epoch Training Duration: 00:00:47
#
# - EPOCH 3 -
# Dice: 0.5856
# IoU: 0.4201
# Training Loss: 0.2673932959636052
# Validation Loss: 0.25830603018403053
# Epoch Training Duration: 00:00:47
#
# - EPOCH 4 -
# Dice: 0.5576
# IoU: 0.4000
# Training Loss: 0.2611202989021937
# Validation Loss: 0.2669607208420833
# Epoch Training Duration: 00:00:47
#
# - EPOCH 5 -
# Dice: 0.6887
# IoU: 0.5364
# Training Loss: 0.2581821596622467
# Validation Loss: 0.19984355987980962
# Epoch Training Duration: 00:00:47
#
# - EPOCH 6 -
# Dice: 0.7074
# IoU: 0.5591
# Training Loss: 0.2531555408239365
# Validation Loss: 0.19176547788083553
# Epoch Training Duration: 00:00:47
#
# - EPOCH 7 -
# Dice: 0.7079
# IoU: 0.5611
# Training Loss: 0.2501741800705592
# Validation Loss: 0.19297809790199003
# Epoch Training Duration: 00:00:47
#
# - EPOCH 8 -
# Dice: 0.6803
# IoU: 0.5291
# Training Loss: 0.24516381084918976
# Validation Loss: 0.19901927560567856
# Epoch Training Duration: 00:00:47
#
# - EPOCH 9 -
# Dice: 0.6956
# IoU: 0.5466
# Training Loss: 0.24445005555947621
# Validation Loss: 0.20052464803059897
# Epoch Training Duration: 00:00:47
#
# - EPOCH 10 -
# Dice: 0.7036
# IoU: 0.5540
# Training Loss: 0.2503873016436895
# Validation Loss: 0.19391739290828505
# Epoch Training Duration: 00:00:47
#
# - EPOCH 11 -
# Dice: 0.7189
# IoU: 0.5741
# Training Loss: 0.24153600017229715
# Validation Loss: 0.18698472327863178
# Epoch Training Duration: 00:00:47
#
# - EPOCH 12 -
# Dice: 0.7173
# IoU: 0.5722
# Training Loss: 0.2343823685248693
# Validation Loss: 0.20249628430853286
# Epoch Training Duration: 00:00:47
#
# - EPOCH 13 -
# Dice: 0.7055
# IoU: 0.5552
# Training Loss: 0.2322091567516327
# Validation Loss: 0.19440566919123134
# Epoch Training Duration: 00:00:47
#
# - EPOCH 14 -
# Dice: 0.6944
# IoU: 0.5412
# Training Loss: 0.23028079628944398
# Validation Loss: 0.1990438112989068
# Epoch Training Duration: 00:00:47
#
# - EPOCH 15 -
# Dice: 0.7073
# IoU: 0.5611
# Training Loss: 0.2251732728878657
# Validation Loss: 0.20175327469284335
# Epoch Training Duration: 00:00:47
#
# - EPOCH 16 -
# Dice: 0.7052
# IoU: 0.5581
# Training Loss: 0.22292324165503183
# Validation Loss: 0.19248151235903302
# Epoch Training Duration: 00:00:47
#
# - EPOCH 17 -
# Dice: 0.7001
# IoU: 0.5481
# Training Loss: 0.22281419853369394
# Validation Loss: 0.20250633948793015
# Epoch Training Duration: 00:00:47
#
# - EPOCH 18 -
# Dice: 0.7295
# IoU: 0.5878
# Training Loss: 0.21889881094296773
# Validation Loss: 0.18390642385929823
# Epoch Training Duration: 00:00:47
#
# - EPOCH 19 -
# Dice: 0.6909
# IoU: 0.5371
# Training Loss: 0.217650625705719
# Validation Loss: 0.20125141212095818
# Epoch Training Duration: 00:00:47
#
# - EPOCH 20 -
# Dice: 0.7336
# IoU: 0.5919
# Training Loss: 0.215605029463768
# Validation Loss: 0.18039774723971883
# Epoch Training Duration: 00:00:47
#
# - EPOCH 21 -
# Dice: 0.7005
# IoU: 0.5473
# Training Loss: 0.21636854350566864
# Validation Loss: 0.1961049052576224
# Epoch Training Duration: 00:00:47
#
# - EPOCH 22 -
# Dice: 0.7257
# IoU: 0.5817
# Training Loss: 0.22372412582238516
# Validation Loss: 0.1892314328191181
# Epoch Training Duration: 00:00:47
#
# - EPOCH 23 -
# Dice: 0.7097
# IoU: 0.5627
# Training Loss: 0.2117470004161199
# Validation Loss: 0.20234754479800662
# Epoch Training Duration: 00:00:47
#
# - EPOCH 24 -
# Dice: 0.7209
# IoU: 0.5759
# Training Loss: 0.20636959612369538
# Validation Loss: 0.18971833384906253
# Epoch Training Duration: 00:00:47
#
# - EPOCH 25 -
# Dice: 0.7222
# IoU: 0.5777
# Training Loss: 0.21027882099151612
# Validation Loss: 0.20735900662839413
# Epoch Training Duration: 00:00:47
#
# - EPOCH 26 -
# Dice: 0.7321
# IoU: 0.5910
# Training Loss: 0.20576435685157776
# Validation Loss: 0.1828153672007223
# Epoch Training Duration: 00:00:47
#
# - EPOCH 27 -
# Dice: 0.7353
# IoU: 0.5944
# Training Loss: 0.20300480326016743
# Validation Loss: 0.18552586063742638
# Epoch Training Duration: 00:00:47
#
# - EPOCH 28 -
# Dice: 0.6402
# IoU: 0.4811
# Training Loss: 0.20262529730796813
# Validation Loss: 0.2327834845830997
# Epoch Training Duration: 00:00:47
#
# - EPOCH 29 -
# Dice: 0.7178
# IoU: 0.5713
# Training Loss: 0.2029660638173421
# Validation Loss: 0.18901425305133066
# Epoch Training Duration: 00:00:47
#
# - EPOCH 30 -
# Dice: 0.7367
# IoU: 0.5970
# Training Loss: 0.19933893283208212
# Validation Loss: 0.18578409294908246
# Epoch Training Duration: 00:00:47
#
# - EPOCH 31 -
# Dice: 0.7350
# IoU: 0.5936
# Training Loss: 0.19720461348692575
# Validation Loss: 0.19206780288368464
# Epoch Training Duration: 00:00:48
#
# - EPOCH 32 -
# Dice: 0.7252
# IoU: 0.5820
# Training Loss: 0.19725343028704326
# Validation Loss: 0.20610383991152048
# Epoch Training Duration: 00:00:48
#
# - EPOCH 33 -
# Dice: 0.7345
# IoU: 0.5939
# Training Loss: 0.2058079022169113
# Validation Loss: 0.18558391532860696
# Epoch Training Duration: 00:00:47
#
# - EPOCH 34 -
# Dice: 0.7347
# IoU: 0.5947
# Training Loss: 0.19618337790171306
# Validation Loss: 0.18494917514423528
# Epoch Training Duration: 00:00:47
#
# - EPOCH 35 -
# Dice: 0.7230
# IoU: 0.5793
# Training Loss: 0.19605008403460183
# Validation Loss: 0.18925703627367815
# Epoch Training Duration: 00:00:47
#
# - EPOCH 36 -
# Dice: 0.7400
# IoU: 0.6012
# Training Loss: 0.1920320510864258
# Validation Loss: 0.1901207189851751
# Epoch Training Duration: 00:00:47
#
# - EPOCH 37 -
# Dice: 0.7394
# IoU: 0.6002
# Training Loss: 0.1918901421626409
# Validation Loss: 0.18904336906659105
# Epoch Training Duration: 00:00:47
#
# - EPOCH 38 -
# Dice: 0.7382
# IoU: 0.5969
# Training Loss: 0.19129028697808584
# Validation Loss: 0.184826013011237
# Epoch Training Duration: 00:00:47
#
# - EPOCH 39 -
# Dice: 0.7441
# IoU: 0.6057
# Training Loss: 0.19049680431683857
# Validation Loss: 0.1890631797723472
# Epoch Training Duration: 00:00:47
#
# - EPOCH 40 -
# Dice: 0.7143
# IoU: 0.5659
# Training Loss: 0.18790114561716714
# Validation Loss: 0.19378941180184484
# Epoch Training Duration: 00:00:47
#
# - EPOCH 41 -
# Dice: 0.7450
# IoU: 0.6071
# Training Loss: 0.18917781750361123
# Validation Loss: 0.18260541597070792
# Epoch Training Duration: 00:00:47
#
# - EPOCH 42 -
# Dice: 0.7358
# IoU: 0.5932
# Training Loss: 0.18877131740252176
# Validation Loss: 0.18201881910984716
# Epoch Training Duration: 00:00:47
#
# - EPOCH 43 -
# Dice: 0.7195
# IoU: 0.5733
# Training Loss: 0.1841284497578939
# Validation Loss: 0.19944406409437457
# Epoch Training Duration: 00:00:48
#
# - EPOCH 44 -
# Dice: 0.7440
# IoU: 0.6056
# Training Loss: 0.18283586939175925
# Validation Loss: 0.1868013805554559
# Epoch Training Duration: 00:00:47
#
# - EPOCH 45 -
# Dice: 0.7428
# IoU: 0.6045
# Training Loss: 0.18070555865764618
# Validation Loss: 0.1789715636211137
# Epoch Training Duration: 00:00:47
#
# - EPOCH 46 -
# Dice: 0.7471
# IoU: 0.6096
# Training Loss: 0.18372110923131307
# Validation Loss: 0.1812120407509307
# Epoch Training Duration: 00:00:47
#
# - EPOCH 47 -
# Dice: 0.7392
# IoU: 0.5987
# Training Loss: 0.181083780725797
# Validation Loss: 0.19054123278086385
# Epoch Training Duration: 00:00:47
#
# - EPOCH 48 -
# Dice: 0.7507
# IoU: 0.6150
# Training Loss: 0.1807532638311386
# Validation Loss: 0.1769282533787191
# Epoch Training Duration: 00:00:47
#
# - EPOCH 49 -
# Dice: 0.7319
# IoU: 0.5910
# Training Loss: 0.17955669581890107
# Validation Loss: 0.1853060854288439
# Epoch Training Duration: 00:00:47
#
# - EPOCH 50 -
# Dice: 0.6691
# IoU: 0.5100
# Training Loss: 0.18112801611423493
# Validation Loss: 0.24181660171598196
# Epoch Training Duration: 00:00:47
#
# Total Training Duration for Threshold 0.4: 00:44:28
#
# -- TRAINING WITH THRESHOLD OF 0.5 --
#
# - EPOCH 1 -
# Dice: 0.6529
# IoU: 0.4957
# Training Loss: 0.33166561464468636
# Validation Loss: 0.22207431277881065
# Epoch Training Duration: 00:00:55
#
# - EPOCH 2 -
# Dice: 0.6723
# IoU: 0.5168
# Training Loss: 0.27752798795700073
# Validation Loss: 0.20768597349524498
# Epoch Training Duration: 00:00:47
#
# - EPOCH 3 -
# Dice: 0.6784
# IoU: 0.5269
# Training Loss: 0.26731038570404053
# Validation Loss: 0.20785780514900884
# Epoch Training Duration: 00:00:47
#
# - EPOCH 4 -
# Dice: 0.6152
# IoU: 0.4551
# Training Loss: 0.2639919457832972
# Validation Loss: 0.25121677791078884
# Epoch Training Duration: 00:00:47
#
# - EPOCH 5 -
# Dice: 0.6864
# IoU: 0.5336
# Training Loss: 0.2543994794289271
# Validation Loss: 0.1990517843514681
# Epoch Training Duration: 00:00:47
#
# - EPOCH 6 -
# Dice: 0.6888
# IoU: 0.5397
# Training Loss: 0.25645907680193586
# Validation Loss: 0.1976628270931542
# Epoch Training Duration: 00:00:47
#
# - EPOCH 7 -
# Dice: 0.6557
# IoU: 0.5012
# Training Loss: 0.24886089503765108
# Validation Loss: 0.21413499349728227
# Epoch Training Duration: 00:00:47
#
# - EPOCH 8 -
# Dice: 0.6850
# IoU: 0.5342
# Training Loss: 0.24857518831888833
# Validation Loss: 0.19287579165150723
# Epoch Training Duration: 00:00:47
#
# - EPOCH 9 -
# Dice: 0.5948
# IoU: 0.4299
# Training Loss: 0.2448188457886378
# Validation Loss: 0.3046045694500208
# Epoch Training Duration: 00:00:47
#
# - EPOCH 10 -
# Dice: 0.6817
# IoU: 0.5303
# Training Loss: 0.24207760790983837
# Validation Loss: 0.19570773063848415
# Epoch Training Duration: 00:00:47
#
# - EPOCH 11 -
# Dice: 0.7069
# IoU: 0.5595
# Training Loss: 0.23792516231536864
# Validation Loss: 0.19660805553818742
# Epoch Training Duration: 00:00:47
#
# - EPOCH 12 -
# Dice: 0.7068
# IoU: 0.5599
# Training Loss: 0.2371568908294042
# Validation Loss: 0.18771132019658884
# Epoch Training Duration: 00:00:47
#
# - EPOCH 13 -
# Dice: 0.7141
# IoU: 0.5685
# Training Loss: 0.23543592572212219
# Validation Loss: 0.18860898353159428
# Epoch Training Duration: 00:00:47
#
# - EPOCH 14 -
# Dice: 0.6691
# IoU: 0.5166
# Training Loss: 0.22923835595448813
# Validation Loss: 0.1939843388584753
# Epoch Training Duration: 00:00:47
#
# - EPOCH 15 -
# Dice: 0.7075
# IoU: 0.5595
# Training Loss: 0.2304896593093872
# Validation Loss: 0.18598619801923633
# Epoch Training Duration: 00:00:47
#
# - EPOCH 16 -
# Dice: 0.7042
# IoU: 0.5546
# Training Loss: 0.21927000681559244
# Validation Loss: 0.19510153913870454
# Epoch Training Duration: 00:00:47
#
# - EPOCH 17 -
# Dice: 0.7141
# IoU: 0.5671
# Training Loss: 0.22071144123872122
# Validation Loss: 0.18735909586151442
# Epoch Training Duration: 00:00:47
#
# - EPOCH 18 -
# Dice: 0.5687
# IoU: 0.4139
# Training Loss: 0.21995949983596802
# Validation Loss: 0.2851676824502647
# Epoch Training Duration: 00:00:47
#
# - EPOCH 19 -
# Dice: 0.7128
# IoU: 0.5670
# Training Loss: 0.21817899386088052
# Validation Loss: 0.1895865802653134
# Epoch Training Duration: 00:00:47
#
# - EPOCH 20 -
# Dice: 0.7052
# IoU: 0.5583
# Training Loss: 0.21186946670214335
# Validation Loss: 0.18893573650469384
# Epoch Training Duration: 00:00:47
#
# - EPOCH 21 -
# Dice: 0.7230
# IoU: 0.5783
# Training Loss: 0.2312484500805537
# Validation Loss: 0.19068926417579254
# Epoch Training Duration: 00:00:47
#
# - EPOCH 22 -
# Dice: 0.7164
# IoU: 0.5720
# Training Loss: 0.21597647845745085
# Validation Loss: 0.18688220422094068
# Epoch Training Duration: 00:00:47
#
# - EPOCH 23 -
# Dice: 0.7194
# IoU: 0.5757
# Training Loss: 0.2162393981218338
# Validation Loss: 0.19081142513702312
# Epoch Training Duration: 00:00:47
#
# - EPOCH 24 -
# Dice: 0.7239
# IoU: 0.5820
# Training Loss: 0.20793023685614268
# Validation Loss: 0.18309400727351507
# Epoch Training Duration: 00:00:47
#
# - EPOCH 25 -
# Dice: 0.7249
# IoU: 0.5809
# Training Loss: 0.20540722807248432
# Validation Loss: 0.1904572807252407
# Epoch Training Duration: 00:00:47
#
# - EPOCH 26 -
# Dice: 0.7296
# IoU: 0.5876
# Training Loss: 0.21010221858819325
# Validation Loss: 0.18411545207103094
# Epoch Training Duration: 00:00:47
#
# - EPOCH 27 -
# Dice: 0.7335
# IoU: 0.5931
# Training Loss: 0.2033472724755605
# Validation Loss: 0.18844829965382814
# Epoch Training Duration: 00:00:47
#
# - EPOCH 28 -
# Dice: 0.6885
# IoU: 0.5339
# Training Loss: 0.20092737257480622
# Validation Loss: 0.21361295692622662
# Epoch Training Duration: 00:00:47
#
# - EPOCH 29 -
# Dice: 0.7143
# IoU: 0.5700
# Training Loss: 0.20018543978532155
# Validation Loss: 0.18964195235942802
# Epoch Training Duration: 00:00:47
#
# - EPOCH 30 -
# Dice: 0.7093
# IoU: 0.5627
# Training Loss: 0.1976629694302877
# Validation Loss: 0.19009956686447063
# Epoch Training Duration: 00:00:47
#
# - EPOCH 31 -
# Dice: 0.7110
# IoU: 0.5652
# Training Loss: 0.1978260999917984
# Validation Loss: 0.18617268232628703
# Epoch Training Duration: 00:00:47
#
# - EPOCH 32 -
# Dice: 0.7067
# IoU: 0.5590
# Training Loss: 0.19485204537709555
# Validation Loss: 0.1986477804991106
# Epoch Training Duration: 00:00:47
#
# - EPOCH 33 -
# Dice: 0.7300
# IoU: 0.5894
# Training Loss: 0.2076067101955414
# Validation Loss: 0.1871103554343184
# Epoch Training Duration: 00:00:47
#
# - EPOCH 34 -
# Dice: 0.7315
# IoU: 0.5911
# Training Loss: 0.19896867811679841
# Validation Loss: 0.18215939278403917
# Epoch Training Duration: 00:00:47
#
# - EPOCH 35 -
# Dice: 0.7307
# IoU: 0.5894
# Training Loss: 0.19482996185620627
# Validation Loss: 0.1847997228614986
# Epoch Training Duration: 00:00:47
#
# - EPOCH 36 -
# Dice: 0.7241
# IoU: 0.5816
# Training Loss: 0.19279911359151206
# Validation Loss: 0.18374300748109818
# Epoch Training Duration: 00:00:48
#
# - EPOCH 37 -
# Dice: 0.7353
# IoU: 0.5947
# Training Loss: 0.19133574962615968
# Validation Loss: 0.17562197723115483
# Epoch Training Duration: 00:00:47
#
# - EPOCH 38 -
# Dice: 0.7365
# IoU: 0.5956
# Training Loss: 0.19144494513670604
# Validation Loss: 0.18304235814139247
# Epoch Training Duration: 00:00:47
#
# - EPOCH 39 -
# Dice: 0.5825
# IoU: 0.4250
# Training Loss: 0.18923560818036397
# Validation Loss: 0.32507112498084706
# Epoch Training Duration: 00:00:47
#
# - EPOCH 40 -
# Dice: 0.7269
# IoU: 0.5853
# Training Loss: 0.19972545742988587
# Validation Loss: 0.1864588373961548
# Epoch Training Duration: 00:00:47
#
# - EPOCH 41 -
# Dice: 0.7288
# IoU: 0.5877
# Training Loss: 0.18972979386647543
# Validation Loss: 0.18296687638697526
# Epoch Training Duration: 00:00:47
#
# - EPOCH 42 -
# Dice: 0.7307
# IoU: 0.5904
# Training Loss: 0.1890026014049848
# Validation Loss: 0.19424674628923336
# Epoch Training Duration: 00:00:47
#
# - EPOCH 43 -
# Dice: 0.7312
# IoU: 0.5898
# Training Loss: 0.18546246806780498
# Validation Loss: 0.19229372994353375
# Epoch Training Duration: 00:00:47
#
# - EPOCH 44 -
# Dice: 0.7236
# IoU: 0.5797
# Training Loss: 0.18494550089041392
# Validation Loss: 0.18812894712512693
# Epoch Training Duration: 00:00:47
#
# - EPOCH 45 -
# Dice: 0.7426
# IoU: 0.6051
# Training Loss: 0.1830678810675939
# Validation Loss: 0.1775968004949391
# Epoch Training Duration: 00:00:48
#
# - EPOCH 46 -
# Dice: 0.7368
# IoU: 0.5972
# Training Loss: 0.18072435835997264
# Validation Loss: 0.18584381804491082
# Epoch Training Duration: 00:00:47
#
# - EPOCH 47 -
# Dice: 0.7254
# IoU: 0.5804
# Training Loss: 0.17904099444548288
# Validation Loss: 0.19034490827471018
# Epoch Training Duration: 00:00:47
#
# - EPOCH 48 -
# Dice: 0.7480
# IoU: 0.6110
# Training Loss: 0.1827392013867696
# Validation Loss: 0.1846755789592862
# Epoch Training Duration: 00:00:47
#
# - EPOCH 49 -
# Dice: 0.5870
# IoU: 0.4272
# Training Loss: 0.1806422116359075
# Validation Loss: 0.2918360363692045
# Epoch Training Duration: 00:00:47
#
# - EPOCH 50 -
# Dice: 0.7353
# IoU: 0.5951
# Training Loss: 0.18515252232551574
# Validation Loss: 0.18341373885050416
# Epoch Training Duration: 00:00:47
#
# Total Training Duration for Threshold 0.5: 00:44:23
#
# -- TRAINING WITH THRESHOLD OF 0.6 --
#
# - EPOCH 1 -
# Dice: 0.6637
# IoU: 0.5105
# Training Loss: 0.32678766787052155
# Validation Loss: 0.21451913937926292
# Epoch Training Duration: 00:00:53
#
# - EPOCH 2 -
# Dice: 0.5552
# IoU: 0.4030
# Training Loss: 0.28061994115511574
# Validation Loss: 0.2326379269361496
# Epoch Training Duration: 00:00:47
#
# - EPOCH 3 -
# Dice: 0.6491
# IoU: 0.4887
# Training Loss: 0.2699190656344096
# Validation Loss: 0.27672586279610795
# Epoch Training Duration: 00:00:47
#
# - EPOCH 4 -
# Dice: 0.5709
# IoU: 0.4148
# Training Loss: 0.26892212867736814
# Validation Loss: 0.21096745133399963
# Epoch Training Duration: 00:00:47
#
# - EPOCH 5 -
# Dice: 0.6793
# IoU: 0.5270
# Training Loss: 0.26172670284907024
# Validation Loss: 0.20852312973390022
# Epoch Training Duration: 00:00:48
#
# - EPOCH 6 -
# Dice: 0.6038
# IoU: 0.4485
# Training Loss: 0.2513392659028371
# Validation Loss: 0.2049967978770534
# Epoch Training Duration: 00:00:47
#
# - EPOCH 7 -
# Dice: 0.6411
# IoU: 0.4859
# Training Loss: 0.2530859007438024
# Validation Loss: 0.19874918274581432
# Epoch Training Duration: 00:00:48
#
# - EPOCH 8 -
# Dice: 0.6890
# IoU: 0.5380
# Training Loss: 0.24997766455014547
# Validation Loss: 0.19949180477609238
# Epoch Training Duration: 00:00:47
#
# - EPOCH 9 -
# Dice: 0.6405
# IoU: 0.4778
# Training Loss: 0.24610157211621603
# Validation Loss: 0.2924726189424594
# Epoch Training Duration: 00:00:47
#
# - EPOCH 10 -
# Dice: 0.6289
# IoU: 0.4687
# Training Loss: 0.2456446901957194
# Validation Loss: 0.2568912198767066
# Epoch Training Duration: 00:00:47
#
# - EPOCH 11 -
# Dice: 0.6560
# IoU: 0.5022
# Training Loss: 0.24001201629638672
# Validation Loss: 0.19736444111913443
# Epoch Training Duration: 00:00:47
#
# - EPOCH 12 -
# Dice: 0.6474
# IoU: 0.4874
# Training Loss: 0.23596636394659679
# Validation Loss: 0.22030656846861044
# Epoch Training Duration: 00:00:47
#
# - EPOCH 13 -
# Dice: 0.6969
# IoU: 0.5473
# Training Loss: 0.23644653220971426
# Validation Loss: 0.19074820323536792
# Epoch Training Duration: 00:00:47
#
# - EPOCH 14 -
# Dice: 0.7094
# IoU: 0.5621
# Training Loss: 0.23114531576633454
# Validation Loss: 0.2053152242054542
# Epoch Training Duration: 00:00:47
#
# - EPOCH 15 -
# Dice: 0.6410
# IoU: 0.4793
# Training Loss: 0.22772764007250468
# Validation Loss: 0.24693119153380394
# Epoch Training Duration: 00:00:47
#
# - EPOCH 16 -
# Dice: 0.6660
# IoU: 0.5132
# Training Loss: 0.22689671576023102
# Validation Loss: 0.19249883480370045
# Epoch Training Duration: 00:00:47
#
# - EPOCH 17 -
# Dice: 0.6623
# IoU: 0.5074
# Training Loss: 0.22590008815129597
# Validation Loss: 0.1951101222075522
# Epoch Training Duration: 00:00:48
#
# - EPOCH 18 -
# Dice: 0.6691
# IoU: 0.5143
# Training Loss: 0.22275894025961557
# Validation Loss: 0.20006713038310409
# Epoch Training Duration: 00:00:47
#
# - EPOCH 19 -
# Dice: 0.6737
# IoU: 0.5205
# Training Loss: 0.22335501233736674
# Validation Loss: 0.1974284096310536
# Epoch Training Duration: 00:00:47
#
# - EPOCH 20 -
# Dice: 0.6453
# IoU: 0.4885
# Training Loss: 0.22068514088789623
# Validation Loss: 0.20825623938192925
# Epoch Training Duration: 00:00:47
#
# - EPOCH 21 -
# Dice: 0.7168
# IoU: 0.5721
# Training Loss: 0.2181012980143229
# Validation Loss: 0.1926347529515624
# Epoch Training Duration: 00:00:47
#
# - EPOCH 22 -
# Dice: 0.7217
# IoU: 0.5780
# Training Loss: 0.21286964356899263
# Validation Loss: 0.18549049800882736
# Epoch Training Duration: 00:00:47
#
# - EPOCH 23 -
# Dice: 0.6169
# IoU: 0.4605
# Training Loss: 0.21556688825289408
# Validation Loss: 0.2008707388304174
# Epoch Training Duration: 00:00:47
#
# - EPOCH 24 -
# Dice: 0.6978
# IoU: 0.5484
# Training Loss: 0.20987897594769797
# Validation Loss: 0.19662624411284924
# Epoch Training Duration: 00:00:47
#
# - EPOCH 25 -
# Dice: 0.7038
# IoU: 0.5577
# Training Loss: 0.21033644457658132
# Validation Loss: 0.1826323999557644
# Epoch Training Duration: 00:00:48
#
# - EPOCH 26 -
# Dice: 0.7131
# IoU: 0.5678
# Training Loss: 0.20808160583178203
# Validation Loss: 0.1896287666944166
# Epoch Training Duration: 00:00:47
#
# - EPOCH 27 -
# Dice: 0.6656
# IoU: 0.5134
# Training Loss: 0.22046383798122407
# Validation Loss: 0.19367371623714766
# Epoch Training Duration: 00:00:47
#
# - EPOCH 28 -
# Dice: 0.7224
# IoU: 0.5794
# Training Loss: 0.20848424315452577
# Validation Loss: 0.19123530263702074
# Epoch Training Duration: 00:00:47
#
# - EPOCH 29 -
# Dice: 0.7165
# IoU: 0.5721
# Training Loss: 0.20623473286628724
# Validation Loss: 0.18818952422589064
# Epoch Training Duration: 00:00:47
#
# - EPOCH 30 -
# Dice: 0.7043
# IoU: 0.5565
# Training Loss: 0.20391658306121827
# Validation Loss: 0.18894745487098893
# Epoch Training Duration: 00:00:47
#
# - EPOCH 31 -
# Dice: 0.7146
# IoU: 0.5702
# Training Loss: 0.2016446437438329
# Validation Loss: 0.18871451572825512
# Epoch Training Duration: 00:00:48
#
# - EPOCH 32 -
# Dice: 0.7211
# IoU: 0.5765
# Training Loss: 0.19970841983954113
# Validation Loss: 0.18655585621794066
# Epoch Training Duration: 00:00:47
#
# - EPOCH 33 -
# Dice: 0.6976
# IoU: 0.5496
# Training Loss: 0.19636980692545572
# Validation Loss: 0.1922361676891645
# Epoch Training Duration: 00:00:48
#
# - EPOCH 34 -
# Dice: 0.7050
# IoU: 0.5563
# Training Loss: 0.1986785920461019
# Validation Loss: 0.18428638918946186
# Epoch Training Duration: 00:00:47
#
# - EPOCH 35 -
# Dice: 0.7174
# IoU: 0.5729
# Training Loss: 0.19417884906133015
# Validation Loss: 0.19282704459813735
# Epoch Training Duration: 00:00:47
#
# - EPOCH 36 -
# Dice: 0.7056
# IoU: 0.5591
# Training Loss: 0.19667000432809195
# Validation Loss: 0.19024677644483745
# Epoch Training Duration: 00:00:47
#
# - EPOCH 37 -
# Dice: 0.6980
# IoU: 0.5489
# Training Loss: 0.19764656563599906
# Validation Loss: 0.20164334176418683
# Epoch Training Duration: 00:00:47
#
# - EPOCH 38 -
# Dice: 0.7132
# IoU: 0.5679
# Training Loss: 0.2009045648574829
# Validation Loss: 0.19357995797569552
# Epoch Training Duration: 00:00:47
#
# - EPOCH 39 -
# Dice: 0.7112
# IoU: 0.5653
# Training Loss: 0.19383463859558106
# Validation Loss: 0.19037623284384608
# Epoch Training Duration: 00:00:47
#
# - EPOCH 40 -
# Dice: 0.7315
# IoU: 0.5906
# Training Loss: 0.1941710191965103
# Validation Loss: 0.17841735808178782
# Epoch Training Duration: 00:00:47
#
# - EPOCH 41 -
# Dice: 0.7300
# IoU: 0.5890
# Training Loss: 0.19072955429553987
# Validation Loss: 0.1809247227696081
# Epoch Training Duration: 00:00:48
#
# - EPOCH 42 -
# Dice: 0.7111
# IoU: 0.5651
# Training Loss: 0.19114393035570781
# Validation Loss: 0.18466320090616742
# Epoch Training Duration: 00:00:48
#
# - EPOCH 43 -
# Dice: 0.7173
# IoU: 0.5728
# Training Loss: 0.18765375773111978
# Validation Loss: 0.19159333237136403
# Epoch Training Duration: 00:00:47
#
# - EPOCH 44 -
# Dice: 0.7105
# IoU: 0.5655
# Training Loss: 0.18973625997702281
# Validation Loss: 0.18708984383071461
# Epoch Training Duration: 00:00:47
#
# - EPOCH 45 -
# Dice: 0.7166
# IoU: 0.5724
# Training Loss: 0.18551835060119629
# Validation Loss: 0.18439066782593727
# Epoch Training Duration: 00:00:47
#
# - EPOCH 46 -
# Dice: 0.6897
# IoU: 0.5412
# Training Loss: 0.19785305579503376
# Validation Loss: 0.21235344481344023
# Epoch Training Duration: 00:00:47
#
# - EPOCH 47 -
# Dice: 0.7252
# IoU: 0.5832
# Training Loss: 0.19723107933998107
# Validation Loss: 0.1789074633270502
# Epoch Training Duration: 00:00:48
#
# - EPOCH 48 -
# Dice: 0.7218
# IoU: 0.5784
# Training Loss: 0.18633165220419565
# Validation Loss: 0.1889835998105506
# Epoch Training Duration: 00:00:48
#
# - EPOCH 49 -
# Dice: 0.7107
# IoU: 0.5647
# Training Loss: 0.1872454677025477
# Validation Loss: 0.18432373522470394
# Epoch Training Duration: 00:00:47
#
# - EPOCH 50 -
# Dice: 0.7062
# IoU: 0.5592
# Training Loss: 0.18846489826838175
# Validation Loss: 0.20286491916825375
# Epoch Training Duration: 00:00:48
#
# Total Training Duration for Threshold 0.6: 00:44:30
#
# -- TRAINING WITH THRESHOLD OF 0.7 --
#
# - EPOCH 1 -
# Dice: 0.5810
# IoU: 0.4224
# Training Loss: 0.3426622188091278
# Validation Loss: 0.21487084465722242
# Epoch Training Duration: 00:00:55
#
# - EPOCH 2 -
# Dice: 0.6661
# IoU: 0.5093
# Training Loss: 0.2764388326803843
# Validation Loss: 0.27272551134228706
# Epoch Training Duration: 00:00:47
#
# - EPOCH 3 -
# Dice: 0.6617
# IoU: 0.5051
# Training Loss: 0.26762933949629464
# Validation Loss: 0.23911227534214655
# Epoch Training Duration: 00:00:47
#
# - EPOCH 4 -
# Dice: 0.6627
# IoU: 0.5067
# Training Loss: 0.2606412873665492
# Validation Loss: 0.21619506490727267
# Epoch Training Duration: 00:00:47
#
# - EPOCH 5 -
# Dice: 0.6472
# IoU: 0.4910
# Training Loss: 0.25503501772880555
# Validation Loss: 0.1960389350230495
# Epoch Training Duration: 00:00:48
#
# - EPOCH 6 -
# Dice: 0.5231
# IoU: 0.3639
# Training Loss: 0.2508219999074936
# Validation Loss: 0.4492928385734558
# Epoch Training Duration: 00:00:47
#
# - EPOCH 7 -
# Dice: 0.6799
# IoU: 0.5278
# Training Loss: 0.25072300871213277
# Validation Loss: 0.2179817990399897
# Epoch Training Duration: 00:00:47
#
# - EPOCH 8 -
# Dice: 0.6480
# IoU: 0.4914
# Training Loss: 0.24414851466814677
# Validation Loss: 0.20068615892281136
# Epoch Training Duration: 00:00:47
#
# - EPOCH 9 -
# Dice: 0.6520
# IoU: 0.4953
# Training Loss: 0.2388818140824636
# Validation Loss: 0.19093641685321927
# Epoch Training Duration: 00:00:47
#
# - EPOCH 10 -
# Dice: 0.6246
# IoU: 0.4674
# Training Loss: 0.23467838009198508
# Validation Loss: 0.1931459360445539
# Epoch Training Duration: 00:00:47
#
# - EPOCH 11 -
# Dice: 0.6229
# IoU: 0.4639
# Training Loss: 0.2354958560069402
# Validation Loss: 0.1918160024409493
# Epoch Training Duration: 00:00:48
#
# - EPOCH 12 -
# Dice: 0.6013
# IoU: 0.4426
# Training Loss: 0.23459582149982453
# Validation Loss: 0.1877641932417949
# Epoch Training Duration: 00:00:47
#
# - EPOCH 13 -
# Dice: 0.6381
# IoU: 0.4811
# Training Loss: 0.23065528253714243
# Validation Loss: 0.19490329936767617
# Epoch Training Duration: 00:00:47
#
# - EPOCH 14 -
# Dice: 0.6409
# IoU: 0.4832
# Training Loss: 0.22731711784998576
# Validation Loss: 0.1989326054851214
# Epoch Training Duration: 00:00:47
#
# - EPOCH 15 -
# Dice: 0.6104
# IoU: 0.4541
# Training Loss: 0.2353639127810796
# Validation Loss: 0.20227505173534155
# Epoch Training Duration: 00:00:47
#
# - EPOCH 16 -
# Dice: 0.6144
# IoU: 0.4565
# Training Loss: 0.22472455004851025
# Validation Loss: 0.19160767815386257
# Epoch Training Duration: 00:00:47
#
# - EPOCH 17 -
# Dice: 0.5711
# IoU: 0.4138
# Training Loss: 0.22230269610881806
# Validation Loss: 0.2220522239804268
# Epoch Training Duration: 00:00:48
#
# - EPOCH 18 -
# Dice: 0.6748
# IoU: 0.5224
# Training Loss: 0.21988409062226613
# Validation Loss: 0.19194060967614254
# Epoch Training Duration: 00:00:47
#
# - EPOCH 19 -
# Dice: 0.6755
# IoU: 0.5237
# Training Loss: 0.21779671569665274
# Validation Loss: 0.1801686535278956
# Epoch Training Duration: 00:00:47
#
# - EPOCH 20 -
# Dice: 0.6837
# IoU: 0.5315
# Training Loss: 0.21402560770511628
# Validation Loss: 0.19705026037991047
# Epoch Training Duration: 00:00:47
#
# - EPOCH 21 -
# Dice: 0.6694
# IoU: 0.5158
# Training Loss: 0.2133432549238205
# Validation Loss: 0.19254535405586162
# Epoch Training Duration: 00:00:47
#
# - EPOCH 22 -
# Dice: 0.6623
# IoU: 0.5078
# Training Loss: 0.20988305429617563
# Validation Loss: 0.189696763176471
# Epoch Training Duration: 00:00:47
#
# - EPOCH 23 -
# Dice: 0.6702
# IoU: 0.5160
# Training Loss: 0.20840465664863586
# Validation Loss: 0.18048824618260065
# Epoch Training Duration: 00:00:47
#
# - EPOCH 24 -
# Dice: 0.6258
# IoU: 0.4676
# Training Loss: 0.20787024557590483
# Validation Loss: 0.18167558731511235
# Epoch Training Duration: 00:00:47
#
# - EPOCH 25 -
# Dice: 0.6787
# IoU: 0.5265
# Training Loss: 0.20474062820275624
# Validation Loss: 0.18297699109340707
# Epoch Training Duration: 00:00:48
#
# - EPOCH 26 -
# Dice: 0.6704
# IoU: 0.5175
# Training Loss: 0.2027958091100057
# Validation Loss: 0.1901487777940929
# Epoch Training Duration: 00:00:47
#
# - EPOCH 27 -
# Dice: 0.6800
# IoU: 0.5287
# Training Loss: 0.20252564450105032
# Validation Loss: 0.17534479483341178
# Epoch Training Duration: 00:00:47
#
# - EPOCH 28 -
# Dice: 0.6704
# IoU: 0.5181
# Training Loss: 0.20243903776009878
# Validation Loss: 0.192030590493232
# Epoch Training Duration: 00:00:47
#
# - EPOCH 29 -
# Dice: 0.5904
# IoU: 0.4301
# Training Loss: 0.201839529077212
# Validation Loss: 0.19150091024736562
# ...
# Epoch Training Duration: 00:00:47
#
# - EPOCH 42 -
# Dice: 0.6865
# IoU: 0.5361
# Training Loss: 0.18586058755715687
# Validation Loss: 0.18738963874056935
# Epoch Training Duration: 00:00:47
#
# - EPOCH 43 -
# Dice: 0.6592
# IoU: 0.5048
# Training Loss: 0.19235296467940013
# Validation Loss: 0.18921032811825475
# Epoch Training Duration: 00:00:48
#
# - EPOCH 44 -
# Dice: 0.6928
# IoU: 0.5436
# Training Loss: 0.18658210277557374
# Validation Loss: 0.18917284766212106
# Epoch Training Duration: 00:00:47
#
# - EPOCH 45 -
# Dice: 0.6933
# IoU: 0.5430
# Training Loss: 0.18305247008800507
# Validation Loss: 0.1900534105176727
# Epoch Training Duration: 00:00:46
#
# - EPOCH 46 -
# Dice: 0.6891
# IoU: 0.5398
# Training Loss: 0.18249059955279032
# Validation Loss: 0.19764815736562014
# Epoch Training Duration: 00:00:47
#
# - EPOCH 47 -
# Dice: 0.6939
# IoU: 0.5455
# Training Loss: 0.18301702837149303
# Validation Loss: 0.19137796255139014
# Epoch Training Duration: 00:00:47
#
# - EPOCH 48 -
# Dice: 0.6931
# IoU: 0.5440
# Training Loss: 0.18193289518356323
# Validation Loss: 0.18853942095302045
# Epoch Training Duration: 00:00:47
#
# - EPOCH 49 -
# Dice: 0.6959
# IoU: 0.5470
# Training Loss: 0.17914253801107408
# Validation Loss: 0.18319574231281877
# Epoch Training Duration: 00:00:47
#
# - EPOCH 50 -
# Dice: 0.6974
# IoU: 0.5489
# Training Loss: 0.17766250411669413
# Validation Loss: 0.1865427993858854
# Epoch Training Duration: 00:00:47
#
# Total Training Duration for Threshold 0.7: 00:44:27
#
# -- TRAINING WITH THRESHOLD OF 0.8 --
#
# - EPOCH 1 -
# Dice: 0.5791
# IoU: 0.4189
# Training Loss: 0.3626729706923167
# Validation Loss: 0.23393349846204123
# Epoch Training Duration: 00:00:56
#
# - EPOCH 2 -
# Dice: 0.5640
# IoU: 0.4017
# Training Loss: 0.2826179381211599
# Validation Loss: 0.23025427075723806
# Epoch Training Duration: 00:00:47
#
# - EPOCH 3 -
# Dice: 0.5812
# IoU: 0.4227
# Training Loss: 0.270476336479187
# Validation Loss: 0.196070805657655
# Epoch Training Duration: 00:00:47
#
# - EPOCH 4 -
# Dice: 0.4276
# IoU: 0.2858
# Training Loss: 0.25981489499409993
# Validation Loss: 0.24200015344346562
# Epoch Training Duration: 00:00:48
#
# - EPOCH 5 -
# Dice: 0.5467
# IoU: 0.3867
# Training Loss: 0.2567023887236913
# Validation Loss: 0.20078664661074677
# Epoch Training Duration: 00:00:47
#
# - EPOCH 6 -
# Dice: 0.4699
# IoU: 0.3196
# Training Loss: 0.25022176146507263
# Validation Loss: 0.21421085592980185
# Epoch Training Duration: 00:00:47
#
# - EPOCH 7 -
# Dice: 0.3587
# IoU: 0.2343
# Training Loss: 0.24933059573173522
# Validation Loss: 0.24580807983875275
# Epoch Training Duration: 00:00:47
#
# - EPOCH 8 -
# Dice: 0.4826
# IoU: 0.3329
# Training Loss: 0.25004722277323405
# Validation Loss: 0.19981549447402358
# Epoch Training Duration: 00:00:47
#
# - EPOCH 9 -
# Dice: 0.5560
# IoU: 0.3952
# Training Loss: 0.24214640120665232
# Validation Loss: 0.19418504973873496
# Epoch Training Duration: 00:00:47
#
# - EPOCH 10 -
# Dice: 0.6265
# IoU: 0.4689
# Training Loss: 0.24438906987508138
# Validation Loss: 0.20514264159525433
# Epoch Training Duration: 00:00:47
#
# - EPOCH 11 -
# Dice: 0.6008
# IoU: 0.4396
# Training Loss: 0.23771579384803773
# Validation Loss: 0.2060204646550119
# Epoch Training Duration: 00:00:47
#
# - EPOCH 12 -
# Dice: 0.6502
# IoU: 0.4944
# Training Loss: 0.23373269001642863
# Validation Loss: 0.1966473115608096
# Epoch Training Duration: 00:00:47
#
# - EPOCH 13 -
# Dice: 0.6701
# IoU: 0.5161
# Training Loss: 0.2272833663225174
# Validation Loss: 0.1996643653449913
# Epoch Training Duration: 00:00:47
#
# - EPOCH 14 -
# Dice: 0.6159
# IoU: 0.4578
# Training Loss: 0.2286343107620875
# Validation Loss: 0.18223797219494978
# Epoch Training Duration: 00:00:48
#
# - EPOCH 15 -
# Dice: 0.6624
# IoU: 0.5078
# Training Loss: 0.22568506399790447
# Validation Loss: 0.19406910194084048
# Epoch Training Duration: 00:00:47
#
# - EPOCH 16 -
# Dice: 0.4027
# IoU: 0.2617
# Training Loss: 0.22579025626182556
# Validation Loss: 0.23608423257246614
# Epoch Training Duration: 00:00:47
#
# - EPOCH 17 -
# Dice: 0.6429
# IoU: 0.4868
# Training Loss: 0.23233591079711913
# Validation Loss: 0.18298127160718045
# Epoch Training Duration: 00:00:47
#
# - EPOCH 18 -
# Dice: 0.5312
# IoU: 0.3720
# Training Loss: 0.22251712739467622
# Validation Loss: 0.18641245101268092
# Epoch Training Duration: 00:00:47
#
# - EPOCH 19 -
# Dice: 0.6193
# IoU: 0.4602
# Training Loss: 0.2227642552057902
# Validation Loss: 0.1794317450063924
# Epoch Training Duration: 00:00:48
#
# - EPOCH 20 -
# Dice: 0.6234
# IoU: 0.4655
# Training Loss: 0.2155206859111786
# Validation Loss: 0.18542708440994224
# Epoch Training Duration: 00:00:47
#
# - EPOCH 21 -
# Dice: 0.6582
# IoU: 0.5036
# Training Loss: 0.21722572684288025
# Validation Loss: 0.19236370470995703
# Epoch Training Duration: 00:00:47
#
# - EPOCH 22 -
# Dice: 0.6278
# IoU: 0.4687
# Training Loss: 0.21540239731470745
# Validation Loss: 0.19603537286942205
# Epoch Training Duration: 00:00:47
#
# - EPOCH 23 -
# Dice: 0.6294
# IoU: 0.4728
# Training Loss: 0.21541086196899414
# Validation Loss: 0.1863101014556984
# Epoch Training Duration: 00:00:47
#
# - EPOCH 24 -
# Dice: 0.6115
# IoU: 0.4518
# Training Loss: 0.20983749548594158
# Validation Loss: 0.18122550348440805
# Epoch Training Duration: 00:00:47
#
# - EPOCH 25 -
# Dice: 0.6423
# IoU: 0.4864
# Training Loss: 0.2120101555188497
# Validation Loss: 0.19226148026064038
# Epoch Training Duration: 00:00:47
#
# - EPOCH 26 -
# Dice: 0.5956
# IoU: 0.4369
# Training Loss: 0.20593791166941325
# Validation Loss: 0.21123158388460675
# Epoch Training Duration: 00:00:47
#
# - EPOCH 27 -
# Dice: 0.6395
# IoU: 0.4829
# Training Loss: 0.20539001484711966
# Validation Loss: 0.19650855520740151
# Epoch Training Duration: 00:00:47
#
# - EPOCH 28 -
# Dice: 0.4664
# IoU: 0.3163
# Training Loss: 0.2061802355448405
# Validation Loss: 0.1951837409287691
# Epoch Training Duration: 00:00:47
#
# - EPOCH 29 -
# Dice: 0.5788
# IoU: 0.4165
# Training Loss: 0.20166483799616497
# Validation Loss: 0.19157898930522302
# Epoch Training Duration: 00:00:47
#
# - EPOCH 30 -
# Dice: 0.6276
# IoU: 0.4700
# Training Loss: 0.2034718269109726
# Validation Loss: 0.18388393024603525
# Epoch Training Duration: 00:00:47
#
# - EPOCH 31 -
# Dice: 0.6114
# IoU: 0.4521
# Training Loss: 0.20138814608256023
# Validation Loss: 0.18439294040823975
# Epoch Training Duration: 00:00:47
#
# - EPOCH 32 -
# Dice: 0.6173
# IoU: 0.4579
# Training Loss: 0.197467440366745
# Validation Loss: 0.18309278429175416
# Epoch Training Duration: 00:00:47
#
# - EPOCH 33 -
# Dice: 0.6106
# IoU: 0.4499
# Training Loss: 0.20539291401704152
# Validation Loss: 0.19187375468512377
# Epoch Training Duration: 00:00:47
#
# - EPOCH 34 -
# Dice: 0.6145
# IoU: 0.4552
# Training Loss: 0.1990221937497457
# Validation Loss: 0.19032128093143305
# Epoch Training Duration: 00:00:47
#
# - EPOCH 35 -
# Dice: 0.6640
# IoU: 0.5099
# Training Loss: 0.197412105401357
# Validation Loss: 0.18711569796626767
# Epoch Training Duration: 00:00:47
#
# - EPOCH 36 -
# Dice: 0.6051
# IoU: 0.4447
# Training Loss: 0.19589510281880695
# Validation Loss: 0.1835314561612904
# Epoch Training Duration: 00:00:47
#
# - EPOCH 37 -
# Dice: 0.5911
# IoU: 0.4308
# Training Loss: 0.19277631282806396
# Validation Loss: 0.18739769017944732
# Epoch Training Duration: 00:00:48
#
# - EPOCH 38 -
# Dice: 0.5668
# IoU: 0.4067
# Training Loss: 0.19506315052509307
# Validation Loss: 0.1910277002801498
# Epoch Training Duration: 00:00:47
#
# - EPOCH 39 -
# Dice: 0.6151
# IoU: 0.4574
# Training Loss: 0.19423510730266572
# Validation Loss: 0.19237302104011178
# Epoch Training Duration: 00:00:47
#
# - EPOCH 40 -
# Dice: 0.5302
# IoU: 0.3730
# Training Loss: 0.1913634294271469
# Validation Loss: 0.21053618394459286
# Epoch Training Duration: 00:00:47
#
# - EPOCH 41 -
# Dice: 0.5917
# IoU: 0.4316
# Training Loss: 0.1886308401823044
# Validation Loss: 0.20130351247886816
# Epoch Training Duration: 00:00:47
#
# - EPOCH 42 -
# Dice: 0.6291
# IoU: 0.4713
# Training Loss: 0.19219869593779246
# Validation Loss: 0.18468648536751667
# Epoch Training Duration: 00:00:47
#
# - EPOCH 43 -
# Dice: 0.6557
# IoU: 0.5021
# Training Loss: 0.18704076290130614
# Validation Loss: 0.18841545625279346
# Epoch Training Duration: 00:00:47
#
# - EPOCH 44 -
# Dice: 0.6677
# IoU: 0.5131
# Training Loss: 0.19112720489501953
# Validation Loss: 0.18384157159986594
# Epoch Training Duration: 00:00:48
#
# - EPOCH 45 -
# Dice: 0.6071
# IoU: 0.4468
# Training Loss: 0.18986209273338317
# Validation Loss: 0.1883025700226426
# Epoch Training Duration: 00:00:47
#
# - EPOCH 46 -
# Dice: 0.6330
# IoU: 0.4755
# Training Loss: 0.1864106293519338
# Validation Loss: 0.19091517423900464
# Epoch Training Duration: 00:00:47
#
# - EPOCH 47 -
# Dice: 0.6404
# IoU: 0.4821
# Training Loss: 0.18442702690760296
# Validation Loss: 0.18859406746923923
# Epoch Training Duration: 00:00:47
#
# - EPOCH 48 -
# Dice: 0.5864
# IoU: 0.4232
# Training Loss: 0.18404079139232635
# Validation Loss: 0.19663326209411025
# Epoch Training Duration: 00:00:47
#
# - EPOCH 49 -
# Dice: 0.6050
# IoU: 0.4450
# Training Loss: 0.18247492015361785
# Validation Loss: 0.20316428132355213
# Epoch Training Duration: 00:00:47
#
# - EPOCH 50 -
# Dice: 0.6232
# IoU: 0.4649
# Training Loss: 0.18027466813723247
# Validation Loss: 0.18513961679612598
# Epoch Training Duration: 00:00:46
#
# Total Training Duration for Threshold 0.8: 00:44:28
#
# -- TRAINING WITH THRESHOLD OF 0.9 --
#
# - EPOCH 1 -
# Dice: 0.3417
# IoU: 0.2132
# Training Loss: 0.33550163328647614
# Validation Loss: 0.22000557215263447
# Epoch Training Duration: 00:00:55
#
# - EPOCH 2 -
# Dice: 0.1088
# IoU: 0.0586
# Training Loss: 0.2770028072595596
# Validation Loss: 0.2205878533422947
# Epoch Training Duration: 00:00:47
#
# - EPOCH 3 -
# Dice: 0.3177
# IoU: 0.1964
# Training Loss: 0.2643910100062688
# Validation Loss: 0.2584533654153347
# Epoch Training Duration: 00:00:47
#
# - EPOCH 4 -
# Dice: 0.1673
# IoU: 0.0961
# Training Loss: 0.2580823395649592
# Validation Loss: 0.20862760969127217
# Epoch Training Duration: 00:00:47
#
# - EPOCH 5 -
# Dice: 0.5267
# IoU: 0.3684
# Training Loss: 0.25412821213404335
# Validation Loss: 0.19715079882492623
# Epoch Training Duration: 00:00:47
#
# - EPOCH 6 -
# Dice: 0.3237
# IoU: 0.2029
# Training Loss: 0.24870425919691722
# Validation Loss: 0.2273044375081857
# Epoch Training Duration: 00:00:47
#
# - EPOCH 7 -
# Dice: 0.2018
# IoU: 0.1215
# Training Loss: 0.2507440012693405
# Validation Loss: 0.2230789091748496
# Epoch Training Duration: 00:00:47
#
# - EPOCH 8 -
# Dice: 0.5048
# IoU: 0.3456
# Training Loss: 0.24599552035331726
# Validation Loss: 0.19810901784027615
# Epoch Training Duration: 00:00:47
#
# - EPOCH 9 -
# Dice: 0.4749
# IoU: 0.3209
# Training Loss: 0.24045901358127594
# Validation Loss: 0.1872072109642128
# Epoch Training Duration: 00:00:48
#
# - EPOCH 10 -
# Dice: 0.5419
# IoU: 0.3812
# Training Loss: 0.23926681141058603
# Validation Loss: 0.22737382197131714
# Epoch Training Duration: 00:00:47
#
# - EPOCH 11 -
# Dice: 0.3351
# IoU: 0.2092
# Training Loss: 0.23380857904752095
# Validation Loss: 0.1947545693255961
# Epoch Training Duration: 00:00:47
#
# - EPOCH 12 -
# Dice: 0.2253
# IoU: 0.1306
# Training Loss: 0.23675245225429534
# Validation Loss: 0.20532744812468687
# Epoch Training Duration: 00:00:47
#
# - EPOCH 13 -
# Dice: 0.4871
# IoU: 0.3330
# Training Loss: 0.23233760794003805
# Validation Loss: 0.18543447259192666
# Epoch Training Duration: 00:00:47
#
# - EPOCH 14 -
# Dice: 0.4829
# IoU: 0.3266
# Training Loss: 0.23250654657681782
# Validation Loss: 0.19315156418209276
# Epoch Training Duration: 00:00:47
#
# - EPOCH 15 -
# Dice: 0.5369
# IoU: 0.3783
# Training Loss: 0.22287267009417217
# Validation Loss: 0.19340735611816248
# Epoch Training Duration: 00:00:47
#
# - EPOCH 16 -
# Dice: 0.4415
# IoU: 0.2922
# Training Loss: 0.22478464722633362
# Validation Loss: 0.18580577475950122
# Epoch Training Duration: 00:00:48
#
# - EPOCH 17 -
# Dice: 0.5262
# IoU: 0.3657
# Training Loss: 0.22371345380942026
# Validation Loss: 0.19266725021104017
# Epoch Training Duration: 00:00:47
#
# - EPOCH 18 -
# Dice: 0.4638
# IoU: 0.3133
# Training Loss: 0.22343660334746043
# Validation Loss: 0.18341103987768292
# Epoch Training Duration: 00:00:47
#
# - EPOCH 19 -
# Dice: 0.3418
# IoU: 0.2214
# Training Loss: 0.22626584589481355
# Validation Loss: 0.20461424409101406
# Epoch Training Duration: 00:00:47
#
# - EPOCH 20 -
# Dice: 0.5831
# IoU: 0.4229
# Training Loss: 0.2273768279949824
# Validation Loss: 0.19044157319391766
# Epoch Training Duration: 00:00:47
#
# - EPOCH 21 -
# Dice: 0.4594
# IoU: 0.3084
# Training Loss: 0.21790464917818705
# Validation Loss: 0.18548785025874773
# Epoch Training Duration: 00:00:47
#
# - EPOCH 22 -
# Dice: 0.3103
# IoU: 0.1896
# Training Loss: 0.2124555399020513
# Validation Loss: 0.1907932792479793
# Epoch Training Duration: 00:00:47
#
# - EPOCH 23 -
# Dice: 0.4552
# IoU: 0.3046
# Training Loss: 0.2135593710343043
# Validation Loss: 0.1881851457680265
# Epoch Training Duration: 00:00:47
#
# - EPOCH 24 -
# Dice: 0.3707
# IoU: 0.2341
# Training Loss: 0.20930525143941245
# Validation Loss: 0.19214054429903626
# Epoch Training Duration: 00:00:47
#
# - EPOCH 25 -
# Dice: 0.5471
# IoU: 0.3861
# Training Loss: 0.20918148974577586
# Validation Loss: 0.21116025932133198
# Epoch Training Duration: 00:00:48
#
# - EPOCH 26 -
# Dice: 0.4811
# IoU: 0.3261
# Training Loss: 0.20697487771511078
# Validation Loss: 0.1848263432426999
# Epoch Training Duration: 00:00:47
#
# - EPOCH 27 -
# Dice: 0.3928
# IoU: 0.2557
# Training Loss: 0.2057173107067744
# Validation Loss: 0.1994598195888102
# Epoch Training Duration: 00:00:47
#
# - EPOCH 28 -
# Dice: 0.5034
# IoU: 0.3448
# Training Loss: 0.20253784239292144
# Validation Loss: 0.18716276421522102
# Epoch Training Duration: 00:00:47
#
# - EPOCH 29 -
# Dice: 0.5915
# IoU: 0.4315
# Training Loss: 0.20537581165631613
# Validation Loss: 0.19725452860196432
# Epoch Training Duration: 00:00:47
#
# - EPOCH 30 -
# Dice: 0.4324
# IoU: 0.2838
# Training Loss: 0.20153699537118275
# Validation Loss: 0.18643843894824386
# Epoch Training Duration: 00:00:47
#
# - EPOCH 31 -
# Dice: 0.5054
# IoU: 0.3472
# Training Loss: 0.20639071583747864
# Validation Loss: 0.18800103788574538
# Epoch Training Duration: 00:00:47
#
# - EPOCH 32 -
# Dice: 0.4154
# IoU: 0.2693
# Training Loss: 0.20309670865535737
# Validation Loss: 0.18194372424234947
# Epoch Training Duration: 00:00:48
#
# - EPOCH 33 -
# Dice: 0.3734
# IoU: 0.2367
# Training Loss: 0.19897579113642375
# Validation Loss: 0.18351417034864426
# Epoch Training Duration: 00:00:47
#
# - EPOCH 34 -
# Dice: 0.5575
# IoU: 0.3963
# Training Loss: 0.19784756263097128
# Validation Loss: 0.18787947576493025
# Epoch Training Duration: 00:00:47
#
# - EPOCH 35 -
# Dice: 0.5176
# IoU: 0.3585
# Training Loss: 0.1982377411921819
# Validation Loss: 0.1888577303228279
# Epoch Training Duration: 00:00:46
#
# - EPOCH 36 -
# Dice: 0.4305
# IoU: 0.2827
# Training Loss: 0.19759232918421427
# Validation Loss: 0.19010610909511647
# Epoch Training Duration: 00:00:47
#
# - EPOCH 37 -
# Dice: 0.4240
# IoU: 0.2771
# Training Loss: 0.19642046173413594
# Validation Loss: 0.19553680516158542
# Epoch Training Duration: 00:00:47
#
# - EPOCH 38 -
# Dice: 0.3815
# IoU: 0.2426
# Training Loss: 0.19318092981974283
# Validation Loss: 0.1910186824388802
# Epoch Training Duration: 00:00:48
#
# - EPOCH 39 -
# Dice: 0.4590
# IoU: 0.3059
# Training Loss: 0.19216354668140412
# Validation Loss: 0.20195037576680383
# Epoch Training Duration: 00:00:48
#
# - EPOCH 40 -
# Dice: 0.4959
# IoU: 0.3404
# Training Loss: 0.19599277138710022
# Validation Loss: 0.20333397729943195
# Epoch Training Duration: 00:00:48
#
# - EPOCH 41 -
# Dice: 0.5451
# IoU: 0.3841
# Training Loss: 0.18848659038543703
# Validation Loss: 0.17822310390571752
# Epoch Training Duration: 00:00:48
#
# - EPOCH 42 -
# Dice: 0.4949
# IoU: 0.3387
# Training Loss: 0.18827815353870392
# Validation Loss: 0.19096810851867
# Epoch Training Duration: 00:00:47
#
# - EPOCH 43 -
# Dice: 0.5184
# IoU: 0.3581
# Training Loss: 0.18756010254224142
# Validation Loss: 0.18077109955872098
# Epoch Training Duration: 00:00:47
#
# - EPOCH 44 -
# Dice: 0.4772
# IoU: 0.3227
# Training Loss: 0.18628858943780263
# Validation Loss: 0.19274888598981002
# Epoch Training Duration: 00:00:47
#
# - EPOCH 45 -
# Dice: 0.4837
# IoU: 0.3273
# Training Loss: 0.1905007682243983
# Validation Loss: 0.18154249045376977
# Epoch Training Duration: 00:00:47
#
# - EPOCH 46 -
# Dice: 0.6369
# IoU: 0.4789
# Training Loss: 0.18623381276925405
# Validation Loss: 0.1946141478450348
# Epoch Training Duration: 00:00:47
#
# - EPOCH 47 -
# Dice: 0.4874
# IoU: 0.3307
# Training Loss: 0.18417733788490295
# Validation Loss: 0.20078409602865577
# Epoch Training Duration: 00:00:48
#
# - EPOCH 48 -
# Dice: 0.5030
# IoU: 0.3464
# Training Loss: 0.18565083026885987
# Validation Loss: 0.17936671013012528
# Epoch Training Duration: 00:00:47
#
# - EPOCH 49 -
# Dice: 0.5542
# IoU: 0.3935
# Training Loss: 0.1821829515695572
# Validation Loss: 0.1848225498882433
# Epoch Training Duration: 00:00:47
#
# - EPOCH 50 -
# Dice: 0.5438
# IoU: 0.3813
# Training Loss: 0.18166093587875365
# Validation Loss: 0.18548736302182078
# Epoch Training Duration: 00:00:47
#
# Total Training Duration for Threshold 0.9: 00:44:27

# %% [markdown]
# # Plotting Statistics

# %% [markdown]
# Two main categories of statistics concerning the model are:
#
# * **Dice and Iou Scores** (plotted separately)
# * **Training and Validation Losses** (plotted together)

# %% [markdown]
# Plotting Dice and IoU.

# %%
def plot_metric(thresholds, scores, number_of_epochs, label, locator = False):
  fig, axes = plt.subplots(3, 3, figsize=(10, 10), sharey = True)
  axes = axes.flatten()

  for ax, threshold in zip(axes, thresholds):
    epochs = range(1, number_of_epochs + 1)
    ax.plot(epochs, scores[threshold], label = label)

    ax.set_xlabel('Epoch')
    ax.set_ylabel(label)
    ax.set_title(f'{label} | Threshold {threshold:.1f}')
    ax.legend()
    ax.grid(True)

    if locator:
      ax.yaxis.set_major_locator(MultipleLocator(0.05))

  plt.tight_layout()
  plt.show()

# %%
plot_metric(thresholds, all_dice_scores, number_of_epochs, 'Dice', True)
print()
plot_metric(thresholds, all_dice_scores, number_of_epochs, 'IoU', True)

# %% [markdown]
# Plotting Training and Validation losses.

# %%
def plot_losses(thresholds, all_train_losses, all_val_losses, number_of_epochs):
  fig, axes = plt.subplots(3, 3, figsize = (15, 10), sharey = True)
  axes = axes.flatten()

  for ax, threshold in zip(axes, thresholds):
    epochs = range(1, number_of_epochs + 1)
    ax.plot(epochs, all_train_losses[threshold], label = 'Training Loss')
    ax.plot(epochs, all_validation_losses[threshold], label = 'Validation Loss')

    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.set_title(f'Training and Validation Loss | Threshold {threshold:.1f}')
    ax.legend()
    ax.grid(True)

  plt.tight_layout()
  plt.show()

plot_losses(thresholds, all_train_losses, all_validation_losses, number_of_epochs)

# %% [markdown]
# # Downloading the Output – Predictions and Models

# %%
# !zip -r /predictions.zip /predictions
# !zip -r /models.zip /models

from google.colab import files

files.download("/predictions.zip")
files.download("/models.zip")
# Out:
# updating: predictions/ (stored 0%)
# updating: predictions/threshold_0.9/ (stored 0%)
# updating: predictions/threshold_0.9/4.png (deflated 3%)
# updating: predictions/threshold_0.9/predicted_11.png (deflated 4%)
# updating: predictions/threshold_0.9/10.png (deflated 11%)
# updating: predictions/threshold_0.9/7.png (deflated 5%)
# updating: predictions/threshold_0.9/3.png (deflated 30%)
# updating: predictions/threshold_0.9/predicted_9.png (deflated 57%)
# updating: predictions/threshold_0.9/11.png (stored 0%)
# updating: predictions/threshold_0.9/predicted_3.png (deflated 37%)
# updating: predictions/threshold_0.9/predicted_7.png (deflated 7%)
# updating: predictions/threshold_0.9/predicted_4.png (deflated 3%)
# updating: predictions/threshold_0.9/predicted_8.png (deflated 8%)
# updating: predictions/threshold_0.9/predicted_1.png (deflated 5%)
# updating: predictions/threshold_0.9/1.png (deflated 3%)
# updating: predictions/threshold_0.9/0.png (deflated 12%)
# updating: predictions/threshold_0.9/9.png (deflated 56%)
# updating: predictions/threshold_0.9/2.png (deflated 13%)
# updating: predictions/threshold_0.9/predicted_2.png (deflated 10%)
# updating: predictions/threshold_0.9/5.png (deflated 9%)
# updating: predictions/threshold_0.9/predicted_5.png (deflated 7%)
# updating: predictions/threshold_0.9/8.png (deflated 9%)
# updating: predictions/threshold_0.9/predicted_10.png (deflated 13%)
# updating: predictions/threshold_0.9/predicted_6.png (deflated 73%)
# updating: predictions/threshold_0.9/6.png (deflated 64%)
# updating: predictions/threshold_0.9/predicted_0.png (deflated 20%)
# updating: predictions/threshold_0.5/ (stored 0%)
# updating: predictions/threshold_0.5/4.png (deflated 3%)
# updating: predictions/threshold_0.5/predicted_11.png (deflated 1%)
# updating: predictions/threshold_0.5/10.png (deflated 11%)
# updating: predictions/threshold_0.5/7.png (deflated 5%)
# updating: predictions/threshold_0.5/3.png (deflated 30%)
# updating: predictions/threshold_0.5/predicted_9.png (deflated 50%)
# updating: predictions/threshold_0.5/11.png (stored 0%)
# updating: predictions/threshold_0.5/predicted_3.png (deflated 26%)
# updating: predictions/threshold_0.5/predicted_7.png (deflated 5%)
# updating: predictions/threshold_0.5/predicted_4.png (deflated 2%)
# updating: predictions/threshold_0.5/predicted_8.png (deflated 4%)
# updating: predictions/threshold_0.5/predicted_1.png (deflated 2%)
# updating: predictions/threshold_0.5/1.png (deflated 3%)
# updating: predictions/threshold_0.5/0.png (deflated 12%)
# updating: predictions/threshold_0.5/9.png (deflated 56%)
# updating: predictions/threshold_0.5/2.png (deflated 13%)
# updating: predictions/threshold_0.5/predicted_2.png (deflated 6%)
# updating: predictions/threshold_0.5/5.png (deflated 9%)
# updating: predictions/threshold_0.5/predicted_5.png (deflated 3%)
# updating: predictions/threshold_0.5/8.png (deflated 9%)
# updating: predictions/threshold_0.5/predicted_10.png (deflated 11%)
# updating: predictions/threshold_0.5/predicted_6.png (deflated 62%)
# updating: predictions/threshold_0.5/6.png (deflated 64%)
# updating: predictions/threshold_0.5/predicted_0.png (deflated 14%)
# updating: predictions/threshold_0.1/ (stored 0%)
# updating: predictions/threshold_0.1/4.png (deflated 3%)
# updating: predictions/threshold_0.1/predicted_11.png (deflated 0%)
# updating: predictions/threshold_0.1/10.png (deflated 11%)
# updating: predictions/threshold_0.1/7.png (deflated 5%)
# updating: predictions/threshold_0.1/3.png (deflated 30%)
# updating: predictions/threshold_0.1/predicted_9.png (deflated 31%)
# updating: predictions/threshold_0.1/11.png (stored 0%)
# updating: predictions/threshold_0.1/predicted_3.png (deflated 22%)
# updating: predictions/threshold_0.1/predicted_7.png (deflated 5%)
# updating: predictions/threshold_0.1/predicted_4.png (deflated 1%)
# updating: predictions/threshold_0.1/predicted_8.png (deflated 1%)
# updating: predictions/threshold_0.1/predicted_1.png (deflated 0%)
# updating: predictions/threshold_0.1/1.png (deflated 3%)
# updating: predictions/threshold_0.1/0.png (deflated 12%)
# updating: predictions/threshold_0.1/9.png (deflated 56%)
# updating: predictions/threshold_0.1/2.png (deflated 13%)
# updating: predictions/threshold_0.1/predicted_2.png (deflated 2%)
# updating: predictions/threshold_0.1/5.png (deflated 9%)
# updating: predictions/threshold_0.1/predicted_5.png (deflated 1%)
# updating: predictions/threshold_0.1/8.png (deflated 9%)
# updating: predictions/threshold_0.1/predicted_10.png (deflated 6%)
# updating: predictions/threshold_0.1/predicted_6.png (deflated 54%)
# updating: predictions/threshold_0.1/6.png (deflated 64%)
# updating: predictions/threshold_0.1/predicted_0.png (deflated 8%)
# updating: predictions/threshold_0.4/ (stored 0%)
# updating: predictions/threshold_0.4/4.png (deflated 3%)
# updating: predictions/threshold_0.4/predicted_11.png (deflated 1%)
# updating: predictions/threshold_0.4/10.png (deflated 11%)
# updating: predictions/threshold_0.4/7.png (deflated 5%)
# updating: predictions/threshold_0.4/3.png (deflated 30%)
# updating: predictions/threshold_0.4/predicted_9.png (deflated 35%)
# updating: predictions/threshold_0.4/11.png (stored 0%)
# updating: predictions/threshold_0.4/predicted_3.png (deflated 25%)
# updating: predictions/threshold_0.4/predicted_7.png (deflated 5%)
# updating: predictions/threshold_0.4/predicted_4.png (deflated 2%)
# updating: predictions/threshold_0.4/predicted_8.png (deflated 2%)
# updating: predictions/threshold_0.4/predicted_1.png (deflated 1%)
# updating: predictions/threshold_0.4/1.png (deflated 3%)
# updating: predictions/threshold_0.4/0.png (deflated 12%)
# updating: predictions/threshold_0.4/9.png (deflated 56%)
# updating: predictions/threshold_0.4/2.png (deflated 13%)
# updating: predictions/threshold_0.4/predicted_2.png (deflated 3%)
# updating: predictions/threshold_0.4/5.png (deflated 9%)
# updating: predictions/threshold_0.4/predicted_5.png (deflated 1%)
# updating: predictions/threshold_0.4/8.png (deflated 9%)
# updating: predictions/threshold_0.4/predicted_10.png (deflated 9%)
# updating: predictions/threshold_0.4/predicted_6.png (deflated 48%)
# updating: predictions/threshold_0.4/6.png (deflated 64%)
# updating: predictions/threshold_0.4/predicted_0.png (deflated 11%)
# updating: predictions/threshold_0.6/ (stored 0%)
# updating: predictions/threshold_0.6/4.png (deflated 3%)
# updating: predictions/threshold_0.6/predicted_11.png (deflated 2%)
# updating: predictions/threshold_0.6/10.png (deflated 11%)
# updating: predictions/threshold_0.6/7.png (deflated 5%)
# updating: predictions/threshold_0.6/3.png (deflated 30%)
# updating: predictions/threshold_0.6/predicted_9.png (deflated 54%)
# updating: predictions/threshold_0.6/11.png (stored 0%)
# updating: predictions/threshold_0.6/predicted_3.png (deflated 29%)
# updating: predictions/threshold_0.6/predicted_7.png (deflated 5%)
# updating: predictions/threshold_0.6/predicted_4.png (deflated 1%)
# updating: predictions/threshold_0.6/predicted_8.png (deflated 3%)
# updating: predictions/threshold_0.6/predicted_1.png (deflated 1%)
# updating: predictions/threshold_0.6/1.png (deflated 3%)
# updating: predictions/threshold_0.6/0.png (deflated 12%)
# updating: predictions/threshold_0.6/9.png (deflated 56%)
# updating: predictions/threshold_0.6/2.png (deflated 13%)
# updating: predictions/threshold_0.6/predicted_2.png (deflated 4%)
# updating: predictions/threshold_0.6/5.png (deflated 9%)
# updating: predictions/threshold_0.6/predicted_5.png (deflated 3%)
# updating: predictions/threshold_0.6/8.png (deflated 9%)
# updating: predictions/threshold_0.6/predicted_10.png (deflated 8%)
# updating: predictions/threshold_0.6/predicted_6.png (deflated 55%)
# updating: predictions/threshold_0.6/6.png (deflated 64%)
# updating: predictions/threshold_0.6/predicted_0.png (deflated 11%)
# updating: predictions/threshold_0.2/ (stored 0%)
# updating: predictions/threshold_0.2/4.png (deflated 3%)
# updating: predictions/threshold_0.2/predicted_11.png (stored 0%)
# updating: predictions/threshold_0.2/10.png (deflated 11%)
# updating: predictions/threshold_0.2/7.png (deflated 5%)
# updating: predictions/threshold_0.2/3.png (deflated 30%)
# updating: predictions/threshold_0.2/predicted_9.png (deflated 32%)
# updating: predictions/threshold_0.2/11.png (stored 0%)
# updating: predictions/threshold_0.2/predicted_3.png (deflated 21%)
# updating: predictions/threshold_0.2/predicted_7.png (deflated 3%)
# updating: predictions/threshold_0.2/predicted_4.png (deflated 1%)
# updating: predictions/threshold_0.2/predicted_8.png (deflated 1%)
# updating: predictions/threshold_0.2/predicted_1.png (deflated 0%)
# updating: predictions/threshold_0.2/1.png (deflated 3%)
# updating: predictions/threshold_0.2/0.png (deflated 12%)
# updating: predictions/threshold_0.2/9.png (deflated 56%)
# updating: predictions/threshold_0.2/2.png (deflated 13%)
# updating: predictions/threshold_0.2/predicted_2.png (deflated 1%)
# updating: predictions/threshold_0.2/5.png (deflated 9%)
# updating: predictions/threshold_0.2/predicted_5.png (deflated 0%)
# updating: predictions/threshold_0.2/8.png (deflated 9%)
# updating: predictions/threshold_0.2/predicted_10.png (deflated 7%)
# updating: predictions/threshold_0.2/predicted_6.png (deflated 42%)
# updating: predictions/threshold_0.2/6.png (deflated 64%)
# updating: predictions/threshold_0.2/predicted_0.png (deflated 9%)
# updating: predictions/threshold_0.3/ (stored 0%)
# updating: predictions/threshold_0.3/4.png (deflated 3%)
# updating: predictions/threshold_0.3/predicted_11.png (deflated 2%)
# updating: predictions/threshold_0.3/10.png (deflated 11%)
# updating: predictions/threshold_0.3/7.png (deflated 5%)
# updating: predictions/threshold_0.3/3.png (deflated 30%)
# updating: predictions/threshold_0.3/predicted_9.png (deflated 39%)
# updating: predictions/threshold_0.3/11.png (stored 0%)
# updating: predictions/threshold_0.3/predicted_3.png (deflated 25%)
# updating: predictions/threshold_0.3/predicted_7.png (deflated 5%)
# updating: predictions/threshold_0.3/predicted_4.png (deflated 1%)
# updating: predictions/threshold_0.3/predicted_8.png (deflated 1%)
# updating: predictions/threshold_0.3/predicted_1.png (deflated 1%)
# updating: predictions/threshold_0.3/1.png (deflated 3%)
# updating: predictions/threshold_0.3/0.png (deflated 12%)
# updating: predictions/threshold_0.3/9.png (deflated 56%)
# updating: predictions/threshold_0.3/2.png (deflated 13%)
# updating: predictions/threshold_0.3/predicted_2.png (deflated 3%)
# updating: predictions/threshold_0.3/5.png (deflated 9%)
# updating: predictions/threshold_0.3/predicted_5.png (deflated 1%)
# updating: predictions/threshold_0.3/8.png (deflated 9%)
# updating: predictions/threshold_0.3/predicted_10.png (deflated 8%)
# updating: predictions/threshold_0.3/predicted_6.png (deflated 46%)
# updating: predictions/threshold_0.3/6.png (deflated 64%)
# updating: predictions/threshold_0.3/predicted_0.png (deflated 8%)
# updating: predictions/threshold_0.8/ (stored 0%)
# updating: predictions/threshold_0.8/4.png (deflated 3%)
# updating: predictions/threshold_0.8/predicted_11.png (deflated 1%)
# updating: predictions/threshold_0.8/10.png (deflated 11%)
# updating: predictions/threshold_0.8/7.png (deflated 5%)
# updating: predictions/threshold_0.8/3.png (deflated 30%)
# updating: predictions/threshold_0.8/predicted_9.png (deflated 55%)
# updating: predictions/threshold_0.8/11.png (stored 0%)
# updating: predictions/threshold_0.8/predicted_3.png (deflated 30%)
# updating: predictions/threshold_0.8/predicted_7.png (deflated 8%)
# updating: predictions/threshold_0.8/predicted_4.png (deflated 3%)
# updating: predictions/threshold_0.8/predicted_8.png (deflated 7%)
# updating: predictions/threshold_0.8/predicted_1.png (deflated 3%)
# updating: predictions/threshold_0.8/1.png (deflated 3%)
# updating: predictions/threshold_0.8/0.png (deflated 12%)
# updating: predictions/threshold_0.8/9.png (deflated 56%)
# updating: predictions/threshold_0.8/2.png (deflated 13%)
# updating: predictions/threshold_0.8/predicted_2.png (deflated 8%)
# updating: predictions/threshold_0.8/5.png (deflated 9%)
# updating: predictions/threshold_0.8/predicted_5.png (deflated 5%)
# updating: predictions/threshold_0.8/8.png (deflated 9%)
# updating: predictions/threshold_0.8/predicted_10.png (deflated 13%)
# updating: predictions/threshold_0.8/predicted_6.png (deflated 65%)
# updating: predictions/threshold_0.8/6.png (deflated 64%)
# updating: predictions/threshold_0.8/predicted_0.png (deflated 17%)
# updating: predictions/threshold_0.7/ (stored 0%)
# updating: predictions/threshold_0.7/4.png (deflated 3%)
# updating: predictions/threshold_0.7/predicted_11.png (deflated 1%)
# updating: predictions/threshold_0.7/10.png (deflated 11%)
# updating: predictions/threshold_0.7/7.png (deflated 5%)
# updating: predictions/threshold_0.7/3.png (deflated 30%)
# updating: predictions/threshold_0.7/predicted_9.png (deflated 56%)
# updating: predictions/threshold_0.7/11.png (stored 0%)
# updating: predictions/threshold_0.7/predicted_3.png (deflated 30%)
# updating: predictions/threshold_0.7/predicted_7.png (deflated 6%)
# updating: predictions/threshold_0.7/predicted_4.png (deflated 2%)
# updating: predictions/threshold_0.7/predicted_8.png (deflated 5%)
# updating: predictions/threshold_0.7/predicted_1.png (deflated 2%)
# updating: predictions/threshold_0.7/1.png (deflated 3%)
# updating: predictions/threshold_0.7/0.png (deflated 12%)
# updating: predictions/threshold_0.7/9.png (deflated 56%)
# updating: predictions/threshold_0.7/2.png (deflated 13%)
# updating: predictions/threshold_0.7/predicted_2.png (deflated 7%)
# updating: predictions/threshold_0.7/5.png (deflated 9%)
# updating: predictions/threshold_0.7/predicted_5.png (deflated 5%)
# updating: predictions/threshold_0.7/8.png (deflated 9%)
# updating: predictions/threshold_0.7/predicted_10.png (deflated 12%)
# updating: predictions/threshold_0.7/predicted_6.png (deflated 66%)
# updating: predictions/threshold_0.7/6.png (deflated 64%)
# updating: predictions/threshold_0.7/predicted_0.png (deflated 16%)
# updating: models/ (stored 0%)
# updating: models/UNet_Threshold_0.3.pth (deflated 7%)
# updating: models/UNet_Threshold_0.2.pth (deflated 7%)
# updating: models/UNet_Threshold_0.8.pth (deflated 7%)
# updating: models/UNet_Threshold_0.7.pth (deflated 7%)
# updating: models/UNet_Threshold_0.9.pth (deflated 7%)
# updating: models/UNet_Threshold_0.1.pth (deflated 7%)
# updating: models/UNet_Threshold_0.4.pth (deflated 7%)
# updating: models/UNet_Threshold_0.5.pth (deflated 7%)
# updating: models/UNet_Threshold_0.6.pth (deflated 7%)

# %% [markdown]
# ## API ##

# %% [markdown]
# API should be used for testing purposes. A user may upload an image and get the mask of buildings back.
#
# **File segmentator.html must be added to the root folder for the API interface to work!**
#
# **Likewise, a model must be provided!**
#
# API selects the best model based on Dice score and passes user input to it in order to get the mask and display it to the user.

# %% [markdown]
# Use the link as the API interface.

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(5000)"))
# Out:
# https://f7v5l3uje3t-496ff2e9c6d22116-5000-colab.googleusercontent.com/

# %% [markdown]
# Selecting and loading the best model available.

# %%
# Get the threshold with highest Dice score
best_threshold = max(all_dice_scores, key = all_dice_scores.get)
best_dice_score = all_dice_scores[best_threshold][-1]

print(f'Best threshold: {best_threshold} with Dice score: {best_dice_score}')

# Load the appropriate model based on the highest Dice score
best_model = UNet(in_channels = 3, out_channels = 1).to(device)
model_path = f'../models/UNet_Threshold_{best_threshold}.pth'

best_model.load_state_dict(torch.load(model_path))
# Out:
# Best threshold: 0.6 with Dice score: 0.7061959927280744
# <All keys matched successfully>

# %% [markdown]
# Using Flask to handle user requests.

# %%
from flask import Flask, render_template, request
import torchvision.transforms as transforms
import io
import base64

app = Flask(__name__, template_folder='../')

@app.route('/', methods=['GET', 'POST'])
def index():
  original_image_base64 = None
  mask_base64 = None

  if request.method == 'POST':

    file = request.files['file']
    original_image = np.array(Image.open(file).convert("RGB"))

    transformed_image = validation_transform(image = original_image)['image']

    predicted_mask = best_model(torch.unsqueeze(transformed_image, 0).to(device))
    predicted_mask = torch.sigmoid(predicted_mask)
    predicted_mask = (predicted_mask > best_threshold).float().cpu().squeeze().numpy()

    mask_pil = transforms.ToPILImage()(predicted_mask)

    original_image_buffered = io.BytesIO()
    mask_buffered = io.BytesIO()

    Image.fromarray(original_image).save(original_image_buffered, format = "PNG")
    mask_pil.save(mask_buffered, format = "PNG")

    original_image_base64 = base64.b64encode(original_image_buffered.getvalue()).decode('utf-8')
    mask_base64 = base64.b64encode(mask_buffered.getvalue()).decode('utf-8')

  # Don't forget to upload segmentator.html to main folder!
  return render_template('segmentator.html', original_image = original_image_base64, mask = mask_base64)

if __name__ == "__main__":
  app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [18/May/2024 00:57:06] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/May/2024 00:57:07] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [18/May/2024 00:57:14] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/May/2024 00:57:15] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [18/May/2024 00:57:31] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/May/2024 00:57:32] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [18/May/2024 00:57:49] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/May/2024 00:57:50] "GET /favicon.ico HTTP/1.1" 404 -
